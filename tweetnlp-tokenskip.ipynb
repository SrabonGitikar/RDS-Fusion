# %% [markdown]
# First, we need to set up the environment with the necessary Hugging Face libraries, including bitsandbytes for memory-efficient model loading and llmlingua for the base token importance.

# %%
# !pip install -q transformers datasets accelerate bitsandbytes torch
# !pip install -q llmlingua
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.7/60.7 MB 31.6 MB/s eta 0:00:00:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.2/12.2 MB 79.6 MB/s eta 0:00:00:00:010:01
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# dask-cuda 26.2.0 requires cuda-core==0.3.*, but you have cuda-core 1.0.1 which is incompatible.
# dask-cuda 26.2.0 requires numba-cuda<0.23.0,>=0.22.1, but you have numba-cuda 0.30.2 which is incompatible.
# distributed-ucxx-cu12 0.48.0 requires numba-cuda[cu12]<0.23.0,>=0.22.1, but you have numba-cuda 0.30.2 which is incompatible.
# cuml-cu12 26.2.0 requires numba<0.62.0,>=0.60.0, but you have numba 0.65.1 which is incompatible.
# cuml-cu12 26.2.0 requires numba-cuda[cu12]<0.23.0,>=0.22.1, but you have numba-cuda 0.30.2 which is incompatible.
# ucxx-cu12 0.48.0 requires numba-cuda[cu12]<0.23.0,>=0.22.1, but you have numba-cuda 0.30.2 which is incompatible.
# cudf-cu12 26.2.1 requires numba<0.62.0,>=0.60.0, but you have numba 0.65.1 which is incompatible.
# cudf-cu12 26.2.1 requires numba-cuda[cu12]<0.23.0,>=0.22.2, but you have numba-cuda 0.30.2 which is incompatible.

# %% [markdown]
# We will load the TweetEval dataset, the RoBERTa classifier, and the Qwen2.5 generator.

# %%
import torch
import numpy as np
from transformers import AutoTokenizer, AutoModelForCausalLM, AutoModelForSequenceClassification, BitsAndBytesConfig
from datasets import load_dataset

device = "cuda" if torch.cuda.is_available() else "cpu"

# 1. Load Dataset (TweetEval - Irony)
print("Loading Dataset...")
dataset = load_dataset("tweet_eval", "irony")
test_data = dataset['test']

# 2. Load Evaluation Classifier (RoBERTa)
print("Loading RoBERTa Classifier...")
roberta_name = "cardiffnlp/twitter-roberta-base-irony"
rob_tokenizer = AutoTokenizer.from_pretrained(roberta_name)
rob_model = AutoModelForSequenceClassification.from_pretrained(roberta_name).to(device)

# 3. Define the 4-bit Quantization Configuration
print("Configuring 4-bit Quantization...")
bnb_config = BitsAndBytesConfig(
    load_in_4bit=True,
    bnb_4bit_use_double_quant=True,
    bnb_4bit_quant_type="nf4",
    bnb_4bit_compute_dtype=torch.float16 # Speeds up computation on T4
)

# 4. Load Reasoning Generator (Qwen 3B with updated quantization)
print("Loading Qwen2.5-3B...")
qwen_name = "Qwen/Qwen2.5-3B-Instruct"
qwen_tokenizer = AutoTokenizer.from_pretrained(qwen_name)
qwen_model = AutoModelForCausalLM.from_pretrained(
    qwen_name,
    device_map="auto",
    quantization_config=bnb_config
)
# Out:
# Loading Dataset...
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# README.md: 0.00B [00:00, ?B/s]
# irony/train-00000-of-00001.parquet:   0%|          | 0.00/183k [00:00<?, ?B/s]
# irony/test-00000-of-00001.parquet:   0%|          | 0.00/54.0k [00:00<?, ?B/s]
# irony/validation-00000-of-00001.parquet:   0%|          | 0.00/61.1k [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/2862 [00:00<?, ? examples/s]
# Generating test split:   0%|          | 0/784 [00:00<?, ? examples/s]
# Generating validation split:   0%|          | 0/955 [00:00<?, ? examples/s]
# Loading RoBERTa Classifier...
# config.json:   0%|          | 0.00/705 [00:00<?, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/150 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/499M [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/201 [00:00<?, ?it/s]
# RobertaForSequenceClassification LOAD REPORT from: cardiffnlp/twitter-roberta-base-irony
# Key                             | Status     |  |
# --------------------------------+------------+--+-
# roberta.embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# model.safetensors:   0%|          | 0.00/499M [00:00<?, ?B/s]
# Configuring 4-bit Quantization...
# Loading Qwen2.5-3B...
# config.json:   0%|          | 0.00/661 [00:00<?, ?B/s]
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# model.safetensors.index.json: 0.00B [00:00, ?B/s]
# Downloading (incomplete total...): 0.00B [00:00, ?B/s]
# Fetching 2 files:   0%|          | 0/2 [00:00<?, ?it/s]
# Loading weights:   0%|          | 0/434 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/242 [00:00<?, ?B/s]

# %% [markdown]
# This cell translates our equation for $H(c)$ and the scaled sigmoid transformation into code. It extracts the logits from Qwen's generation to calculate how "uncertain" or complex the reasoning is.

# %%
import torch
import torch.nn.functional as F
import math

def calculate_dynamic_gamma(logits, min_gamma=0.1, max_gamma=0.9, k=1, mu=0.5):
    """
    Calculates the reasoning entropy and maps it to a dynamic compression ratio.
    """
    # Convert logits to probabilities
    probs = F.softmax(logits, dim=-1)

    # Epsilon (1e-9) to prevent log(0) yielding -inf and breaking the sum into a nan
    epsilon = 1e-9
    entropy_tensor = -torch.sum(probs * torch.log(probs + epsilon), dim=-1)
    entropy = entropy_tensor.mean().item()

    # Fallback catch just in case a nan slips through due to precision limits
    if math.isnan(entropy):
        entropy = 0.0

    # USING math.exp instead of np.exp since entropy is a standard float here
    gamma_dyn = min_gamma + (max_gamma - min_gamma) / (1 + math.exp(-k * (entropy - mu)))

    return gamma_dyn, entropy

# %% [markdown]
# This is the core of the adversarial robustness. We pass the text through RoBERTa, grab the embeddings, and compute the gradient of the loss with respect to those embeddings.

# %%
def get_gradient_sensitivity(text, rob_tokenizer, rob_model, device, target_class=1):
    """
    Approximates token impact by checking the gradient norm of the embeddings
    during a backward pass in the RoBERTa classifier.
    """
    inputs = rob_tokenizer(text, return_tensors="pt").to(device)

    # Get the embedding layer output and retain its gradients
    embeddings = rob_model.roberta.embeddings.word_embeddings(inputs['input_ids'])
    embeddings.retain_grad()

    # Forward pass
    outputs = rob_model(inputs_embeds=embeddings, attention_mask=inputs['attention_mask'])
    logits = outputs.logits

    # Compute a dummy loss against the predicted or target class
    loss = F.cross_entropy(logits, torch.tensor([target_class]).to(device))

    # Backward pass to get gradients
    rob_model.zero_grad()
    loss.backward()

    # Calculate the L2 norm of the gradients for each token
    grad_norms = embeddings.grad.norm(dim=-1).squeeze().cpu().numpy()

    # Map back to tokens
    tokens = rob_tokenizer.convert_ids_to_tokens(inputs['input_ids'].squeeze())

    # Explicit list of tokens and punctuation to completely ignore
    skip_tokens = {'<s>', '</s>', '<pad>', '<unk>', '.', ',', ':', '"', "'", '?', '!'}

    sensitivity_scores = {}
    for token, grad in zip(tokens, grad_norms):
        # Clean special characters from RoBERTa tokens (like Ġ)
        clean_token = token.replace('Ġ', '').strip()

        # Filtering logic to ignore special tokens and single-character noise
        if clean_token and token not in skip_tokens and len(clean_token) > 1:
            # If a word is split into subwords, keep the max gradient value
            if clean_token in sensitivity_scores:
                sensitivity_scores[clean_token] = max(sensitivity_scores[clean_token], float(grad))
            else:
                sensitivity_scores[clean_token] = float(grad)

    return sensitivity_scores

# %% [markdown]
# Self Classification

# %%
import torch
import torch.nn.functional as F
import nltk, re
from nltk.corpus import stopwords

nltk.download('stopwords', quiet=True)
nltk.download('punkt', quiet=True)


# ═════════════════════════════════════════════════════════════════════════════
# PROMPTS  — continuous confidence scoring with explicit hashtag guidance
# ═════════════════════════════════════════════════════════════════════════════

STRUCTURED_PROMPT = """\
You are an expert linguist specializing in detecting irony and sarcasm in social media text.

DEFINITION: A tweet is IRONIC if there is a contrast between its literal meaning and its \
intended meaning, or if the author says the opposite of what they actually mean (often to \
mock, criticize, or be humorous). A tweet is NON-IRONIC if it is a sincere, literal statement.

KEY SIGNALS TO CHECK:
  - Does the literal meaning contradict the real-world situation?
  - Is there an exaggerated, over-the-top positive/negative tone?
  - Are there hashtags like #not, #sarcasm, #irony, #obviously that signal ironic intent?
  - Does the tweet mock or criticize something by pretending to praise it?
  - Would a reasonable reader take this at face value, or detect a hidden meaning?
  - Are there elongated words like "Loooove" or "Soooo" used sarcastically?

CONFIDENCE SCALE:
  0.0 = Absolutely certain NON-IRONIC (sincere, literal, no ambiguity at all)
  0.1 = Very likely non-ironic, tiny residual doubt
  0.3 = Probably non-ironic, some mixed signals present
  0.5 = Completely uncertain — could genuinely be either
  0.7 = Probably ironic, some mixed signals present
  0.9 = Very likely ironic, tiny residual doubt
  1.0 = Absolutely certain IRONIC (clear sarcasm/irony, no ambiguity at all)

EXAMPLES:
Tweet: "Oh great, another Monday. Just what I needed."
Reasoning: "Just what I needed" is exaggeratedly positive about something universally \
disliked. Classic sarcasm with no ambiguity.
Score: 0.95

Tweet: "Happy birthday to my best friend! Hope your day is amazing."
Reasoning: Sincere, literal birthday wish. No hidden meaning, no contrast, tone \
matches content perfectly.
Score: 0.05

Tweet: "Wow, love how my flight got cancelled on the day of my interview. Truly blessed."
Reasoning: "Truly blessed" after describing a disaster is a clear ironic inversion. \
Very high confidence.
Score: 0.92

Tweet: "This weather is something else today."
Reasoning: Ambiguous — could be genuine admiration or sarcastic complaint depending \
on context not available in the tweet alone.
Score: 0.50

Now analyze the following tweet using the same reasoning process.

Tweet: '{tweet}'

Think step by step through the KEY SIGNALS above. End your response with EXACTLY:
Score: X.XX
(a number between 0.00 and 1.00, two decimal places)"""


FORCED_VERDICT_PROMPT = """\
You analyzed a tweet and wrote this reasoning:
---
{cot_text}
---

Based solely on your own analysis above, rate your confidence that the tweet is ironic.

Output ONLY a single line in this exact format, nothing else:
Score: X.XX
(0.00 = definitely non-ironic, 0.50 = uncertain, 1.00 = definitely ironic)"""


# ═════════════════════════════════════════════════════════════════════════════
# EXPLICIT IRONY SIGNAL DETECTOR
# Catches author-labeled irony signals that both RoBERTa and CoT systematically
# miss: #not, #sarcasm, #irony, emoji contrast, letter elongation.
# ═════════════════════════════════════════════════════════════════════════════

_STRONG_IRONY_RE = re.compile(
    r"#(not|sarcasm|sarcastic|irony|ironic|jk|justkidding|kms|killme|"
    r"killusslow|obviously|surenot|yeahright|fml|eyeroll)\b",
    re.IGNORECASE
)
_WEAK_IRONY_RE = re.compile(
    r"#(humor|lol|smh|seriously|really|wow|sure|totally|great|wonderful)\b",
    re.IGNORECASE
)
# Positive emoji followed immediately by negative emoji → contrast = sarcasm
_EMOJI_CONTRAST_RE = re.compile(
    r"[😊😄😀👍❤️🙂😁]\s{0,3}[|,\s]*\s{0,3}[😒😤😡😞😑🙄😔😢]"
)
# Letter elongation: "Loooovvveee", "Soooo" (3+ repeated chars)
_ELONGATION_RE = re.compile(r"([a-zA-Z])\1{2,}")

def detect_explicit_irony_signal(tweet_text):
    """
    Scans tweet text for explicit, author-provided irony/sarcasm markers.

    Returns a float in [0.0, 0.88]:
      0.88  → Strong signal (#not, #sarcasm, #irony etc.) — near-certain irony
      0–0.70 → Weak composite signal (soft hashtags + emoji contrast + elongation)
      0.0   → No explicit signal detected

    Design note: Even at 0.88, the blending formula (60/40) means a COMBINED
    very-wrong RoBERTa+CoT can still override, preventing false positives.
    """
    if _STRONG_IRONY_RE.search(tweet_text):
        return 0.88

    score = 0.0
    if _WEAK_IRONY_RE.search(tweet_text):
        score += 0.15
    if _EMOJI_CONTRAST_RE.search(tweet_text):
        score += 0.25
    if _ELONGATION_RE.search(tweet_text):
        score += 0.12
    return min(score, 0.70)


# ═════════════════════════════════════════════════════════════════════════════
# CONFIDENCE SCORE EXTRACTION  (unchanged from v4)
# ═════════════════════════════════════════════════════════════════════════════

def extract_cot_confidence(cot_text):
    """
    Parses Qwen's continuous confidence score from its CoT output.
    Returns float in [0.0, 1.0].

    Priority order:
      P1. Explicit "Score: X.XX" line
      P2. Legacy "Verdict: IRONIC/NON-IRONIC" line (backward compat)
      P3. Negation-aware weighted scan on last 3 sentences → mapped to [0.15, 0.85]
      P4. Full-text fallback → returns 0.5
    """
    lower = cot_text.lower().strip()

    # P1: Score line
    score_match = re.search(
        r"score\s*[:\-]\s*([01](?:\.\d{1,2})?|0?\.\d{1,2})",
        lower
    )
    if score_match:
        return max(0.0, min(1.0, float(score_match.group(1))))

    # P2: Legacy verdict line
    verdict_match = re.search(r"verdict\s*[:\-]\s*(.{1,40})", lower)
    if verdict_match:
        v = verdict_match.group(1).strip()
        if re.search(r"\b(non[- ]?ironic|not\s+ironic|not\s+sarcastic|"
                     r"sincere|literal|no\s+irony|no\s+sarcasm)\b", v):
            return 0.1
        if re.search(r"\b(ironic|sarcastic|sarcasm|irony)\b", v):
            return 0.9
        if re.search(r"^\s*(yes|correct|true|indeed)\s*$", v):
            return 0.9
        if re.search(r"^\s*(no|false|incorrect)\s*$", v):
            return 0.1

    # P3: Negation-aware scan on last 3 sentences
    sentences  = re.split(r"(?<=[.!?])\s+", cot_text.strip())
    window     = sentences[-3:] if len(sentences) >= 3 else sentences
    conclusion = " ".join(window).lower()

    NEGATED_IRONY  = re.compile(
        r"\b(not|no|isn'?t|aren'?t|doesn'?t|without|lacks?|free\s+from)\b"
        r".{0,25}\b(iron(?:ic|y)|sarcas(?:m|tic))\b"
    )
    PLAIN_IRONY    = re.compile(r"\b(iron(?:ic|y)|sarcas(?:m|tic))\b")
    CONCLUDE_WORDS = re.compile(
        r"\b(therefore|thus|hence|so|conclude|conclusion|overall|in\s+summary|"
        r"clearly|obviously|evident|appears?|seems?|suggest|indicate)\b"
    )
    DIRECT_IRONIC = re.compile(
        r"\b(this|the)\s+(tweet|text|statement|post)\s+(is|appears?|seems?)\s+"
        r"(?:to\s+be\s+)?(ironic|sarcastic)\b"
    )
    DIRECT_NONIRONIC = re.compile(
        r"\b(this|the)\s+(tweet|text|statement|post)\s+(is|appears?|seems?)\s+"
        r"(?:to\s+be\s+)?(?:not\s+|non[- ]?)(ironic|sarcastic)\b"
        r"|\b(genuine|sincere|literal|straightforward|earnest)\b"
    )

    ironic_score = nonironic_score = 0
    negated_spans = [(m.start(), m.end()) for m in NEGATED_IRONY.finditer(conclusion)]
    for s, e in negated_spans:
        ctx = conclusion[max(0,s-50):s] + conclusion[e:e+50]
        nonironic_score += 3 if CONCLUDE_WORDS.search(ctx) else 2
    for m in PLAIN_IRONY.finditer(conclusion):
        if any(s <= m.start() <= e for s, e in negated_spans):
            continue
        ctx = conclusion[max(0, m.start()-50):m.start()] + conclusion[m.end():m.end()+50]
        ironic_score += 3 if CONCLUDE_WORDS.search(ctx) else 2
    ironic_score    += len(DIRECT_IRONIC.findall(conclusion))    * 2
    nonironic_score += len(DIRECT_NONIRONIC.findall(conclusion)) * 2

    total = ironic_score + nonironic_score
    if total > 0:
        return 0.15 + (ironic_score / total) * 0.70

    # P4: Full-text fallback
    full_negated = len(NEGATED_IRONY.findall(lower))
    full_plain   = len(PLAIN_IRONY.findall(lower)) - full_negated
    total_full   = full_plain + full_negated
    if total_full > 0:
        return 0.15 + (max(0, full_plain) / total_full) * 0.70

    return 0.5


# ═════════════════════════════════════════════════════════════════════════════
# TWO-PASS FALLBACK
# ═════════════════════════════════════════════════════════════════════════════

def get_forced_score(cot_text, qwen_model, qwen_tokenizer, device):
    """Pass 2: triggered when Pass 1 returns exactly 0.5. Max 10 new tokens."""
    prompt  = FORCED_VERDICT_PROMPT.format(cot_text=cot_text[:800])
    inputs  = qwen_tokenizer(prompt, return_tensors="pt").to(device)
    with torch.no_grad():
        outputs = qwen_model.generate(**inputs, max_new_tokens=10, do_sample=False)
    generated_ids = outputs[0][inputs["input_ids"].shape[1]:]
    response      = qwen_tokenizer.decode(generated_ids, skip_special_tokens=True)
    return extract_cot_confidence(response)


def get_cot_signal_with_fallback(cot_text, qwen_model, qwen_tokenizer, device):
    """Returns continuous float in [0.0, 1.0]. Runs Pass 2 only if Pass 1 gives 0.5."""
    score = extract_cot_confidence(cot_text)
    if score == 0.5:
        score = get_forced_score(cot_text, qwen_model, qwen_tokenizer, device)
    return score


# ═════════════════════════════════════════════════════════════════════════════
# ROBERTA CLASSIFIER  (unchanged)
# ═════════════════════════════════════════════════════════════════════════════

def classify_tweet(tweet_text, rob_tokenizer, rob_model, device):
    """Classify the raw tweet with RoBERTa. Returns (predicted_class, logits)."""
    inputs = rob_tokenizer(tweet_text, return_tensors="pt",
                           truncation=True, max_length=128).to(device)
    with torch.no_grad():
        outputs = rob_model(**inputs)
    logits     = outputs.logits
    prediction = torch.argmax(logits, dim=-1).item()
    return prediction, logits


# ═════════════════════════════════════════════════════════════════════════════
# ENTROPY-GATED ADAPTIVE ALPHA
# Changes: alpha_low 0.55→0.50, alpha_high 0.85→0.88
# Risk of tweet-10 regression mitigated by CoT skepticism applied before this.
# ═════════════════════════════════════════════════════════════════════════════

def entropy_to_alpha(entropy,
                     low_thresh=0.2,  high_thresh=0.5,
                     alpha_low=0.50,  alpha_high=0.88):
    """
    Maps reasoning entropy to RoBERTa weight (alpha).
      Low entropy  → Qwen was confident → trust CoT more → lower alpha (0.50)
      High entropy → Qwen was uncertain → trust RoBERTa more → higher alpha (0.88)
    """
    if entropy <= low_thresh:
        return alpha_low
    elif entropy >= high_thresh:
        return alpha_high
    t = (entropy - low_thresh) / (high_thresh - low_thresh)
    return alpha_low + t * (alpha_high - alpha_low)


# ═════════════════════════════════════════════════════════════════════════════
# FUSED CLASSIFICATION  v5
# New in this version vs v4:
#   1. CoT extreme score skepticism — pulls p_cot toward 0.5 when Qwen's
#      generation entropy contradicts its own claimed confidence.
#      This also mitigates regression risk from the wider alpha range.
#   2. Hashtag prior injection — explicit irony signals from tweet text.
#   3. Conflict override softened: threshold 0.80→0.85, alpha 0.90→0.85.
#      (Not removed — still valuable in extreme disagreement cases like tweet 55.)
# ═════════════════════════════════════════════════════════════════════════════

def fused_classify_v2(tweet_text, cot_text, entropy,
                      rob_tokenizer, rob_model,
                      qwen_model, qwen_tokenizer, device):
    """
    Entropy-gated fusion with hashtag injection and CoT skepticism.

    Full pipeline:
      1. RoBERTa → p_roberta
      2. Two-pass Qwen extraction → p_cot  (continuous [0,1])
      3. CoT extreme score skepticism: shrink toward 0.5 when entropy
         contradicts claimed confidence (prevents overconfident wrong CoT)
      4. Gentle clamping to [0.05, 0.95]
      5. entropy_to_alpha → base alpha
      6. Softened conflict override (threshold 0.85, override alpha 0.85)
      7. Standard fusion: p_fused = alpha*p_roberta + (1-alpha)*p_cot
      8. Hashtag prior injection (if detected, overrides step 7 result)

    Returns: (prediction, p_roberta, p_cot, alpha, p_fused, hashtag_prior)
    """
    # ── 1. RoBERTa ────────────────────────────────────────────────────────────
    _, tweet_logits = classify_tweet(tweet_text, rob_tokenizer, rob_model, device)
    tweet_probs = F.softmax(tweet_logits, dim=-1).squeeze().cpu()
    p_roberta   = tweet_probs[1].item()

    # ── 2. Qwen confidence score (two-pass) ───────────────────────────────────
    p_cot = get_cot_signal_with_fallback(cot_text, qwen_model, qwen_tokenizer, device)

    # ── 3. CoT extreme score skepticism ───────────────────────────────────────
    # When Qwen's generation entropy is moderate/high but its verdict is extreme
    # (very close to 0 or 1), it is likely overconfident. Shrink toward 0.5.
    # This prevents a wrong extreme CoT score from dominating the fusion.
    # Verified safe: in low-RoBERTa correct cases, fused still stays below 0.5.
    SKEPTICISM_ENTROPY_THRESH = 0.25   # entropy above this = non-trivial uncertainty
    SKEPTICISM_COT_THRESH     = 0.15   # p_cot this extreme is suspect under uncertainty
    if entropy > SKEPTICISM_ENTROPY_THRESH:
        if p_cot <= SKEPTICISM_COT_THRESH or p_cot >= (1 - SKEPTICISM_COT_THRESH):
            p_cot = 0.5 + (p_cot - 0.5) * 0.5   # halve distance from 0.5
            # e.g. 0.10 → 0.30,  0.95 → 0.725

    # ── 4. Gentle clamping ────────────────────────────────────────────────────
    p_cot = max(0.05, min(0.95, p_cot))

    # ── 5. Entropy-adaptive alpha ─────────────────────────────────────────────
    alpha = entropy_to_alpha(entropy)

    # ── 6. Softened conflict override ────────────────────────────────────────
    # Raised threshold (0.80→0.85) and lowered override alpha (0.90→0.85).
    # NOTE: CoT skepticism in step 3 already shrinks extreme p_cot values,
    # so this override fires less often than before — only for true extremes.
    if abs(p_roberta - p_cot) > 0.85:
        alpha = 0.85

    # ── 7. Standard fusion ────────────────────────────────────────────────────
    p_fused = alpha * p_roberta + (1 - alpha) * p_cot

    # ── 8. Hashtag prior injection ────────────────────────────────────────────
    hashtag_prior = detect_explicit_irony_signal(tweet_text)
    if hashtag_prior >= 0.85:
        # Strong signal: author explicitly labeled the tweet as ironic.
        # Drop alpha to give CoT more say, then blend hashtag prior at 40%.
        # Safety: even if both models are wrong (both say 0), p_fused = 0.352
        # which is still < 0.5, so this cannot force a wrong ironic prediction
        # when both models are confident the tweet is non-ironic.
        alpha_strong = min(alpha, 0.30)
        p_fused_base = alpha_strong * p_roberta + (1 - alpha_strong) * p_cot
        p_fused = 0.60 * p_fused_base + 0.40 * hashtag_prior
        alpha   = alpha_strong   # report the effective alpha used

    elif hashtag_prior > 0.0:
        # Weak signal: moderate blend
        p_fused = 0.75 * p_fused + 0.25 * hashtag_prior

    # ── 9. Decision ───────────────────────────────────────────────────────────
    prediction = int(p_fused >= 0.5)

    return prediction, p_roberta, p_cot, alpha, p_fused, hashtag_prior


# ═════════════════════════════════════════════════════════════════════════════
# COT COMPRESSION  (unchanged — contrastive connectors always preserved)
# ═════════════════════════════════════════════════════════════════════════════

CONTRASTIVE_CONNECTORS = {
    "but", "yet", "though", "although", "however", "despite", "while",
    "whereas", "still", "even", "never", "not", "no", "without", "barely"
}

def compress_cot_improved(original_text, gamma_dyn, critical_tokens):
    """
    Token-scored compression preserving:
      - Gradient-critical tokens     (score 1000)
      - Contrastive connectors       (score  500)
      - Non-stopword content tokens  (score   10)
      - Everything else              (score    1)
    """
    stop_words    = set(stopwords.words("english")) - CONTRASTIVE_CONNECTORS
    words         = original_text.split()
    target_length = max(5, int(len(words) * (1.0 - gamma_dyn)))

    scored_words = []
    for idx, word in enumerate(words):
        clean = word.lower().strip(".,!?\"'")
        is_critical = any(
            crit.lower() in clean for crit in critical_tokens if len(crit) >= 4
        )
        if is_critical:                                   score = 1000
        elif clean in CONTRASTIVE_CONNECTORS:             score =  500
        elif clean not in stop_words and len(clean) >= 3: score =   10
        else:                                             score =    1
        scored_words.append((idx, word, score))

    scored_words.sort(key=lambda x: x[2], reverse=True)
    kept = sorted(scored_words[:target_length], key=lambda x: x[0])
    return " ".join(w[1] for w in kept)


print("✅ All helper functions loaded (v5).")
print("   • detect_explicit_irony_signal   — NEW: hashtag/emoji/elongation detector")
print("   • extract_cot_confidence         — continuous score parser (unchanged)")
print("   • get_cot_signal_with_fallback   — two-pass pipeline (unchanged)")
print("   • classify_tweet                 — RoBERTa classifier (unchanged)")
print("   • entropy_to_alpha               — alpha_low 0.55→0.50, alpha_high 0.85→0.88")
print("   • fused_classify_v2              — v5: skepticism + hashtag prior + softened override")
print("   • compress_cot_improved          — unchanged")
# Out:
# ✅ All helper functions loaded (v5).
#    • detect_explicit_irony_signal   — NEW: hashtag/emoji/elongation detector
#    • extract_cot_confidence         — continuous score parser (unchanged)
#    • get_cot_signal_with_fallback   — two-pass pipeline (unchanged)
#    • classify_tweet                 — RoBERTa classifier (unchanged)
#    • entropy_to_alpha               — alpha_low 0.55→0.50, alpha_high 0.85→0.88
#    • fused_classify_v2              — v5: skepticism + hashtag prior + softened override
#    • compress_cot_improved          — unchanged

# %% [markdown]
# This cell loops through a few test examples. It prompts Qwen for a Chain-of-Thought, calculates the dynamic budget, extracts the gradient sensitivities, and prepares the data for the final fusion.

# %%
def generate_cot_and_analyze_v2(tweet, mode="FULL_RDS", tweet_num=""):
    num_str = f" {tweet_num}" if tweet_num else ""
    print(f"\n--- Processing Tweet{num_str}: {tweet[:60]}... ---")

    # ── Step 1: Generate CoT with structured verdict prompt ───────────────
    prompt = STRUCTURED_PROMPT.format(tweet=tweet)
    inputs = qwen_tokenizer(prompt, return_tensors="pt").to(device)

    with torch.no_grad():
        outputs = qwen_model.generate(
            **inputs,
            max_new_tokens=120,
            return_dict_in_generate=True,
            output_scores=True
        )

    generated_ids = outputs.sequences[0][inputs["input_ids"].shape[1]:]
    cot_text = qwen_tokenizer.decode(generated_ids, skip_special_tokens=True)
    print(f"  CoT Length : {len(cot_text.split())} words")

    # ── Step 2: Global Budgeter (Entropy → Dynamic Gamma) ─────────────────
    if mode in ["FULL_RDS", "ENTROPY_ONLY"]:
        logits_stack = torch.stack(outputs.scores, dim=1).squeeze(0)
        gamma_dyn, entropy = calculate_dynamic_gamma(logits_stack)
        print(f"  Entropy    : {entropy:.3f}  →  Gamma: {gamma_dyn:.3f}")
    else:
        gamma_dyn, entropy = 0.5, 0.0

    # ── Step 3: Local Guardian (Gradient Sensitivity) ─────────────────────
    if mode in ["FULL_RDS", "GRADIENT_ONLY"]:
        sensitivities = get_gradient_sensitivity(
            cot_text, rob_tokenizer, rob_model, device, target_class=1
        )
        sorted_sens = sorted(sensitivities.items(), key=lambda x: x[1], reverse=True)
        critical_tokens = [t[0] for t in sorted_sens if len(t[0]) >= 4][:5]
        print(f"  Crit.Tokens: {critical_tokens}")
    else:
        critical_tokens = []

    return {
        "tweet"          : tweet,
        "cot_text"       : cot_text,
        "entropy"        : entropy,
        "gamma_dyn"      : gamma_dyn,
        "critical_tokens": critical_tokens,
        "mode"           : mode
    }


# ════════════════════════════════════════════════════════════════════════════
# EXPLICIT IRONY SIGNAL DETECTOR
# Catches author-labeled irony signals that both RoBERTa and CoT systematically
# miss: #not, #sarcasm, #irony, emoji contrast, letter elongation.
# ════════════════════════════════════════════════════════════════════════════

# Definitive sarcasm markers — author explicitly labeling their own tweet
_STRONG_IRONY_RE = re.compile(
    r"#(not|sarcasm|sarcastic|irony|ironic|jk|justkidding|kms|killme|"
    r"killusslow|obviously|surenot|yeahright|fml|eyeroll)\b",
    re.IGNORECASE
)

# Softer signals — still meaningful but not conclusive alone
_WEAK_IRONY_RE = re.compile(
    r"#(humor|lol|smh|seriously|really|wow|sure|totally|great|wonderful)\b",
    re.IGNORECASE
)

# Positive emoji immediately followed by a negative emoji → contrast = sarcasm
_EMOJI_CONTRAST_RE = re.compile(
    r"[😊😄😀👍❤️🙂😁]\s{0,3}[|,\s]*\s{0,3}[😒😤😡😞😑🙄😔😢]"
)

# Letter elongation: "Loooovvveee", "Soooo", "Greaaat" (3+ repeated chars)
_ELONGATION_RE = re.compile(r"([a-zA-Z])\1{2,}")

def detect_explicit_irony_signal(tweet_text):
    """
    Scans tweet text for explicit, author-provided irony/sarcasm markers.

    Returns a float in [0.0, 0.88]:
      0.88  → Strong signal  (#not, #sarcasm, #irony etc.) — near-certain irony
      0–0.70 → Weak composite signal (soft hashtags + emoji contrast + elongation)
      0.0   → No explicit signal detected
    """
    # Strong signal: one match is enough — these are definitive
    if _STRONG_IRONY_RE.search(tweet_text):
        return 0.88

    # Weak signals: accumulate and cap
    score = 0.0
    if _WEAK_IRONY_RE.search(tweet_text):
        score += 0.15
    if _EMOJI_CONTRAST_RE.search(tweet_text):
        score += 0.25
    if _ELONGATION_RE.search(tweet_text):
        score += 0.12

    return min(score, 0.70)


# ════════════════════════════════════════════════════════════════════════════
# UPDATED FUSED CLASSIFY  — v4 with hashtag integration
# ════════════════════════════════════════════════════════════════════════════

def entropy_to_alpha(entropy,
                     low_thresh=0.2, high_thresh=0.5,
                     alpha_low=0.45,   # widened from 0.55 → CoT gets more weight when confident
                     alpha_high=0.90): # widened from 0.85
    """
    Maps reasoning entropy to RoBERTa weight (alpha).
      Low entropy  → Qwen was confident → trust CoT more → lower alpha
      High entropy → Qwen was uncertain → trust RoBERTa more → higher alpha
    """
    if entropy <= low_thresh:
        return alpha_low
    elif entropy >= high_thresh:
        return alpha_high
    t = (entropy - low_thresh) / (high_thresh - low_thresh)
    return alpha_low + t * (alpha_high - alpha_low)


def fused_classify_v2(tweet_text, cot_text, entropy,
                      rob_tokenizer, rob_model,
                      qwen_model, qwen_tokenizer, device):
    """
    Entropy-gated fusion of RoBERTa and Qwen with hashtag-prior injection.

    Fusion pipeline:
      1. RoBERTa → p_roberta
      2. Two-pass Qwen extraction → p_cot  (continuous score in [0,1])
      3. detect_explicit_irony_signal → hashtag_prior
      4. entropy_to_alpha → base alpha
      5. If strong hashtag signal: lower alpha to 0.30, blend prior at 40%
         If weak  hashtag signal: blend prior at 25%
         If no signal: standard entropy-gated fusion
      6. Conflict override: REMOVED (was causing errors in tweets 6, 35)

    Returns: (prediction, p_roberta, p_cot, alpha, p_fused, hashtag_prior)
    """
    # ── 1. RoBERTa probability ────────────────────────────────────────────────
    _, tweet_logits = classify_tweet(tweet_text, rob_tokenizer, rob_model, device)
    tweet_probs = F.softmax(tweet_logits, dim=-1).squeeze().cpu()
    p_roberta = tweet_probs[1].item()

    # ── 2. Qwen continuous confidence score (two-pass) ────────────────────────
    p_cot = get_cot_signal_with_fallback(
        cot_text, qwen_model, qwen_tokenizer, device
    )
    p_cot = max(0.05, min(0.95, p_cot))   # gentle clamping

    # ── 3. Explicit irony signal from tweet text ──────────────────────────────
    hashtag_prior = detect_explicit_irony_signal(tweet_text)

    # ── 4. Base entropy-gated alpha ───────────────────────────────────────────
    alpha = entropy_to_alpha(entropy)

    # ── 5. Standard fusion ────────────────────────────────────────────────────
    p_fused = alpha * p_roberta + (1 - alpha) * p_cot

    # ── 6. Hashtag-prior injection ────────────────────────────────────────────
    if hashtag_prior >= 0.85:
        # Strong signal: author explicitly labeled the tweet as sarcastic.
        # Drop alpha so CoT gets more influence, then blend in the hashtag prior.
        alpha = min(alpha, 0.30)
        p_fused_base = alpha * p_roberta + (1 - alpha) * p_cot
        p_fused = 0.60 * p_fused_base + 0.40 * hashtag_prior

    elif hashtag_prior > 0.0:
        # Weak composite signal: moderate blend
        p_fused = 0.75 * p_fused + 0.25 * hashtag_prior

    # ── 7. Final decision ─────────────────────────────────────────────────────
    prediction = int(p_fused >= 0.5)

    return prediction, p_roberta, p_cot, alpha, p_fused, hashtag_prior


# ════════════════════════════════════════════════════════════════════════════
# EXECUTION LOOP
# ════════════════════════════════════════════════════════════════════════════
CURRENT_MODE = "FULL_RDS"
NUM_SAMPLES  = len(test_data)

results_list        = []
correct_predictions = 0

print(f"   Starting RDS v2 Pipeline  [{CURRENT_MODE} mode  |  N={NUM_SAMPLES}]")
print(f"   Upgrades: hashtag prior injection + wider alpha range + conflict override removed\n")

for i in range(NUM_SAMPLES):
    sample_tweet = test_data[i]["text"]
    true_label   = test_data[i]["label"]

    result_dict = generate_cot_and_analyze_v2(sample_tweet, mode=CURRENT_MODE, tweet_num=i+1)

    compressed_text = compress_cot_improved(
        result_dict["cot_text"],
        result_dict["gamma_dyn"],
        result_dict["critical_tokens"]
    )

    prediction, p_roberta, cot_signal, alpha, p_fused, hashtag_prior = fused_classify_v2(
        sample_tweet,
        compressed_text,
        result_dict["entropy"],
        rob_tokenizer, rob_model,
        qwen_model, qwen_tokenizer,
        device
    )

    is_correct = (prediction == true_label)
    if is_correct:
        correct_predictions += 1

    # Running count: correct so far / total processed so far
    total_so_far   = i + 1
    running_acc    = (correct_predictions / total_so_far) * 100
    htag_str       = f" | HTag={hashtag_prior:.2f}" if hashtag_prior > 0.0 else ""

    print(f"  RoBERTa={p_roberta:.3f} | CoT={cot_signal:.2f} | α={alpha:.3f}"
          f"{htag_str} | Fused={p_fused:.3f} | Pred={prediction} | True={true_label}"
          f" | {'✅' if is_correct else '❌'}"
          f"  [{correct_predictions}/{total_so_far} = {running_acc:.1f}%]")

    orig_len = len(result_dict["cot_text"].split())
    comp_len = len(compressed_text.split())

    results_list.append({
        "Tweet"             : sample_tweet[:35] + "...",
        "True"              : true_label,
        "Pred"              : prediction,
        "✓?"                : "✅" if is_correct else "❌",
        "RoBERTa P(ironic)" : round(p_roberta, 3),
        "CoT Score"         : round(cot_signal, 3),
        "HTag Prior"        : round(hashtag_prior, 3),
        "α (adaptive)"      : round(alpha, 3),
        "Fused P(ironic)"   : round(p_fused, 3),
        "Entropy"           : round(result_dict["entropy"], 3),
        "Gamma"             : round(result_dict["gamma_dyn"], 3),
        "Orig Len"          : orig_len,
        "Comp Len"          : comp_len,
    })

accuracy_pct = (correct_predictions / NUM_SAMPLES) * 100
skip_ratio = sum(
    1 - r["Comp Len"] / r["Orig Len"]
    for r in results_list if r["Orig Len"] > 0
) / NUM_SAMPLES

htag_triggered = sum(1 for r in results_list if r["HTag Prior"] > 0.0)
htag_strong    = sum(1 for r in results_list if r["HTag Prior"] >= 0.85)

print(f"\n{'='*64}")
print(f"🏆 RDS v2 [{CURRENT_MODE}] ACCURACY : {accuracy_pct:.1f}%  ({correct_predictions}/{NUM_SAMPLES})")
print(f"📉 Avg Token-Skip Ratio         : {skip_ratio:.1%}")
print(f"🏷️  Hashtag detector fired       : {htag_triggered} tweets  ({htag_strong} strong signals)")
print(f"{'='*64}")

df = pd.DataFrame(results_list)
display(df)
# Out:
# 🚀 Starting RDS v2 Pipeline  [FULL_RDS mode  |  N=784]
#    Upgrades: hashtag prior injection + wider alpha range + conflict override removed
#
#
# --- Processing Tweet 1: @user Can U Help?||More conservatives needed on #TSU + get p... ---
#   CoT Length : 88 words
#   Entropy    : 0.393  →  Gamma: 0.479
#   Crit.Tokens: ['SIGN', 'introduces', 'However', 'exaggerated', 'making']
#   RoBERTa=0.303 | CoT=0.15 | α=0.739 | Fused=0.263 | Pred=0 | True=0 | ✅  [1/1 = 100.0%]
#
# --- Processing Tweet 2: Just walked in to #Starbucks and asked for a "tall blonde" H... ---
#   CoT Length : 80 words
#   Entropy    : 0.327  →  Gamma: 0.465
#   Crit.Tokens: ['Analysis', 'analyze', 'indicates', 'sarcastic', 'suggests']
#   RoBERTa=0.650 | CoT=0.85 | α=0.300 | HTag=0.88 | Fused=0.826 | Pred=1 | True=1 | ✅  [2/2 = 100.0%]
#
# --- Processing Tweet 3: #NOT GONNA WIN... ---
#   CoT Length : 95 words
#   Entropy    : 0.459  →  Gamma: 0.492
#   Crit.Tokens: ['irony', 'contrast', 'ironically', 'achieve', 'Hash']
#   RoBERTa=0.033 | CoT=0.15 | α=0.300 | HTag=0.88 | Fused=0.421 | Pred=0 | True=0 | ✅  [3/3 = 100.0%]
#
# --- Processing Tweet 4: @user He is exactly that sort of person. Weirdo!... ---
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
#   CoT Length : 85 words
#   Entropy    : 0.294  →  Gamma: 0.459
#   Crit.Tokens: ['Analysis', 'analyze', 'exaggeration', 'contrast', 'irony']
#   RoBERTa=0.209 | CoT=0.50 | α=0.591 | Fused=0.328 | Pred=0 | True=0 | ✅  [4/4 = 100.0%]
#
# --- Processing Tweet 5: So much #sarcasm at work mate 10/10 #boring 100% #dead mate ... ---
#   CoT Length : 75 words
#   Entropy    : 0.332  →  Gamma: 0.466
#   Crit.Tokens: ['Analysis', 'contradicts', 'Does', 'boring', 'exaggerated']
#   RoBERTa=0.075 | CoT=0.50 | α=0.300 | HTag=0.88 | Fused=0.575 | Pred=1 | True=1 | ✅  [5/5 = 100.0%]
#
# --- Processing Tweet 6: Corny jokes are my absolute favorite... ---
#   CoT Length : 80 words
#   Entropy    : 0.309  →  Gamma: 0.462
#   Crit.Tokens: ['####', 'Step', 'Corn', 'absolute', 'phrase']
#   RoBERTa=0.981 | CoT=0.15 | α=0.613 | Fused=0.660 | Pred=1 | True=0 | ❌  [5/6 = 83.3%]
#
# --- Processing Tweet 7: People complain about my backround pic and all I feel is lik... ---
#   CoT Length : 89 words
#   Entropy    : 0.309  →  Gamma: 0.462
#   Crit.Tokens: ['complain', 'People', 'contradiction', 'picture', 'about']
#   RoBERTa=0.269 | CoT=0.15 | α=0.300 | HTag=0.88 | Fused=0.463 | Pred=0 | True=1 | ❌  [5/7 = 71.4%]
#
# --- Processing Tweet 8: @user @user Darn, my sock joke needs fixing?... ---
#   CoT Length : 87 words
#   Entropy    : 0.316  →  Gamma: 0.463
#   Crit.Tokens: ['Does', 'Analysis', 'indicates', 'tone', 'analyze']
#   RoBERTa=0.090 | CoT=0.15 | α=0.624 | Fused=0.112 | Pred=0 | True=0 | ✅  [6/8 = 75.0%]
#
# --- Processing Tweet 9: if Christian expects Fifa to sleep in my bed with me tonight... ---
#   CoT Length : 95 words
#   Entropy    : 0.505  →  Gamma: 0.501
#   Crit.Tokens: ['Christian', 'likely', 'contradiction', 'implies', 'entity']
#   RoBERTa=0.031 | CoT=0.15 | α=0.900 | Fused=0.043 | Pred=0 | True=0 | ✅  [7/9 = 77.8%]
#
# --- Processing Tweet 10: People who tell people with anxiety to "just stop worrying a... ---
#   CoT Length : 87 words
#   Entropy    : 0.360  →  Gamma: 0.472
#   Crit.Tokens: ['Step', 'phrase', 'suggests', 'educ', 'tone']
#   RoBERTa=0.866 | CoT=0.85 | α=0.300 | HTag=0.88 | Fused=0.865 | Pred=1 | True=1 | ✅  [8/10 = 80.0%]
#
# --- Processing Tweet 11: Most important thing I've learned in school... ---
#   CoT Length : 85 words
#   Entropy    : 0.307  →  Gamma: 0.461
#   Crit.Tokens: ['straightforward', 'hasht', 'beyond', 'Does', 'learning']
#   RoBERTa=0.910 | CoT=0.15 | α=0.610 | Fused=0.613 | Pred=1 | True=0 | ❌  [8/11 = 72.7%]
#
# --- Processing Tweet 12: #OrionLaunch underway - yeah! #Orion... ---
#   CoT Length : 84 words
#   Entropy    : 0.326  →  Gamma: 0.465
#   Crit.Tokens: ['indicator', 'approval', 'However', 'tone', 'enthusiastic']
#   RoBERTa=0.359 | CoT=0.15 | α=0.639 | Fused=0.284 | Pred=0 | True=0 | ✅  [9/12 = 75.0%]
#
# --- Processing Tweet 13: I love context and large ensemble Fridays!!!!! Der my most f... ---
#   CoT Length : 75 words
#   Entropy    : 0.279  →  Gamma: 0.456
#   Crit.Tokens: ['ensemble', 'Positive', 'suggests', 'Fridays', 'often']
#   RoBERTa=0.904 | CoT=0.45 | α=0.300 | HTag=0.88 | Fused=0.704 | Pred=1 | True=1 | ✅  [10/13 = 76.9%]
#
# --- Processing Tweet 14: Oh boy... @user in the house. Warm up the DJ booth @user... ---
#   CoT Length : 93 words
#   Entropy    : 0.408  →  Gamma: 0.482
#   Crit.Tokens: ['Contrast', 'distress', 'suggests', 'Tone', 'booth']
#   RoBERTa=0.073 | CoT=0.15 | α=0.763 | Fused=0.092 | Pred=0 | True=0 | ✅  [11/14 = 78.6%]
#
# --- Processing Tweet 15: LIAR, i've never denied the 532 murders in Chicago in 2012 @... ---
#   CoT Length : 77 words
#   Entropy    : 0.289  →  Gamma: 0.458
#   Crit.Tokens: ['contradicts', 'criteria', 'SIGN', 'Situation', 'iguous']
#   RoBERTa=0.059 | CoT=0.15 | α=0.584 | Fused=0.097 | Pred=0 | True=0 | ✅  [12/15 = 80.0%]
#
# --- Processing Tweet 16: Always classy, never trashy and just a little sassy.... ---
#   CoT Length : 84 words
#   Entropy    : 0.415  →  Gamma: 0.483
#   Crit.Tokens: ['irony', 'However', 'Tone', 'Always', 'sophistication']
#   RoBERTa=0.090 | CoT=0.50 | α=0.772 | Fused=0.184 | Pred=0 | True=0 | ✅  [13/16 = 81.2%]
#
# --- Processing Tweet 17: you believe you can say something, provide no proof and its ... ---
#   CoT Length : 80 words
#   Entropy    : 0.302  →  Gamma: 0.461
#   Crit.Tokens: ['irony', 'Tone', 'Analysis', 'Positive', 'extreme']
#   RoBERTa=0.116 | CoT=0.25 | α=0.604 | Fused=0.169 | Pred=0 | True=0 | ✅  [14/17 = 82.4%]
#
# --- Processing Tweet 18: @user #Not #Long To Go #Before #MainStream #Media #Pitch. #S... ---
#   CoT Length : 63 words
#   Entropy    : 0.192  →  Gamma: 0.439
#   Crit.Tokens: ['irony', 'refusal', 'gery', 'otype', 'Phil']
#   RoBERTa=0.124 | CoT=0.15 | α=0.300 | HTag=0.88 | Fused=0.437 | Pred=0 | True=0 | ✅  [15/18 = 83.3%]
#
# --- Processing Tweet 19: @user Re: Jamie Grace has Tourette's? Thanks for sharing. I'... ---
#   CoT Length : 94 words
#   Entropy    : 0.317  →  Gamma: 0.463
#   Crit.Tokens: ['gratitude', 'sincere', 'expresses', 'expressing', 'informative']
#   RoBERTa=0.050 | CoT=0.15 | α=0.625 | Fused=0.088 | Pred=0 | True=0 | ✅  [16/19 = 84.2%]
#
# --- Processing Tweet 20: @user Guess they didn't get the memo reg non-nuclear Baltic ... ---
#   CoT Length : 77 words
#   Entropy    : 0.352  →  Gamma: 0.471
#   Crit.Tokens: ['nuclear', 'intended', 'straightforward', 'factual', 'expressing']
#   RoBERTa=0.486 | CoT=0.43 | α=0.300 | HTag=0.88 | Fused=0.620 | Pred=1 | True=1 | ✅  [17/20 = 85.0%]
#
# --- Processing Tweet 21: Exam na jud. Merry christmas. ||#Sarcasm|#KillUsSlowly... ---
#   CoT Length : 91 words
#   Entropy    : 0.462  →  Gamma: 0.492
#   Crit.Tokens: ['Step', 'tones', 'contradictory', 'Analy', 'mocking']
#   RoBERTa=0.155 | CoT=0.50 | α=0.300 | HTag=0.88 | Fused=0.590 | Pred=1 | True=1 | ✅  [18/21 = 85.7%]
#
# --- Processing Tweet 22: The definition of #IRONY would be if a 77-year-old rapper we... ---
#   CoT Length : 84 words
#   Entropy    : 0.205  →  Gamma: 0.441
#   Crit.Tokens: ['likely', 'irony', 'Maybe', 'mainstream', 'scenario']
#   RoBERTa=0.815 | CoT=0.62 | α=0.300 | HTag=0.88 | Fused=0.758 | Pred=1 | True=1 | ✅  [19/22 = 86.4%]
#
# --- Processing Tweet 23: Pretty excited about how you gave up on me. File Under: #sar... ---
#   CoT Length : 84 words
#   Entropy    : 0.271  →  Gamma: 0.454
#   Crit.Tokens: ['####', 'File', 'Tone', 'Analysis', 'contradiction']
#   RoBERTa=0.508 | CoT=0.15 | α=0.300 | HTag=0.88 | Fused=0.507 | Pred=1 | True=1 | ✅  [20/23 = 87.0%]
#
# --- Processing Tweet 24: Who told the #hipsters that #irony was a thing of the Clinto... ---
#   CoT Length : 84 words
#   Entropy    : 0.297  →  Gamma: 0.460
#   Crit.Tokens: ['Does', 'phrase', 'suggest', 'tone', 'analyze']
#   RoBERTa=0.348 | CoT=0.38 | α=0.300 | HTag=0.88 | Fused=0.576 | Pred=1 | True=1 | ✅  [21/24 = 87.5%]
#
# --- Processing Tweet 25: @user u know that. How u doing??... ---
#   CoT Length : 85 words
#   Entropy    : 0.261  →  Gamma: 0.453
#   Crit.Tokens: ['greeting', 'somewhat', 'acknowledgment', 'contradiction', 'Does']
#   RoBERTa=0.026 | CoT=0.15 | α=0.542 | Fused=0.083 | Pred=0 | True=0 | ✅  [22/25 = 88.0%]
#
# --- Processing Tweet 26: @user hmm... let me think about that #sarcasm... ---
#   CoT Length : 79 words
#   Entropy    : 0.269  →  Gamma: 0.454
#   Crit.Tokens: ['####', 'indicates', 'thoughtful', 'pause', 'hesitation']
#   RoBERTa=0.088 | CoT=0.85 | α=0.300 | HTag=0.88 | Fused=0.725 | Pred=1 | True=1 | ✅  [23/26 = 88.5%]
#
# --- Processing Tweet 27: If you wanna look like a badass, have drama on social media ... ---
#   CoT Length : 86 words
#   Entropy    : 0.310  →  Gamma: 0.462
#   Crit.Tokens: ['contradiction', 'However', 'creates', 'signals', 'Tone']
#   RoBERTa=0.703 | CoT=0.50 | α=0.300 | HTag=0.88 | Fused=0.689 | Pred=1 | True=1 | ✅  [24/27 = 88.9%]
#
# --- Processing Tweet 28: How dare Charles Barkley have an intelligent conversation ab... ---
#   CoT Length : 84 words
#   Entropy    : 0.306  →  Gamma: 0.461
#   Crit.Tokens: ['contradictory', 'tone', 'implies', 'contradict', 'SIGN']
#   RoBERTa=0.355 | CoT=0.15 | α=0.300 | HTag=0.88 | Fused=0.479 | Pred=0 | True=1 | ❌  [24/28 = 85.7%]
#
# --- Processing Tweet 29: @user I think the general rule is, if it's open all night, p... ---
#   CoT Length : 95 words
#   Entropy    : 0.320  →  Gamma: 0.464
#   Crit.Tokens: ['contradictory', '####', 'typically', 'Analysis', 'However']
#   RoBERTa=0.055 | CoT=0.15 | α=0.630 | Fused=0.090 | Pred=0 | True=0 | ✅  [25/29 = 86.2%]
#
# --- Processing Tweet 30: Natalie Prass - Bird of Prey: via @user... ---
#   CoT Length : 86 words
#   Entropy    : 0.240  →  Gamma: 0.448
#   Crit.Tokens: ['Step', '####', 'seems', 'neutral', 'contradiction']
#   RoBERTa=0.029 | CoT=0.15 | α=0.510 | Fused=0.088 | Pred=0 | True=0 | ✅  [26/30 = 86.7%]
#
# --- Processing Tweet 31: Nooooooooooo again it's on!!! #PickANewSong #CantStandIt... ---
#   CoT Length : 77 words
#   Entropy    : 0.279  →  Gamma: 0.456
#   Crit.Tokens: ['subjected', 'Tone', 'contradiction', 'implies', 'Analysis']
#   RoBERTa=0.266 | CoT=0.25 | α=0.568 | HTag=0.12 | Fused=0.224 | Pred=0 | True=0 | ✅  [27/31 = 87.1%]
#
# --- Processing Tweet 32: Being a hipster now is so mainstream. Oh, the irony. #hipste... ---
#   CoT Length : 73 words
#   Entropy    : 0.278  →  Gamma: 0.456
#   Crit.Tokens: ['indicates', 'definitively', 'determine', 'However', 'tone']
#   RoBERTa=0.922 | CoT=0.85 | α=0.300 | HTag=0.88 | Fused=0.875 | Pred=1 | True=1 | ✅  [28/32 = 87.5%]
#
# --- Processing Tweet 33: @user exactly and we are fighting like animals... ---
#   CoT Length : 78 words
#   Entropy    : 0.314  →  Gamma: 0.463
#   Crit.Tokens: ['Analysis', 'irony', 'straightforward', 'analyze', 'language']
#   RoBERTa=0.351 | CoT=0.15 | α=0.621 | Fused=0.275 | Pred=0 | True=0 | ✅  [29/33 = 87.9%]
#
# --- Processing Tweet 34: #TeenAnalCasting #Top Top 50 Christian Songs For 2012... ---
#   CoT Length : 80 words
#   Entropy    : 0.374  →  Gamma: 0.475
#   Crit.Tokens: ['Christian', 'Songs', 'contradicts', 'Tone', 'signal']
#   RoBERTa=0.111 | CoT=0.50 | α=0.711 | Fused=0.224 | Pred=0 | True=0 | ✅  [30/34 = 88.2%]
#
# --- Processing Tweet 35: The girls on #SororitySisters thought they'd get rich and fa... ---
#   CoT Length : 86 words
#   Entropy    : 0.343  →  Gamma: 0.469
#   Crit.Tokens: ['Tone', 'However', '..."', 'ironic', 'mockery']
#   RoBERTa=0.865 | CoT=0.15 | α=0.665 | Fused=0.626 | Pred=1 | True=0 | ❌  [30/35 = 85.7%]
#
# --- Processing Tweet 36: Speaking of #country #music albums, anyone else think #Sundo... ---
#   CoT Length : 79 words
#   Entropy    : 0.357  →  Gamma: 0.472
#   Crit.Tokens: ['implies', 'subjective', 'Analysis', 'sentiment', 'indicate']
#   RoBERTa=0.045 | CoT=0.85 | α=0.686 | Fused=0.298 | Pred=0 | True=0 | ✅  [31/36 = 86.1%]
#
# --- Processing Tweet 37: #TeenAnalCasting #Sex Sex and the City 2 Movie Casting Audit... ---
#   CoT Length : 82 words
#   Entropy    : 0.411  →  Gamma: 0.482
#   Crit.Tokens: ['contradiction', 'improbable', 'world', 'signals', 'Meaning']
#   RoBERTa=0.170 | CoT=0.15 | α=0.767 | Fused=0.166 | Pred=0 | True=0 | ✅  [32/37 = 86.5%]
#
# --- Processing Tweet 38: season 6 episode 3 carries outfit, simple & chic 👌... ---
#   CoT Length : 81 words
#   Entropy    : 0.368  →  Gamma: 0.474
#   Crit.Tokens: ['suggests', 'Analysis', 'Tone', 'necessarily', 'analyze']
#   RoBERTa=0.089 | CoT=0.25 | α=0.702 | Fused=0.137 | Pred=0 | True=0 | ✅  [33/38 = 86.8%]
#
# --- Processing Tweet 39: Well got the truck buried today perfect way to start a rainy... ---
#   CoT Length : 80 words
#   Entropy    : 0.372  →  Gamma: 0.474
#   Crit.Tokens: ['irony', 'Positive', 'implies', 'agger', 'signal']
#   RoBERTa=0.566 | CoT=0.62 | α=0.300 | HTag=0.88 | Fused=0.713 | Pred=1 | True=1 | ✅  [34/39 = 87.2%]
#
# --- Processing Tweet 40: On the train and surrounded by posh people, I'm so at home! ... ---
#   CoT Length : 87 words
#   Entropy    : 0.368  →  Gamma: 0.474
#   Crit.Tokens: ['Conclusion', 'Analysis', 'contrasts', 'implies', 'irony']
#   RoBERTa=0.665 | CoT=0.32 | α=0.300 | HTag=0.88 | Fused=0.608 | Pred=1 | True=1 | ✅  [35/40 = 87.5%]
#
# --- Processing Tweet 41: Stupid #doctors visits is gonna bury me!! Now that's #irony... ---
#   CoT Length : 75 words
#   Entropy    : 0.323  →  Gamma: 0.465
#   Crit.Tokens: ['Tone', 'contradicts', 'Positive', 'bury', 'checks']
#   RoBERTa=0.549 | CoT=0.15 | α=0.300 | HTag=0.88 | Fused=0.514 | Pred=1 | True=1 | ✅  [36/41 = 87.8%]
#
# --- Processing Tweet 42: Love the way @user says fault from last night will be fixed ... ---
#   CoT Length : 75 words
#   Entropy    : 0.234  →  Gamma: 0.447
#   Crit.Tokens: ['Tone', 'mocking', 'contradiction', 'expresses', 'rast']
#   RoBERTa=0.961 | CoT=0.15 | α=0.300 | HTag=0.88 | Fused=0.588 | Pred=1 | True=1 | ✅  [37/42 = 88.1%]
#
# --- Processing Tweet 43: Planning a vacation instead of studying.... My priorities ar... ---
#   CoT Length : 90 words
#   Entropy    : 0.465  →  Gamma: 0.493
#   Crit.Tokens: ['Analysis', 'priorities', 'line', 'Tone', 'However']
#   RoBERTa=0.624 | CoT=0.25 | α=0.300 | HTag=0.88 | Fused=0.569 | Pred=1 | True=1 | ✅  [38/43 = 88.4%]
#
# --- Processing Tweet 44: Dan said he's going to have a sign for me at the airport whe... ---
#   CoT Length : 95 words
#   Entropy    : 0.398  →  Gamma: 0.480
#   Crit.Tokens: ['contradiction', 'analyze', 'likely', 'joking', 'intended']
#   RoBERTa=0.362 | CoT=0.15 | α=0.746 | Fused=0.309 | Pred=0 | True=0 | ✅  [39/44 = 88.6%]
#
# --- Processing Tweet 45: You decide to go on vacation without me sleep? Reaaaal nice.... ---
#   CoT Length : 80 words
#   Entropy    : 0.312  →  Gamma: 0.462
#   Crit.Tokens: ['ironic', 'nice', 'speaker', 'analysis', 'clearly']
#   RoBERTa=0.188 | CoT=0.15 | α=0.300 | HTag=0.88 | Fused=0.449 | Pred=0 | True=1 | ❌  [39/45 = 86.7%]
#
# --- Processing Tweet 46: @user No sugar during christmas time? :(... ---
#   CoT Length : 89 words
#   Entropy    : 0.351  →  Gamma: 0.470
#   Crit.Tokens: ['signals', 'phrase', 'asked', 'exaggerated', 'time']
#   RoBERTa=0.125 | CoT=0.15 | α=0.676 | Fused=0.133 | Pred=0 | True=0 | ✅  [40/46 = 87.0%]
#
# --- Processing Tweet 47: Can't wait to have an afternoon schedule because of you. It'... ---
#   CoT Length : 83 words
#   Entropy    : 0.284  →  Gamma: 0.457
#   Crit.Tokens: ['####', 'Analysis', 'However', 'indicates', 'tone']
#   RoBERTa=0.970 | CoT=0.15 | α=0.300 | HTag=0.88 | Fused=0.590 | Pred=1 | True=1 | ✅  [41/47 = 87.2%]
#
# --- Processing Tweet 48: @user 180 dead on 26/11 n more than 10k our ppl killed in te... ---
#   CoT Length : 89 words
#   Entropy    : 0.394  →  Gamma: 0.479
#   Crit.Tokens: ['irony', 'indicates', 'intending', 'signals', 'contrasts']
#   RoBERTa=0.286 | CoT=0.85 | α=0.300 | HTag=0.88 | Fused=0.760 | Pred=1 | True=1 | ✅  [42/48 = 87.5%]
#
# --- Processing Tweet 49: the ONLY time a crime becomes a federal crime @user @user @u... ---
#   CoT Length : 87 words
#   Entropy    : 0.379  →  Gamma: 0.476
#   Crit.Tokens: ['exaggerated', 'suggests', 'Analysis', 'Tone', 'contradiction']
#   RoBERTa=0.090 | CoT=0.50 | α=0.718 | Fused=0.206 | Pred=0 | True=0 | ✅  [43/49 = 87.8%]
#
# --- Processing Tweet 50: this music is for the people and not for the money. peace an... ---
#   CoT Length : 84 words
#   Entropy    : 0.313  →  Gamma: 0.463
#   Crit.Tokens: ['sentiment', 'irony', 'expressing', 'suggests', 'KING']
#   RoBERTa=0.101 | CoT=0.85 | α=0.619 | Fused=0.386 | Pred=0 | True=0 | ✅  [44/50 = 88.0%]
#
# --- Processing Tweet 51: Rangers league game with Alloa moved because of the Petrofac... ---
#   CoT Length : 90 words
#   Entropy    : 0.381  →  Gamma: 0.476
#   Crit.Tokens: ['contrast', 'signal', 'situation', 'Situation', 'Meaning']
#   RoBERTa=0.565 | CoT=0.15 | α=0.300 | HTag=0.88 | Fused=0.517 | Pred=1 | True=1 | ✅  [45/51 = 88.2%]
#
# --- Processing Tweet 52: How to Find a Life Coach (& the questions you need to ask be... ---
#   CoT Length : 86 words
#   Entropy    : 0.413  →  Gamma: 0.483
#   Crit.Tokens: ['Tone', 'Analysis', 'presented', 'uses', 'coach']
#   RoBERTa=0.033 | CoT=0.15 | α=0.770 | Fused=0.060 | Pred=0 | True=0 | ✅  [46/52 = 88.5%]
#
# --- Processing Tweet 53: I wonder what was the holiday rituals for true Africans... ---
#   CoT Length : 73 words
#   Entropy    : 0.411  →  Gamma: 0.482
#   Crit.Tokens: ['tradition', 'However', 'potentially', 'contentious', 'suggests']
#   RoBERTa=0.209 | CoT=0.15 | α=0.767 | Fused=0.195 | Pred=0 | True=0 | ✅  [47/53 = 88.7%]
#
# --- Processing Tweet 54: Been at the ER now since 10... #yay #not... ---
#   CoT Length : 94 words
#   Entropy    : 0.439  →  Gamma: 0.488
#   Crit.Tokens: ['irony', 'intent', 'ironic', 'indicator', 'contradicts']
#   RoBERTa=0.344 | CoT=0.50 | α=0.300 | HTag=0.88 | Fused=0.624 | Pred=1 | True=1 | ✅  [48/54 = 88.9%]
#
# --- Processing Tweet 55: @user Suhs been clean for 2 years and has only been in the l... ---
#   CoT Length : 88 words
#   Entropy    : 0.206  →  Gamma: 0.442
#   Crit.Tokens: ['suggests', 'biased', 'SIGN', 'Analysis', 'Meaning']
#   RoBERTa=0.041 | CoT=0.15 | α=0.300 | HTag=0.88 | Fused=0.422 | Pred=0 | True=0 | ✅  [49/55 = 89.1%]
#
# --- Processing Tweet 56: @user @user thank you studs for perfecting and teaching my b... ---
#   CoT Length : 75 words
#   Entropy    : 0.257  →  Gamma: 0.452
#   Crit.Tokens: ['irony', '####', 'indicate', 'Analysis', 'However']
#   RoBERTa=0.643 | CoT=0.57 | α=0.535 | Fused=0.609 | Pred=1 | True=0 | ❌  [49/56 = 87.5%]
#
# --- Processing Tweet 57: Haley approves of her new hammock 🐭 #ratsofinstagram... ---
#   CoT Length : 86 words
#   Entropy    : 0.370  →  Gamma: 0.474
#   Crit.Tokens: ['Haley', 'agger', 'Tone', 'approve', 'Reality']
#   RoBERTa=0.187 | CoT=0.25 | α=0.705 | Fused=0.205 | Pred=0 | True=0 | ✅  [50/57 = 87.7%]
#
# --- Processing Tweet 58: 30 years on, people still haven't got justice they deserve. ... ---
#   CoT Length : 83 words
#   Entropy    : 0.224  →  Gamma: 0.445
#   Crit.Tokens: ['mocking', 'implies', 'SIGN', 'Does', 'However']
#   RoBERTa=0.915 | CoT=0.15 | α=0.300 | HTag=0.88 | Fused=0.580 | Pred=1 | True=1 | ✅  [51/58 = 87.9%]
#
# --- Processing Tweet 59: Pips who drop out of school n have Kirya as 'eir role model ... ---
#   CoT Length : 79 words
#   Entropy    : 0.193  →  Gamma: 0.439
#   Crit.Tokens: ['####', 'Step', 'mentions', 'appears', 'Analysis']
#   RoBERTa=0.289 | CoT=0.15 | α=0.300 | HTag=0.88 | Fused=0.467 | Pred=0 | True=0 | ✅  [52/59 = 88.1%]
#
# --- Processing Tweet 60: Free Pets and Animals Books #freebiebookdownload #Pets... ---
#   CoT Length : 85 words
#   Entropy    : 0.248  →  Gamma: 0.450
#   Crit.Tokens: ['download', '####', 'Analysis', 'tone', 'Tone']
#   RoBERTa=0.155 | CoT=0.29 | α=0.522 | Fused=0.219 | Pred=0 | True=0 | ✅  [53/60 = 88.3%]
#
# --- Processing Tweet 61: @user There will be no next employer in NFL for Trestman. He... ---
#   CoT Length : 79 words
#   Entropy    : 0.325  →  Gamma: 0.465
#   Crit.Tokens: ['Tone', 'notation', 'However', 'Meaning', 'signals']
#   RoBERTa=0.081 | CoT=0.50 | α=0.637 | Fused=0.233 | Pred=0 | True=0 | ✅  [54/61 = 88.5%]
#
# --- Processing Tweet 62: Loooovvveeeeeee when my phone gets wiped -.- #not... ---
#   CoT Length : 86 words
#   Entropy    : 0.395  →  Gamma: 0.479
#   Crit.Tokens: ['####', 'factual', 'stating', 'user', 'statement']
#   RoBERTa=0.306 | CoT=0.25 | α=0.300 | HTag=0.88 | Fused=0.512 | Pred=1 | True=1 | ✅  [55/62 = 88.7%]
#
# --- Processing Tweet 63: Painting all cops with a broad brush because of the actions ... ---
#   CoT Length : 101 words
#   Entropy    : 0.390  →  Gamma: 0.478
#   Crit.Tokens: ['Analysis', 'contradiction', 'racists', 'However', 'which']
#   RoBERTa=0.861 | CoT=0.25 | α=0.300 | HTag=0.88 | Fused=0.612 | Pred=1 | True=1 | ✅  [56/63 = 88.9%]
#
# --- Processing Tweet 64: Don't know if I can handle this crazy 11-2 shift. It's so lo... ---
#   CoT Length : 90 words
#   Entropy    : 0.295  →  Gamma: 0.459
#   Crit.Tokens: ['shift', 'contrast', 'There', 'length', 'described']
#   RoBERTa=0.084 | CoT=0.15 | α=0.300 | HTag=0.88 | Fused=0.430 | Pred=0 | True=1 | ❌  [56/64 = 87.5%]
#
# --- Processing Tweet 65: I just love being ignored😊|#not😒... ---
#   CoT Length : 82 words
#   Entropy    : 0.300  →  Gamma: 0.460
#   Crit.Tokens: ['Analysis', 'contradiction', 'exaggerated', 'Does', 'suggests']
#   RoBERTa=0.180 | CoT=0.25 | α=0.300 | HTag=0.88 | Fused=0.489 | Pred=0 | True=1 | ❌  [56/65 = 86.2%]
#
# --- Processing Tweet 66: #Irony RT @user If you're going to give someone a scathing, ... ---
#   CoT Length : 80 words
#   Entropy    : 0.308  →  Gamma: 0.462
#   Crit.Tokens: ['signals', 'hashtag', 'Iron', 'Tone', 'phrase']
#   RoBERTa=0.295 | CoT=0.15 | α=0.300 | HTag=0.88 | Fused=0.468 | Pred=0 | True=1 | ❌  [56/66 = 84.8%]
#
# --- Processing Tweet 67: Produce Mobile Apps #not... ---
#   CoT Length : 86 words
#   Entropy    : 0.326  →  Gamma: 0.465
#   Crit.Tokens: ['####', 'Analysis', 'speaker', 'producing', 'Cont']
#   RoBERTa=0.319 | CoT=0.15 | α=0.300 | HTag=0.88 | Fused=0.472 | Pred=0 | True=1 | ❌  [56/67 = 83.6%]
#
# --- Processing Tweet 68: Decide that you want it more than you are afraid of it. -Bil... ---
#   CoT Length : 82 words
#   Entropy    : 0.337  →  Gamma: 0.468
#   Crit.Tokens: ['contradiction', 'Tone', 'quote', 'tags', 'typically']
#   RoBERTa=0.077 | CoT=0.85 | α=0.300 | HTag=0.88 | Fused=0.723 | Pred=1 | True=1 | ✅  [57/68 = 83.8%]
#
# --- Processing Tweet 69: Finally finished the first season of #VeronicaMars. Move ove... ---
#   CoT Length : 81 words
#   Entropy    : 0.270  →  Gamma: 0.454
#   Crit.Tokens: ['ultimate', 'sheriff', 'However', 'suggests', 'Analysis']
#   RoBERTa=0.103 | CoT=0.15 | α=0.555 | Fused=0.124 | Pred=0 | True=0 | ✅  [58/69 = 84.1%]
#
# --- Processing Tweet 70: Merry Christmas to all those soldiers out there that couldn'... ---
#   CoT Length : 83 words
#   Entropy    : 0.360  →  Gamma: 0.472
#   Crit.Tokens: ['elements', 'generally', 'Meaning', 'signals', 'tags']
#   RoBERTa=0.041 | CoT=0.15 | α=0.690 | Fused=0.074 | Pred=0 | True=0 | ✅  [59/70 = 84.3%]
#
# --- Processing Tweet 71: About as relevant as Michael Sam and Jason Collins. RT @user... ---
#   CoT Length : 95 words
#   Entropy    : 0.360  →  Gamma: 0.472
#   Crit.Tokens: ['####', 'Step', 'Analysis', 'signals', 'athletes']
#   RoBERTa=0.788 | CoT=0.15 | α=0.690 | Fused=0.590 | Pred=1 | True=0 | ❌  [59/71 = 83.1%]
#
# --- Processing Tweet 72: Getting Final Jeopardy correct on Kids Jeopardy boosts my se... ---
#   CoT Length : 84 words
#   Entropy    : 0.309  →  Gamma: 0.462
#   Crit.Tokens: ['Situation', 'situation', 'minor', 'contradiction', 'especially']
#   RoBERTa=0.966 | CoT=0.15 | α=0.614 | Fused=0.651 | Pred=1 | True=0 | ❌  [59/72 = 81.9%]
#
# --- Processing Tweet 73: itsfunny bc people think im quiet|but im just listening toev... ---
#   CoT Length : 82 words
#   Entropy    : 0.281  →  Gamma: 0.456
#   Crit.Tokens: ['####', 'subsequent', 'This', 'weaknesses', 'suggest']
#   RoBERTa=0.093 | CoT=0.50 | α=0.300 | HTag=0.88 | Fused=0.579 | Pred=1 | True=1 | ✅  [60/73 = 82.2%]
#
# --- Processing Tweet 74: Woke Up , showered , made a lunch and got ready for work onl... ---
#   CoT Length : 96 words
#   Entropy    : 0.313  →  Gamma: 0.463
#   Crit.Tokens: ['However', 'Does', 'describes', 'actions', 'contradicts']
#   RoBERTa=0.603 | CoT=0.15 | α=0.620 | Fused=0.431 | Pred=0 | True=0 | ✅  [61/74 = 82.4%]
#
# --- Processing Tweet 75: @user @user @user @user @user How many of those jobs earn #m... ---
#   CoT Length : 81 words
#   Entropy    : 0.332  →  Gamma: 0.467
#   Crit.Tokens: ['somewhat', 'deliberate', 'indicate', 'Tone', 'Analysis']
#   RoBERTa=0.096 | CoT=0.15 | α=0.649 | Fused=0.115 | Pred=0 | True=0 | ✅  [62/75 = 82.7%]
#
# --- Processing Tweet 76: I reckon straight women fancy victoria secret models more th... ---
#   CoT Length : 86 words
#   Entropy    : 0.280  →  Gamma: 0.456
#   Crit.Tokens: ['reck', 'Analysis', 'Step', 'fancy', 'exaggerated']
#   RoBERTa=0.879 | CoT=0.85 | α=0.300 | HTag=0.88 | Fused=0.867 | Pred=1 | True=1 | ✅  [63/76 = 82.9%]
#
# --- Processing Tweet 77: Incredible insight on the @user #bornrisky campaign: #ampute... ---
#   CoT Length : 72 words
#   Entropy    : 0.284  →  Gamma: 0.457
#   Crit.Tokens: ['However', 'irony', 'neutral', 'hasht', 'SIGN']
#   RoBERTa=0.311 | CoT=0.85 | α=0.576 | Fused=0.540 | Pred=1 | True=0 | ❌  [63/77 = 81.8%]
#
# --- Processing Tweet 78: Love #hiphop mix tapes or have a mixtape to promote check ou... ---
#   CoT Length : 81 words
#   Entropy    : 0.405  →  Gamma: 0.481
#   Crit.Tokens: ['suggests', 'Tone', 'However', 'ironic', 'analyze']
#   RoBERTa=0.057 | CoT=0.65 | α=0.757 | Fused=0.201 | Pred=0 | True=0 | ✅  [64/78 = 82.1%]
#
# --- Processing Tweet 79: Extended cut "NICHA" #trailer #spoof #film #dramatic #action... ---
#   CoT Length : 79 words
#   Entropy    : 0.412  →  Gamma: 0.482
#   Crit.Tokens: ['parody', '2014', 'contradiction', 'Tone', 'signals']
#   RoBERTa=0.210 | CoT=0.15 | α=0.768 | Fused=0.196 | Pred=0 | True=0 | ✅  [65/79 = 82.3%]
#
# --- Processing Tweet 80: @user Stunning work. #british #textiles #footwear #madeinbri... ---
#   CoT Length : 74 words
#   Entropy    : 0.309  →  Gamma: 0.462
#   Crit.Tokens: ['generally', 'praises', 'Does', 'clone', 'indicates']
#   RoBERTa=0.378 | CoT=0.38 | α=0.300 | HTag=0.88 | Fused=0.581 | Pred=1 | True=0 | ❌  [65/80 = 81.2%]
#
# --- Processing Tweet 81: @user @user Sent it but too slow. I had already posted.... ---
#   CoT Length : 92 words
#   Entropy    : 0.310  →  Gamma: 0.462
#   Crit.Tokens: ['####', 'straightforward', 'statement', 'inherently', 'Does']
#   RoBERTa=0.046 | CoT=0.15 | α=0.615 | Fused=0.086 | Pred=0 | True=0 | ✅  [66/81 = 81.5%]
#
# --- Processing Tweet 82: #FEMALECONDOM #anally #vaginally #prevent STD's/HIV/pregnanc... ---
#   CoT Length : 82 words
#   Entropy    : 0.383  →  Gamma: 0.477
#   Crit.Tokens: ['Tone', 'expressing', 'Meaning', 'tight', 'suggests']
#   RoBERTa=0.160 | CoT=0.57 | α=0.300 | HTag=0.88 | Fused=0.620 | Pred=1 | True=0 | ❌  [66/82 = 80.5%]
#
# --- Processing Tweet 83: Little cutie #Chico #Dog #Doggy #Puppy #Sweet #Cute #UK #Bla... ---
#   CoT Length : 81 words
#   Entropy    : 0.270  →  Gamma: 0.454
#   Crit.Tokens: ['irony', 'determine', 'signals', 'tone', 'suggest']
#   RoBERTa=0.092 | CoT=0.85 | α=0.300 | HTag=0.88 | Fused=0.725 | Pred=1 | True=0 | ❌  [66/83 = 79.5%]
#
# --- Processing Tweet 84: @user Niagra Falls tho... Really? #irony #LOL... ---
#   CoT Length : 82 words
#   Entropy    : 0.420  →  Gamma: 0.484
#   Crit.Tokens: ['####', 'Tone', 'agger', 'unrealistic', 'SIGN']
#   RoBERTa=0.217 | CoT=0.85 | α=0.300 | HTag=0.88 | Fused=0.748 | Pred=1 | True=1 | ✅  [67/84 = 79.8%]
#
# --- Processing Tweet 85: If we win against Poland and Scotland, does that put us 65th... ---
#   CoT Length : 89 words
#   Entropy    : 0.453  →  Gamma: 0.491
#   Crit.Tokens: ['However', 'unrealistic', 'Scotland', 'expressing', 'excitement']
#   RoBERTa=0.114 | CoT=0.15 | α=0.300 | HTag=0.88 | Fused=0.436 | Pred=0 | True=1 | ❌  [67/85 = 78.8%]
#
# --- Processing Tweet 86: #Myanmar #men #plead #not #guilty to #murder of #British #to... ---
#   CoT Length : 90 words
#   Entropy    : 0.491  →  Gamma: 0.498
#   Crit.Tokens: ['British', 'irony', 'Analy', 'indicates', 'mentions']
#   RoBERTa=0.209 | CoT=0.15 | α=0.300 | HTag=0.88 | Fused=0.453 | Pred=0 | True=0 | ✅  [68/86 = 79.1%]
#
# --- Processing Tweet 87: Since the tribunal was established 14 years ago, no complain... ---
#   CoT Length : 92 words
#   Entropy    : 0.323  →  Gamma: 0.465
#   Crit.Tokens: ['Analysis', 'tribunal', 'implication', 'implies', 'Situation']
#   RoBERTa=0.561 | CoT=0.15 | α=0.300 | HTag=0.88 | Fused=0.516 | Pred=1 | True=1 | ✅  [69/87 = 79.3%]
#
# --- Processing Tweet 88: @user Garner protesters chant 'F*ck Fox News' despite Fox ag... ---
#   CoT Length : 84 words
#   Entropy    : 0.335  →  Gamma: 0.467
#   Crit.Tokens: ['irony', 'creates', 'Tone', 'indicator', 'signals']
#   RoBERTa=0.812 | CoT=0.85 | α=0.300 | HTag=0.88 | Fused=0.855 | Pred=1 | True=1 | ✅  [70/88 = 79.5%]
#
# --- Processing Tweet 89: @user After 1989, why did NATO need to expand?... ---
#   CoT Length : 82 words
#   Entropy    : 0.305  →  Gamma: 0.461
#   Crit.Tokens: ['overly', 'contrast', 'signals', 'tone', '1989']
#   RoBERTa=0.169 | CoT=0.50 | α=0.608 | Fused=0.299 | Pred=0 | True=0 | ✅  [71/89 = 79.8%]
#
# --- Processing Tweet 90: The #Irony of playing this song on my way to #work |#NoMoney... ---
#   CoT Length : 86 words
#   Entropy    : 0.383  →  Gamma: 0.477
#   Crit.Tokens: ['Does', 'Analysis', 'suggests', 'unusual', 'commuting']
#   RoBERTa=0.204 | CoT=0.25 | α=0.300 | HTag=0.88 | Fused=0.494 | Pred=0 | True=1 | ❌  [71/90 = 78.9%]
#
# --- Processing Tweet 91: You are taking your responsibilities so seriously today that... ---
#   CoT Length : 86 words
#   Entropy    : 0.301  →  Gamma: 0.460
#   Crit.Tokens: ['indicates', 'ironic', 'Analysis', 'typically', 'exaggeration']
#   RoBERTa=0.767 | CoT=0.57 | α=0.601 | Fused=0.689 | Pred=1 | True=0 | ❌  [71/91 = 78.0%]
#
# --- Processing Tweet 92: @user @user @user @user @user we get it right for business t... ---
#   CoT Length : 90 words
#   Entropy    : 0.293  →  Gamma: 0.459
#   Crit.Tokens: ['user', 'ironic', 'aspects', 'trickle', 'business']
#   RoBERTa=0.473 | CoT=0.50 | α=0.300 | HTag=0.88 | Fused=0.647 | Pred=1 | True=1 | ✅  [72/92 = 78.3%]
#
# --- Processing Tweet 93: can you not understand that not EVERYTHING is about the Pres... ---
#   CoT Length : 86 words
#   Entropy    : 0.337  →  Gamma: 0.468
#   Crit.Tokens: ['Tone', 'dismissive', 'Analysis', 'agger', 'suggests']
#   RoBERTa=0.070 | CoT=0.15 | α=0.656 | Fused=0.097 | Pred=0 | True=0 | ✅  [73/93 = 78.5%]
#
# --- Processing Tweet 94: When you're in the doctors waiting room and hear a baby in t... ---
#   CoT Length : 84 words
#   Entropy    : 0.362  →  Gamma: 0.472
#   Crit.Tokens: ['reality', 'true', 'suggests', 'contradictory', 'exaggerated']
#   RoBERTa=0.971 | CoT=0.50 | α=0.300 | HTag=0.88 | Fused=0.737 | Pred=1 | True=1 | ✅  [74/94 = 78.7%]
#
# --- Processing Tweet 95: Well now the festive season has begun, let's take a moment t... ---
#   CoT Length : 82 words
#   Entropy    : 0.335  →  Gamma: 0.467
#   Crit.Tokens: ['However', 'celebration', 'current', 'phrase', 'Tone']
#   RoBERTa=0.616 | CoT=0.15 | α=0.300 | HTag=0.88 | Fused=0.526 | Pred=1 | True=1 | ✅  [75/95 = 78.9%]
#
# --- Processing Tweet 96: The last day of the year and I will be tweeting on my major ... ---
#   CoT Length : 92 words
#   Entropy    : 0.457  →  Gamma: 0.491
#   Crit.Tokens: ['experiences', 'notable', 'suggests', 'contrast', 'highlights']
#   RoBERTa=0.133 | CoT=0.15 | α=0.835 | Fused=0.135 | Pred=0 | True=0 | ✅  [76/96 = 79.2%]
#
# --- Processing Tweet 97: MB forgot to move the elf on shelf and now 10 is asking me i... ---
#   CoT Length : 83 words
#   Entropy    : 0.295  →  Gamma: 0.459
#   Crit.Tokens: ['indicate', 'irony', 'Tone', 'implies', 'suggests']
#   RoBERTa=0.629 | CoT=0.57 | α=0.592 | Fused=0.605 | Pred=1 | True=0 | ❌  [76/97 = 78.4%]
#
# --- Processing Tweet 98: @user happy new year, da! Thanks sobra for this year 👍👍... ---
#   CoT Length : 86 words
#   Entropy    : 0.243  →  Gamma: 0.449
#   Crit.Tokens: ['####', 'suggests', 'exaggerated', 'Analysis', 'Step']
#   RoBERTa=0.095 | CoT=0.15 | α=0.514 | Fused=0.122 | Pred=0 | True=0 | ✅  [77/98 = 78.6%]
#
# --- Processing Tweet 99: WATCH: #Megatron from #Transformers Rant About Social Media ... ---
#   CoT Length : 90 words
#   Entropy    : 0.335  →  Gamma: 0.467
#   Crit.Tokens: ['####', 'Iron', 'Step', 'ironic', 'Does']
#   RoBERTa=0.515 | CoT=0.62 | α=0.300 | HTag=0.88 | Fused=0.704 | Pred=1 | True=0 | ❌  [77/99 = 77.8%]
#
# --- Processing Tweet 100: @user @user #not #working when are we able to download games... ---
#   CoT Length : 92 words
#   Entropy    : 0.471  →  Gamma: 0.494
#   Crit.Tokens: ['irony', 'implies', 'tags', 'Context', 'tone']
#   RoBERTa=0.075 | CoT=0.85 | α=0.300 | HTag=0.88 | Fused=0.722 | Pred=1 | True=0 | ❌  [77/100 = 77.0%]
#
# --- Processing Tweet 101: I just wrote a 13 page paper... I was awfully tired when I w... ---
#   CoT Length : 81 words
#   Entropy    : 0.253  →  Gamma: 0.451
#   Crit.Tokens: ['implies', 'Tone', 'However', 'Meaning', 'This']
#   RoBERTa=0.273 | CoT=0.15 | α=0.300 | HTag=0.88 | Fused=0.464 | Pred=0 | True=1 | ❌  [77/101 = 76.2%]
#
# --- Processing Tweet 102: @user happy birthday Skip! We will always love you! #Phillie... ---
#   CoT Length : 88 words
#   Entropy    : 0.487  →  Gamma: 0.497
#   Crit.Tokens: ['Skip', 'birthday', 'evaluate', 'appears', 'Phill']
#   RoBERTa=0.036 | CoT=0.15 | α=0.881 | Fused=0.049 | Pred=0 | True=0 | ✅  [78/102 = 76.5%]
#
# --- Processing Tweet 103: or a trout, or northern pike|@brownbearmike1 @user @user @us... ---
#   CoT Length : 82 words
#   Entropy    : 0.274  →  Gamma: 0.455
#   Crit.Tokens: ['indicate', 'listing', 'neutral', 'fishing', 'Does']
#   RoBERTa=0.034 | CoT=0.25 | α=0.561 | Fused=0.129 | Pred=0 | True=0 | ✅  [79/103 = 76.7%]
#
# --- Processing Tweet 104: One of my favorite things to do is to make people wonder...i... ---
#   CoT Length : 84 words
#   Entropy    : 0.238  →  Gamma: 0.448
#   Crit.Tokens: ['described', 'Does', 'straightforward', 'contradiction', 'sentence']
#   RoBERTa=0.411 | CoT=0.15 | α=0.507 | Fused=0.282 | Pred=0 | True=0 | ✅  [80/104 = 76.9%]
#
# --- Processing Tweet 105: Watching Sanjay, @user ... Getting the start vs. Butler and ... ---
#   CoT Length : 92 words
#   Entropy    : 0.445  →  Gamma: 0.489
#   Crit.Tokens: ['favoring', 'mentions', 'straightforward', 'contradiction', 'watching']
#   RoBERTa=0.042 | CoT=0.15 | α=0.817 | Fused=0.062 | Pred=0 | True=0 | ✅  [81/105 = 77.1%]
#
# --- Processing Tweet 106: There's no better way to start the week than to get your wis... ---
#   CoT Length : 94 words
#   Entropy    : 0.434  →  Gamma: 0.487
#   Crit.Tokens: ['Step', 'irony', 'indicating', 'criticizing', 'mocking']
#   RoBERTa=0.962 | CoT=0.67 | α=0.300 | HTag=0.88 | Fused=0.809 | Pred=1 | True=1 | ✅  [82/106 = 77.4%]
#
# --- Processing Tweet 107: The most exciting way to start a Friday: a presentation on s... ---
#   CoT Length : 82 words
#   Entropy    : 0.302  →  Gamma: 0.461
#   Crit.Tokens: ['exciting', 'signals', 'presentation', 'Friday', 'bridges']
#   RoBERTa=0.977 | CoT=0.38 | α=0.300 | HTag=0.88 | Fused=0.689 | Pred=1 | True=1 | ✅  [83/107 = 77.6%]
#
# --- Processing Tweet 108: New shirt #new #shirt #im #sorry #its #just #i #literally #d... ---
#   CoT Length : 88 words
#   Entropy    : 0.358  →  Gamma: 0.472
#   Crit.Tokens: ['exaggeration', 'emphasizing', 'sorry', 'suggests', 'care']
#   RoBERTa=0.116 | CoT=0.25 | α=0.300 | HTag=0.88 | Fused=0.478 | Pred=0 | True=0 | ✅  [84/108 = 77.8%]
#
# --- Processing Tweet 109: @user @user @user It wasn't for one person. It was a busines... ---
#   CoT Length : 89 words
#   Entropy    : 0.393  →  Gamma: 0.479
#   Crit.Tokens: ['Analysis', 'irony', 'apparent', 'Tone', 'Step']
#   RoBERTa=0.047 | CoT=0.38 | α=0.739 | Fused=0.135 | Pred=0 | True=0 | ✅  [85/109 = 78.0%]
#
# --- Processing Tweet 110: HAHAHAHA!! Oops.......I'm addicted to @user Tweets sooo FUNN... ---
#   CoT Length : 79 words
#   Entropy    : 0.400  →  Gamma: 0.480
#   Crit.Tokens: ['contrasts', 'irony', 'suggests', 'admission', 'tags']
#   RoBERTa=0.347 | CoT=0.85 | α=0.300 | HTag=0.88 | Fused=0.771 | Pred=1 | True=0 | ❌  [85/110 = 77.3%]
#
# --- Processing Tweet 111: @user @user @user absolutely loved it! Well done all involve... ---
#   CoT Length : 81 words
#   Entropy    : 0.338  →  Gamma: 0.468
#   Crit.Tokens: ['####', 'ironically', 'Analysis', 'mask', 'intensify']
#   RoBERTa=0.135 | CoT=0.15 | α=0.656 | Fused=0.140 | Pred=0 | True=0 | ✅  [86/111 = 77.5%]
#
# --- Processing Tweet 112: @user That was the case, not the recording.So comparing the ... ---
#   CoT Length : 88 words
#   Entropy    : 0.357  →  Gamma: 0.471
#   Crit.Tokens: ['eral', 'apple', 'ording', 'suggests', 'fundamentally']
#   RoBERTa=0.049 | CoT=0.15 | α=0.686 | Fused=0.081 | Pred=0 | True=0 | ✅  [87/112 = 77.7%]
#
# --- Processing Tweet 113: Wow...lol||Need cash in your hands today? Go to #not #wun #n... ---
#   CoT Length : 79 words
#   Entropy    : 0.448  →  Gamma: 0.490
#   Crit.Tokens: ['contradiction', '..."', 'instructions', 'cash', 'indicates']
#   RoBERTa=0.114 | CoT=0.57 | α=0.300 | HTag=0.88 | Fused=0.612 | Pred=1 | True=0 | ❌  [87/113 = 77.0%]
#
# --- Processing Tweet 114: At least I don't have to clean the floor... ---
#   CoT Length : 93 words
#   Entropy    : 0.349  →  Gamma: 0.470
#   Crit.Tokens: ['contrast', 'Analysis', 'stating', 'rast', 'thankful']
#   RoBERTa=0.950 | CoT=0.15 | α=0.673 | Fused=0.688 | Pred=1 | True=0 | ❌  [87/114 = 76.3%]
#
# --- Processing Tweet 115: Incidentally the foreword for movie #BhopalAPrayerForRain is... ---
#   CoT Length : 83 words
#   Entropy    : 0.362  →  Gamma: 0.472
#   Crit.Tokens: ['directly', 'Iron', 'Context', 'Hash', 'delayed']
#   RoBERTa=0.753 | CoT=0.50 | α=0.300 | HTag=0.88 | Fused=0.697 | Pred=1 | True=1 | ✅  [88/115 = 76.5%]
#
# --- Processing Tweet 116: @user Our 3 losses followed bye weeks & an FCS team. Do we g... ---
#   CoT Length : 83 words
#   Entropy    : 0.461  →  Gamma: 0.492
#   Crit.Tokens: ['firing', 'ironic', 'Tone', 'irony', 'Context']
#   RoBERTa=0.057 | CoT=0.85 | α=0.300 | HTag=0.88 | Fused=0.719 | Pred=1 | True=1 | ✅  [89/116 = 76.7%]
#
# --- Processing Tweet 117: #AskSuperwomanLIVE if you could swim in any liquid besides w... ---
#   CoT Length : 86 words
#   Entropy    : 0.280  →  Gamma: 0.456
#   Crit.Tokens: ['exaggerated', 'Analysis', 'typical', 'statement', 'tone']
#   RoBERTa=0.025 | CoT=0.15 | α=0.569 | Fused=0.079 | Pred=0 | True=0 | ✅  [90/117 = 76.9%]
#
# --- Processing Tweet 118: One of the most embarrassing losses @user Ever. #WTF... ---
#   CoT Length : 92 words
#   Entropy    : 0.372  →  Gamma: 0.474
#   Crit.Tokens: ['criticizing', 'mocking', 'user', 'signal', 'suggesting']
#   RoBERTa=0.330 | CoT=0.15 | α=0.708 | Fused=0.277 | Pred=0 | True=0 | ✅  [91/118 = 77.1%]
#
# --- Processing Tweet 119: @user untrue - its Cutler's fault... ---
#   CoT Length : 85 words
#   Entropy    : 0.459  →  Gamma: 0.492
#   Crit.Tokens: ['straightforward', 'Analysis', 'Cutler', 'attribution', 'analyzed']
#   RoBERTa=0.101 | CoT=0.15 | α=0.839 | Fused=0.109 | Pred=0 | True=0 | ✅  [92/119 = 77.3%]
#
# --- Processing Tweet 120: #Malala Yousufzai receives #NobelPeacePrize and #Pakistan ra... ---
#   CoT Length : 80 words
#   Entropy    : 0.245  →  Gamma: 0.449
#   Crit.Tokens: ['emphasizing', 'contrast', 'Tone', 'indicates', 'However']
#   RoBERTa=0.912 | CoT=0.50 | α=0.300 | HTag=0.88 | Fused=0.726 | Pred=1 | True=1 | ✅  [93/120 = 77.5%]
#
# --- Processing Tweet 121: #Not so Ugly Christmas Sweater red with red snowflakes & seq... ---
#   CoT Length : 84 words
#   Entropy    : 0.406  →  Gamma: 0.481
#   Crit.Tokens: ['design', 'sweater', 'description', 'however', 'suggests']
#   RoBERTa=0.032 | CoT=0.15 | α=0.300 | HTag=0.88 | Fused=0.421 | Pred=0 | True=0 | ✅  [94/121 = 77.7%]
#
# --- Processing Tweet 122: Testing water temperatures #excitingtimes #Not... ---
#   CoT Length : 86 words
#   Entropy    : 0.362  →  Gamma: 0.472
#   Crit.Tokens: ['Analysis', 'expressing', 'iting', 'Testing', 'Sign']
#   RoBERTa=0.566 | CoT=0.85 | α=0.300 | HTag=0.88 | Fused=0.811 | Pred=1 | True=1 | ✅  [95/122 = 77.9%]
#
# --- Processing Tweet 123: Waking up with your cat attacking your hand is always deligh... ---
#   CoT Length : 86 words
#   Entropy    : 0.396  →  Gamma: 0.479
#   Crit.Tokens: ['delightful', 'contrasts', 'exaggeration', 'Tone', 'contradicts']
#   RoBERTa=0.954 | CoT=0.15 | α=0.300 | HTag=0.88 | Fused=0.587 | Pred=1 | True=1 | ✅  [96/123 = 78.0%]
#
# --- Processing Tweet 124: May not have hung out with you as much as some people, but e... ---
#   CoT Length : 89 words
#   Entropy    : 0.290  →  Gamma: 0.458
#   Crit.Tokens: ['####', 'enjoyable', 'contradiction', 'suggests', 'speaker']
#   RoBERTa=0.041 | CoT=0.25 | α=0.585 | Fused=0.128 | Pred=0 | True=0 | ✅  [97/124 = 78.2%]
#
# --- Processing Tweet 125: @user the #USA is #NOT a #Democracy. The #USA is a #Republic... ---
#   CoT Length : 90 words
#   Entropy    : 0.317  →  Gamma: 0.464
#   Crit.Tokens: ['suggesting', 'irony', 'stark', 'rast', 'contradiction']
#   RoBERTa=0.101 | CoT=0.32 | α=0.300 | HTag=0.88 | Fused=0.507 | Pred=1 | True=0 | ❌  [97/125 = 77.6%]
#
# --- Processing Tweet 126: I blame my mom. Mother of the Year #sarcasm... ---
#   CoT Length : 82 words
#   Entropy    : 0.364  →  Gamma: 0.473
#   Crit.Tokens: ['analyzed', 'compliment', 'irony', 'exaggerated', 'Situation']
#   RoBERTa=0.414 | CoT=0.50 | α=0.300 | HTag=0.88 | Fused=0.637 | Pred=1 | True=1 | ✅  [98/126 = 77.8%]
#
# --- Processing Tweet 127: Pulling my books out to prepare to organize my new bookshelv... ---
#   CoT Length : 89 words
#   Entropy    : 0.450  →  Gamma: 0.490
#   Crit.Tokens: ['ironic', 'responsibilities', 'exaggeration', 'Tone', 'signals']
#   RoBERTa=0.300 | CoT=0.85 | α=0.300 | HTag=0.88 | Fused=0.763 | Pred=1 | True=1 | ✅  [99/127 = 78.0%]
#
# --- Processing Tweet 128: @user @user To be fair, you didn't use the mandatory #sarcas... ---
#   CoT Length : 86 words
#   Entropy    : 0.537  →  Gamma: 0.507
#   Crit.Tokens: ['indicates', 'However', 'analyze', 'contradiction', 'signals']
#   RoBERTa=0.155 | CoT=0.15 | α=0.300 | HTag=0.88 | Fused=0.443 | Pred=0 | True=0 | ✅  [100/128 = 78.1%]
#
# --- Processing Tweet 129: 'I like the hope Jan Ellis writes with, the precision of the... ---
#   CoT Length : 83 words
#   Entropy    : 0.332  →  Gamma: 0.466
#   Crit.Tokens: ['Analysis', 'irony', 'tone', 'Sign', 'expressing']
#   RoBERTa=0.136 | CoT=0.62 | α=0.300 | HTag=0.88 | Fused=0.635 | Pred=1 | True=0 | ❌  [100/129 = 77.5%]
#
# --- Processing Tweet 130: Girls just wanna have fun#work#not#friends#only#dance#drinks... ---
#   CoT Length : 85 words
#   Entropy    : 0.389  →  Gamma: 0.478
#   Crit.Tokens: ['Analysis', 'Tone', 'irony', 'emphasizing', 'implies']
#   RoBERTa=0.232 | CoT=0.38 | α=0.300 | HTag=0.88 | Fused=0.555 | Pred=1 | True=0 | ❌  [100/130 = 76.9%]
#
# --- Processing Tweet 131: The Bay Area storm is so big that tons of people's work was ... ---
#   CoT Length : 90 words
#   Entropy    : 0.277  →  Gamma: 0.455
#   Crit.Tokens: ['speaker', 'contradiction', 'describes', 'delays', 'creates']
#   RoBERTa=0.924 | CoT=0.85 | α=0.300 | HTag=0.88 | Fused=0.875 | Pred=1 | True=1 | ✅  [101/131 = 77.1%]
#
# --- Processing Tweet 132: @user I'm from the UK and I honestly think your a goddess! I... ---
#   CoT Length : 83 words
#   Entropy    : 0.301  →  Gamma: 0.460
#   Crit.Tokens: ['user', 'However', 'exaggerated', 'compliment', 'admiration']
#   RoBERTa=0.054 | CoT=0.15 | α=0.601 | Fused=0.092 | Pred=0 | True=0 | ✅  [102/132 = 77.3%]
#
# --- Processing Tweet 133: Leaving whilst its dark is fun. #not... ---
#   CoT Length : 86 words
#   Entropy    : 0.245  →  Gamma: 0.449
#   Crit.Tokens: ['####', 'straightforward', 'enjoyable', 'analyze', 'likely']
#   RoBERTa=0.810 | CoT=0.15 | α=0.300 | HTag=0.88 | Fused=0.561 | Pred=1 | True=1 | ✅  [103/133 = 77.4%]
#
# --- Processing Tweet 134: @user please note #sarcasm in last tweet before you kill you... ---
#   CoT Length : 89 words
#   Entropy    : 0.391  →  Gamma: 0.478
#   Crit.Tokens: ['recipient', 'Tone', 'author', 'clear', 'intent']
#   RoBERTa=0.131 | CoT=0.50 | α=0.300 | HTag=0.88 | Fused=0.586 | Pred=1 | True=0 | ❌  [103/134 = 76.9%]
#
# --- Processing Tweet 135: @user my mum to be back with us for Xmas 🎄... ---
#   CoT Length : 85 words
#   Entropy    : 0.211  →  Gamma: 0.443
#   Crit.Tokens: ['Analysis', 'straightforward', 'Sign', 'stating', 'Does']
#   RoBERTa=0.037 | CoT=0.05 | α=0.466 | Fused=0.044 | Pred=0 | True=0 | ✅  [104/135 = 77.0%]
#
# --- Processing Tweet 136: @user Even though @user got more ex-wives than @user majors,... ---
#   CoT Length : 84 words
#   Entropy    : 0.286  →  Gamma: 0.457
#   Crit.Tokens: ['situation', 'Analysis', 'phrase', 'Situation', 'Tone']
#   RoBERTa=0.253 | CoT=0.50 | α=0.300 | HTag=0.88 | Fused=0.607 | Pred=1 | True=1 | ✅  [105/136 = 77.2%]
#
# --- Processing Tweet 137: @user Ucan MAKE MONEY #TWEETING this info w/ new app||http:/... ---
#   CoT Length : 84 words
#   Entropy    : 0.447  →  Gamma: 0.489
#   Crit.Tokens: ['enthusiasm', 'Tone', 'earnings', 'ironic', 'implies']
#   RoBERTa=0.087 | CoT=0.57 | α=0.820 | Fused=0.173 | Pred=0 | True=0 | ✅  [106/137 = 77.4%]
#
# --- Processing Tweet 138: Take me tooooo church #not... ---
#   CoT Length : 77 words
#   Entropy    : 0.350  →  Gamma: 0.470
#   Crit.Tokens: ['church', 'irony', 'user', 'exaggerated', 'Tone']
#   RoBERTa=0.034 | CoT=0.85 | α=0.300 | HTag=0.88 | Fused=0.715 | Pred=1 | True=0 | ❌  [106/138 = 76.8%]
#
# --- Processing Tweet 139: A 'republican move' which will 'effectively rob the royals'.... ---
#   CoT Length : 83 words
#   Entropy    : 0.363  →  Gamma: 0.473
#   Crit.Tokens: ['exaggerated', 'signals', 'ifiable', 'unjust', 'implies']
#   RoBERTa=0.500 | CoT=0.50 | α=0.300 | HTag=0.88 | Fused=0.652 | Pred=1 | True=1 | ✅  [107/139 = 77.0%]
#
# --- Processing Tweet 140: #obama @user announce special urgent package for #Pakistan .... ---
#   CoT Length : 70 words
#   Entropy    : 0.201  →  Gamma: 0.441
#   Crit.Tokens: ['factual', 'indicate', 'Pret', 'special', 'Meaning']
#   RoBERTa=0.856 | CoT=0.15 | α=0.300 | HTag=0.88 | Fused=0.569 | Pred=1 | True=1 | ✅  [108/140 = 77.1%]
#
# --- Processing Tweet 141: @user Shirota Yu and... Inoue Yoshio? He was in Mozart! appa... ---
#   CoT Length : 82 words
#   Entropy    : 0.408  →  Gamma: 0.482
#   Crit.Tokens: ['agger', 'ironic', 'unusual', 'which', 'included']
#   RoBERTa=0.114 | CoT=0.57 | α=0.762 | Fused=0.223 | Pred=0 | True=0 | ✅  [109/141 = 77.3%]
#
# --- Processing Tweet 142: Looking for quality music check> @user hot record "What Abou... ---
#   CoT Length : 86 words
#   Entropy    : 0.335  →  Gamma: 0.467
#   Crit.Tokens: ['recommending', 'check', 'neutral', 'hasht', 'tweet']
#   RoBERTa=0.030 | CoT=0.50 | α=0.652 | Fused=0.194 | Pred=0 | True=0 | ✅  [110/142 = 77.5%]
#
# --- Processing Tweet 143: how is it possible that somebody so interesting is also so, ... ---
#   CoT Length : 85 words
#   Entropy    : 0.249  →  Gamma: 0.450
#   Crit.Tokens: ['Tone', 'implies', 'agger', 'contradiction', 'eral']
#   RoBERTa=0.087 | CoT=0.15 | α=0.300 | HTag=0.88 | Fused=0.431 | Pred=0 | True=1 | ❌  [110/143 = 76.9%]
#
# --- Processing Tweet 144: @user Not going this time, we might have a chance! Fool me o... ---
#   CoT Length : 86 words
#   Entropy    : 0.319  →  Gamma: 0.464
#   Crit.Tokens: ['Analysis', 'analyze', 'phrase', 'ated', 'mocking']
#   RoBERTa=0.068 | CoT=0.15 | α=0.628 | Fused=0.098 | Pred=0 | True=0 | ✅  [111/144 = 77.1%]
#
# --- Processing Tweet 145: @user Minky Wale tail fritter for price of a bijoux flat in ... ---
#   CoT Length : 82 words
#   Entropy    : 0.342  →  Gamma: 0.468
#   Crit.Tokens: ['implies', 'contrast', 'Tone', 'creates', 'Analysis']
#   RoBERTa=0.063 | CoT=0.15 | α=0.663 | Fused=0.093 | Pred=0 | True=0 | ✅  [112/145 = 77.2%]
#
# --- Processing Tweet 146: .@ibnlive is the first to cut to ads during primetime to pro... ---
#   CoT Length : 83 words
#   Entropy    : 0.244  →  Gamma: 0.449
#   Crit.Tokens: ['Does', 'contradiction', 'SIGN', 'Iron', 'journalism']
#   RoBERTa=0.960 | CoT=0.38 | α=0.300 | HTag=0.88 | Fused=0.686 | Pred=1 | True=1 | ✅  [113/146 = 77.4%]
#
# --- Processing Tweet 147: .@ChrisBrett2 @user @user @user I think it's your white skin... ---
#   CoT Length : 84 words
#   Entropy    : 0.459  →  Gamma: 0.492
#   Crit.Tokens: ['critical', 'suggests', 'unclear', 'tone', 'SIGN']
#   RoBERTa=0.164 | CoT=0.15 | α=0.300 | HTag=0.88 | Fused=0.444 | Pred=0 | True=1 | ❌  [113/147 = 76.9%]
#
# --- Processing Tweet 148: #hi #good #morning #instadaily #snapchat #selfie #comment # ... ---
#   CoT Length : 76 words
#   Entropy    : 0.347  →  Gamma: 0.470
#   Crit.Tokens: ['Tone', 'iron', 'signal', 'Positive', 'exaggeration']
#   RoBERTa=0.126 | CoT=0.15 | α=0.300 | HTag=0.88 | Fused=0.438 | Pred=0 | True=0 | ✅  [114/148 = 77.0%]
#
# --- Processing Tweet 149: I JUST WANT TO BE DONE WITH FINALS #4hoursleft... ---
#   CoT Length : 78 words
#   Entropy    : 0.323  →  Gamma: 0.465
# ...
#
# --- Processing Tweet 738: Ah yes. Just what I wanted today- a pounding migraine. #Sarc... ---
#   CoT Length : 88 words
#   Entropy    : 0.414  →  Gamma: 0.483
#   Crit.Tokens: ['irony', 'Meaning', 'contradicts', 'Tone', 'signals']
#   RoBERTa=0.954 | CoT=0.85 | α=0.300 | HTag=0.88 | Fused=0.881 | Pred=1 | True=1 | ✅  [581/738 = 78.7%]
#
# --- Processing Tweet 739: Munching cheese like its Christmas #stiltonoverload... ---
#   CoT Length : 82 words
#   Entropy    : 0.307  →  Gamma: 0.462
#   Crit.Tokens: ['Analysis', 'exaggeration', 'Does', 'describes', 'ironic']
#   RoBERTa=0.337 | CoT=0.50 | α=0.611 | Fused=0.401 | Pred=0 | True=0 | ✅  [582/739 = 78.8%]
#
# --- Processing Tweet 740: #Hazard worker training. 1st break there was 3 doz donuts an... ---
#   CoT Length : 89 words
#   Entropy    : 0.321  →  Gamma: 0.464
#   Crit.Tokens: ['tone', 'phrase', 'signal', 'However', 'employees']
#   RoBERTa=0.253 | CoT=0.15 | α=0.300 | HTag=0.88 | Fused=0.461 | Pred=0 | True=1 | ❌  [582/740 = 78.6%]
#
# --- Processing Tweet 741: The thought of work tonight really kills that Friday feeling... ---
#   CoT Length : 80 words
#   Entropy    : 0.397  →  Gamma: 0.479
#   Crit.Tokens: ['Situation', 'situation', 'exaggeration', 'Tone', 'displeasure']
#   RoBERTa=0.747 | CoT=0.15 | α=0.746 | Fused=0.595 | Pred=1 | True=0 | ❌  [582/741 = 78.5%]
#
# --- Processing Tweet 742: The thirstiest of thirst buckets calling other people thirst... ---
#   CoT Length : 90 words
#   Entropy    : 0.335  →  Gamma: 0.467
#   Crit.Tokens: ['####', 'implies', 'Analysis', 'Step', 'mocking']
#   RoBERTa=0.491 | CoT=0.38 | α=0.300 | HTag=0.88 | Fused=0.601 | Pred=1 | True=1 | ✅  [583/742 = 78.6%]
#
# --- Processing Tweet 743: @user #pantsdowntiggy was his crime. Pixelation #moot or #ir... ---
#   CoT Length : 74 words
#   Entropy    : 0.402  →  Gamma: 0.480
#   Crit.Tokens: ['ironic', 'appears', 'straightforward', 'Tone', 'clear']
#   RoBERTa=0.090 | CoT=0.45 | α=0.300 | HTag=0.88 | Fused=0.557 | Pred=1 | True=0 | ❌  [583/743 = 78.5%]
#
# --- Processing Tweet 744: #notcies #eu Green determined to block Hinkley Point - Green... ---
#   CoT Length : 84 words
#   Entropy    : 0.306  →  Gamma: 0.461
#   Crit.Tokens: ['indicating', 'cies', 'irony', 'Analysis', 'Positive']
#   RoBERTa=0.262 | CoT=0.85 | α=0.609 | Fused=0.492 | Pred=0 | True=0 | ✅  [584/744 = 78.5%]
#
# --- Processing Tweet 745: I've got a right thirst on... #NewsYearsEve... ---
#   CoT Length : 77 words
#   Entropy    : 0.371  →  Gamma: 0.474
#   Crit.Tokens: ['irony', 'Tone', 'signal', 'straightforward', 'indicate']
#   RoBERTa=0.101 | CoT=0.45 | α=0.706 | Fused=0.203 | Pred=0 | True=0 | ✅  [585/745 = 78.5%]
#
# --- Processing Tweet 746: Love the fact that I turned off my alarm this morning and sl... ---
#   CoT Length : 86 words
#   Entropy    : 0.309  →  Gamma: 0.462
#   Crit.Tokens: ['Analysis', 'irony', 'adds', 'However', 'supports']
#   RoBERTa=0.911 | CoT=0.85 | α=0.300 | HTag=0.88 | Fused=0.873 | Pred=1 | True=1 | ✅  [586/746 = 78.6%]
#
# --- Processing Tweet 747: #mcfc trying to kill their opponents.... ---
#   CoT Length : 80 words
#   Entropy    : 0.314  →  Gamma: 0.463
#   Crit.Tokens: ['without', 'Tone', 'exaggerated', 'SIGN', 'analyze']
#   RoBERTa=0.405 | CoT=0.15 | α=0.621 | Fused=0.308 | Pred=0 | True=0 | ✅  [587/747 = 78.6%]
#
# --- Processing Tweet 748: #Seen #a #headline #about #a #doctor #that #starts #with #"D... ---
#   CoT Length : 77 words
#   Entropy    : 0.251  →  Gamma: 0.450
#   Crit.Tokens: ['Analysis', '..."', 'Sign', 'pull', 'phrase']
#   RoBERTa=0.117 | CoT=0.15 | α=0.300 | HTag=0.88 | Fused=0.436 | Pred=0 | True=0 | ✅  [588/748 = 78.6%]
#
# --- Processing Tweet 749: @user @user Yet no "dog in the manger" that actually makes i... ---
#   CoT Length : 91 words
#   Entropy    : 0.355  →  Gamma: 0.471
#   Crit.Tokens: ['Iron', 'Analysis', 'access', 'implies', 'prevents']
#   RoBERTa=0.401 | CoT=0.50 | α=0.300 | HTag=0.88 | Fused=0.634 | Pred=1 | True=1 | ✅  [589/749 = 78.6%]
#
# --- Processing Tweet 750: #Irony Reverend tells kids that Santa is not real why declar... ---
#   CoT Length : 93 words
#   Entropy    : 0.480  →  Gamma: 0.496
#   Crit.Tokens: ['emphasizing', 'empirical', 'However', 'reinforcing', 'mentions']
#   RoBERTa=0.844 | CoT=0.15 | α=0.300 | HTag=0.88 | Fused=0.567 | Pred=1 | True=1 | ✅  [590/750 = 78.7%]
#
# --- Processing Tweet 751: Laborers in the San Joaquin Valley, one of the most producti... ---
#   CoT Length : 87 words
#   Entropy    : 0.270  →  Gamma: 0.454
#   Crit.Tokens: ['contradiction', 'stark', 'renowned', 'orers', 'overty']
#   RoBERTa=0.609 | CoT=0.38 | α=0.300 | HTag=0.88 | Fused=0.623 | Pred=1 | True=1 | ✅  [591/751 = 78.7%]
#
# --- Processing Tweet 752: I think my friend just sent @user a snapchat of me drinkin w... ---
#   CoT Length : 86 words
#   Entropy    : 0.245  →  Gamma: 0.449
#   Crit.Tokens: ['attribut', 'likely', 'intended', 'Meaning', 'nature']
#   RoBERTa=0.678 | CoT=0.38 | α=0.300 | HTag=0.88 | Fused=0.635 | Pred=1 | True=1 | ✅  [592/752 = 78.7%]
#
# --- Processing Tweet 753: Girls won't answer their phone when I'm calling them bc they... ---
#   CoT Length : 93 words
#   Entropy    : 0.341  →  Gamma: 0.468
#   Crit.Tokens: ['Tone', 'ironic', 'Meaning', 'signal', 'conversations']
#   RoBERTa=0.636 | CoT=0.38 | α=0.300 | HTag=0.88 | Fused=0.628 | Pred=1 | True=1 | ✅  [593/753 = 78.8%]
#
# --- Processing Tweet 754: @user make sure you don't say Christmas!! The decorate for t... ---
#   CoT Length : 82 words
#   Entropy    : 0.345  →  Gamma: 0.469
#   Crit.Tokens: ['suggests', 'situation', 'implies', 'Situation', 'SIGN']
#   RoBERTa=0.372 | CoT=0.38 | α=0.300 | HTag=0.88 | Fused=0.580 | Pred=1 | True=1 | ✅  [594/754 = 78.8%]
#
# --- Processing Tweet 755: Re: prison book ban - Of course Grayling is also trying to b... ---
#   CoT Length : 101 words
#   Entropy    : 0.397  →  Gamma: 0.479
#   Crit.Tokens: ['irony', 'Contrast', 'suggests', 'Judicial', 'Between']
#   RoBERTa=0.918 | CoT=0.43 | α=0.300 | HTag=0.88 | Fused=0.698 | Pred=1 | True=1 | ✅  [595/755 = 78.8%]
#
# --- Processing Tweet 756: Rolled out of bed for closing.... #ilookreallygood #not... ---
#   CoT Length : 84 words
#   Entropy    : 0.337  →  Gamma: 0.468
#   Crit.Tokens: ['tone', 'signals', 'implies', 'rolled', 'Does']
#   RoBERTa=0.193 | CoT=0.15 | α=0.300 | HTag=0.88 | Fused=0.450 | Pred=0 | True=1 | ❌  [595/756 = 78.7%]
#
# --- Processing Tweet 757: Watching VT and Cincy - qb for VT with (GODS) down left arm ... ---
#   CoT Length : 83 words
#   Entropy    : 0.383  →  Gamma: 0.477
#   Crit.Tokens: ['Tone', 'quarterbacks', 'ironic', 'injuries', 'author']
#   RoBERTa=0.213 | CoT=0.15 | α=0.300 | HTag=0.88 | Fused=0.453 | Pred=0 | True=1 | ❌  [595/757 = 78.6%]
#
# --- Processing Tweet 758: you seem super smart MT "@GrannyMarried: @user @user ||#NO #... ---
#   CoT Length : 77 words
#   Entropy    : 0.360  →  Gamma: 0.472
#   Crit.Tokens: ['boarding', 'Meaning', 'However', 'contradiction', 'technique']
#   RoBERTa=0.347 | CoT=0.15 | α=0.300 | HTag=0.88 | Fused=0.477 | Pred=0 | True=1 | ❌  [595/758 = 78.5%]
#
# --- Processing Tweet 759: @user Cheers bro! Top man 🙋... ---
#   CoT Length : 82 words
#   Entropy    : 0.213  →  Gamma: 0.443
#   Crit.Tokens: ['ironically', 'However', 'SIGN', 'expression', 'determine']
#   RoBERTa=0.045 | CoT=0.25 | α=0.469 | Fused=0.154 | Pred=0 | True=0 | ✅  [596/759 = 78.5%]
#
# --- Processing Tweet 760: Even getting cooked breakfast.. Hes defo up to something 😕😮😆... ---
#   CoT Length : 78 words
#   Entropy    : 0.345  →  Gamma: 0.469
#   Crit.Tokens: ['multiple', 'indicate', 'SIGN', 'Tone', 'irony']
#   RoBERTa=0.207 | CoT=0.85 | α=0.667 | Fused=0.421 | Pred=0 | True=0 | ✅  [597/760 = 78.6%]
#
# --- Processing Tweet 761: ROFLMAO yeah, OOPS is right @user @user @user @user... ---
#   CoT Length : 76 words
#   Entropy    : 0.354  →  Gamma: 0.471
#   Crit.Tokens: ['accompanies', 'irony', 'Tone', 'suggests', 'amusement']
#   RoBERTa=0.078 | CoT=0.50 | α=0.681 | Fused=0.213 | Pred=0 | True=0 | ✅  [598/761 = 78.6%]
#
# --- Processing Tweet 762: Coin ! LeCoinCanard: Coin ! LeCoinCanard: Coin ! have a wank... ---
#   CoT Length : 87 words
#   Entropy    : 0.468  →  Gamma: 0.494
#   Crit.Tokens: ['sarcast', 'SIGN', 'Coin', 'mocked', 'These']
#   RoBERTa=0.136 | CoT=0.15 | α=0.300 | HTag=0.88 | Fused=0.439 | Pred=0 | True=1 | ❌  [598/762 = 78.5%]
#
# --- Processing Tweet 763: I really want to see Into The Woods!... ---
#   CoT Length : 83 words
#   Entropy    : 0.295  →  Gamma: 0.459
#   Crit.Tokens: ['indicators', 'contradiction', 'straightforward', 'bole', 'sentiment']
#   RoBERTa=0.053 | CoT=0.15 | α=0.592 | Fused=0.093 | Pred=0 | True=0 | ✅  [599/763 = 78.5%]
#
# --- Processing Tweet 764: @user that bump off the apron looked like it hurt.. was that... ---
#   CoT Length : 79 words
#   Entropy    : 0.239  →  Gamma: 0.448
#   Crit.Tokens: ['exaggeration', 'straightforward', 'Analysis', 'observation', 'Tone']
#   RoBERTa=0.054 | CoT=0.38 | α=0.300 | HTag=0.88 | Fused=0.523 | Pred=1 | True=1 | ✅  [600/764 = 78.5%]
#
# --- Processing Tweet 765: @user please make me smile this Xmas.. First Xmas without my... ---
#   CoT Length : 81 words
#   Entropy    : 0.415  →  Gamma: 0.483
#   Crit.Tokens: ['Analysis', 'Tone', 'suggests', 'Meaning', 'However']
#   RoBERTa=0.037 | CoT=0.15 | α=0.772 | HTag=0.12 | Fused=0.077 | Pred=0 | True=0 | ✅  [601/765 = 78.6%]
#
# --- Processing Tweet 766: @user Hope the header didn't mess up that barnet... ---
#   CoT Length : 83 words
#   Entropy    : 0.224  →  Gamma: 0.445
#   Crit.Tokens: ['neutral', 'Hope', 'phrase', 'tone', 'indication']
#   RoBERTa=0.100 | CoT=0.50 | α=0.486 | Fused=0.305 | Pred=0 | True=0 | ✅  [602/766 = 78.6%]
#
# --- Processing Tweet 767: If it's NOT? then it IS! Hand Crafted Artistically Fashionab... ---
#   CoT Length : 76 words
#   Entropy    : 0.284  →  Gamma: 0.457
#   Crit.Tokens: ['indicates', 'Score', 'confidence', 'exaggerated', 'Does']
#   RoBERTa=0.059 | CoT=0.15 | α=0.576 | Fused=0.098 | Pred=0 | True=0 | ✅  [603/767 = 78.6%]
#
# --- Processing Tweet 768: It's okay @user I didn't really want to see my idol anyway. ... ---
#   CoT Length : 89 words
#   Entropy    : 0.236  →  Gamma: 0.448
#   Crit.Tokens: ['However', 'suggests', 'sarcastic', 'Analysis', 'anyway']
#   RoBERTa=0.281 | CoT=0.50 | α=0.300 | HTag=0.88 | Fused=0.613 | Pred=1 | True=1 | ✅  [604/768 = 78.6%]
#
# --- Processing Tweet 769: I'll try to guess the ASCII symbols without my admins help. ... ---
#   CoT Length : 88 words
#   Entropy    : 0.300  →  Gamma: 0.460
#   Crit.Tokens: ['Tone', 'admins', 'ASCII', 'symbols', 'straightforward']
#   RoBERTa=0.297 | CoT=0.15 | α=0.601 | Fused=0.238 | Pred=0 | True=0 | ✅  [605/769 = 78.7%]
#
# --- Processing Tweet 770: Hearing gun shots when I first wake up makes me feel like I'... ---
#   CoT Length : 91 words
#   Entropy    : 0.455  →  Gamma: 0.491
#   Crit.Tokens: ['gunshots', 'earing', 'irony', 'implies', 'convey']
#   RoBERTa=0.982 | CoT=0.65 | α=0.300 | HTag=0.88 | Fused=0.802 | Pred=1 | True=1 | ✅  [606/770 = 78.7%]
#
# --- Processing Tweet 771: Protesters upset over decision in chokehold death take the s... ---
#   CoT Length : 85 words
#   Entropy    : 0.356  →  Gamma: 0.471
#   Crit.Tokens: ['Analysis', 'straightforward', 'factual', 'analyze', 'emotions']
#   RoBERTa=0.621 | CoT=0.15 | α=0.684 | Fused=0.472 | Pred=0 | True=0 | ✅  [607/771 = 78.7%]
#
# --- Processing Tweet 772: @user Great,& not sure if i've seen that actual pic! #not ju... ---
#   CoT Length : 84 words
#   Entropy    : 0.238  →  Gamma: 0.448
#   Crit.Tokens: ['####', 'compliment', 'praising', 'expresses', 'girls']
#   RoBERTa=0.057 | CoT=0.15 | α=0.300 | HTag=0.88 | Fused=0.425 | Pred=0 | True=0 | ✅  [608/772 = 78.8%]
#
# --- Processing Tweet 773: #TGIF oh just kidding I have 30 mins from one job to the nex... ---
#   CoT Length : 85 words
#   Entropy    : 0.339  →  Gamma: 0.468
#   Crit.Tokens: ['Tone', 'approaching', 'However', 'suggests', 'SIGN']
#   RoBERTa=0.933 | CoT=0.15 | α=0.300 | HTag=0.88 | Fused=0.583 | Pred=1 | True=1 | ✅  [609/773 = 78.8%]
#
# --- Processing Tweet 774: Just got yelled at by proxy. It's going to be an excellent d... ---
#   CoT Length : 86 words
#   Entropy    : 0.284  →  Gamma: 0.457
#   Crit.Tokens: ['contradiction', 'creates', 'contrasts', 'exaggeration', 'excellent']
#   RoBERTa=0.974 | CoT=0.50 | α=0.300 | HTag=0.88 | Fused=0.737 | Pred=1 | True=1 | ✅  [610/774 = 78.8%]
#
# --- Processing Tweet 775: Lol everyday excuse the language #relationships #men #women ... ---
#   CoT Length : 80 words
#   Entropy    : 0.330  →  Gamma: 0.466
#   Crit.Tokens: ['####', 'intentionally', 'Analysis', 'overly', 'vague']
#   RoBERTa=0.268 | CoT=0.25 | α=0.300 | HTag=0.88 | Fused=0.505 | Pred=1 | True=0 | ❌  [610/775 = 78.7%]
#
# --- Processing Tweet 776: Making the most out of my last vacation day. #not #tvandslee... ---
#   CoT Length : 83 words
#   Entropy    : 0.251  →  Gamma: 0.450
#   Crit.Tokens: ['However', 'suggests', 'contradiction', 'Does', 'SIGN']
#   RoBERTa=0.509 | CoT=0.15 | α=0.300 | HTag=0.88 | Fused=0.507 | Pred=1 | True=1 | ✅  [611/776 = 78.7%]
#
# --- Processing Tweet 777: What a lovely day to drive #not #boo #fog #work 😳😳😳... ---
#   CoT Length : 76 words
#   Entropy    : 0.297  →  Gamma: 0.459
#   Crit.Tokens: ['contradictory', 'suggests', 'typically', 'Tone', 'seems']
#   RoBERTa=0.345 | CoT=0.15 | α=0.300 | HTag=0.88 | Fused=0.477 | Pred=0 | True=1 | ❌  [611/777 = 78.6%]
#
# --- Processing Tweet 778: So restaurants that thrive on the social nature of eating be... ---
#   CoT Length : 90 words
#   Entropy    : 0.332  →  Gamma: 0.466
#   Crit.Tokens: ['Analysis', 'contrast', 'Situation', 'analyze', 'situation']
#   RoBERTa=0.935 | CoT=0.15 | α=0.300 | HTag=0.88 | Fused=0.583 | Pred=1 | True=1 | ✅  [612/778 = 78.7%]
#
# --- Processing Tweet 779: This long drive home later in the snow is gonna be shweeeet ... ---
#   CoT Length : 75 words
#   Entropy    : 0.298  →  Gamma: 0.460
#   Crit.Tokens: ['indicator', 'signals', 'tags', 'indicates', 'clear']
#   RoBERTa=0.074 | CoT=0.50 | α=0.300 | HTag=0.88 | Fused=0.575 | Pred=1 | True=1 | ✅  [613/779 = 78.7%]
#
# --- Processing Tweet 780: If you drag yesterday into today, your tomorrow cannot be wh... ---
#   CoT Length : 91 words
#   Entropy    : 0.367  →  Gamma: 0.473
#   Crit.Tokens: ['Analysis', 'contrast', 'Tone', 'dwelling', 'hashtag']
#   RoBERTa=0.027 | CoT=0.15 | α=0.701 | Fused=0.064 | Pred=0 | True=0 | ✅  [614/780 = 78.7%]
#
# --- Processing Tweet 781: Congrats to my fav @user & her team & my birthplace team #Oh... ---
#   CoT Length : 80 words
#   Entropy    : 0.327  →  Gamma: 0.466
#   Crit.Tokens: ['Context', 'ulatory', 'agger', 'tone', 'enthusiastic']
#   RoBERTa=0.082 | CoT=0.15 | α=0.641 | Fused=0.107 | Pred=0 | True=0 | ✅  [615/781 = 78.7%]
#
# --- Processing Tweet 782: @user Jessica sheds tears at her fan signing event makes me ... ---
#   CoT Length : 88 words
#   Entropy    : 0.263  →  Gamma: 0.453
#   Crit.Tokens: ['suggests', 'mentions', 'signals', 'contradiction', 'response']
#   RoBERTa=0.326 | CoT=0.15 | α=0.545 | Fused=0.246 | Pred=0 | True=0 | ✅  [616/782 = 78.8%]
#
# --- Processing Tweet 783: #Irony: al jazeera is pro Anti - #GamerGate because feminism... ---
#   CoT Length : 88 words
#   Entropy    : 0.360  →  Gamma: 0.472
#   Crit.Tokens: ['However', 'brief', 'Iron', 'irony', 'Does']
#   RoBERTa=0.796 | CoT=0.72 | α=0.300 | HTag=0.88 | Fused=0.799 | Pred=1 | True=1 | ✅  [617/783 = 78.8%]
#
# --- Processing Tweet 784: #NOT ALL 👌 There good & bad in every occupation & race 📚📖 #S... ---
#   CoT Length : 89 words
#   Entropy    : 0.412  →  Gamma: 0.482
#   Crit.Tokens: ['ironically', 'irony', 'emoji', 'typically', 'SIGN']
#   RoBERTa=0.093 | CoT=0.85 | α=0.300 | HTag=0.88 | Fused=0.726 | Pred=1 | True=0 | ❌  [617/784 = 78.7%]
#
# ================================================================
# 🏆 RDS v2 [FULL_RDS] ACCURACY : 78.7%  (617/784)
# 📉 Avg Token-Skip Ratio         : 47.2%
# 🏷️  Hashtag detector fired       : 442 tweets  (431 strong signals)
# ================================================================
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_58/3936329111.py in <cell line: 0>()
#     265 print(f"{'='*64}")
#     266
# --> 267 df = pd.DataFrame(results_list)
#     268 display(df)
#
# NameError: name 'pd' is not defined
