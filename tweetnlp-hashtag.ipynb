# %% [markdown]
# # Ablation: RoBERTa + Hashtag Prior (No CoT)
#
# **Purpose:** Isolate the contribution of the CoT compression pipeline in RDS by testing whether
# RoBERTa + the Symbolic Hashtag Prior alone can match full RDS performance.
#
# **What is stripped vs. kept:**
# - ❌ Removed: Qwen CoT generation, Entropy Budgeter, Gradient-Sensitized Local Guardian, LLMLingua-2 compression
# - ✅ Kept: RoBERTa classifier (`cardiffnlp/twitter-roberta-base-irony`)
# - ✅ Kept: Symbolic Prior (`detect_explicit_irony_signal`) — exact same regexes, same weights
# - ✅ Kept: Same dataset split (first 50 = validation, remaining 734 = test)
# - ✅ Kept: Same fusion injection logic and numerical parameters from RDS
#
# **Fusion in this ablation:**
# Since there is no CoT signal, the base prediction is purely RoBERTa. The hashtag prior is then
# injected using the same blending weights as RDS (ωstrong=0.60, ωweak=0.75, αcap=0.30).
# When no signal fires, the prediction defaults to RoBERTa alone.

# %%
# ── Cell 1: Install dependencies ─────────────────────────────────────────────
# !pip install -q transformers datasets torch
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.2/12.2 MB 93.9 MB/s eta 0:00:00:00:010:01
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# dask-cuda 26.2.0 requires cuda-core==0.3.*, but you have cuda-core 1.0.1 which is incompatible.
# dask-cuda 26.2.0 requires numba-cuda<0.23.0,>=0.22.1, but you have numba-cuda 0.30.2 which is incompatible.
# distributed-ucxx-cu12 0.48.0 requires numba-cuda[cu12]<0.23.0,>=0.22.1, but you have numba-cuda 0.30.2 which is incompatible.
# cuml-cu12 26.2.0 requires numba<0.62.0,>=0.60.0, but you have numba 0.65.1 which is incompatible.
# cuml-cu12 26.2.0 requires numba-cuda[cu12]<0.23.0,>=0.22.1, but you have numba-cuda 0.30.2 which is incompatible.
# ucxx-cu12 0.48.0 requires numba-cuda[cu12]<0.23.0,>=0.22.1, but you have numba-cuda 0.30.2 which is incompatible.
# cudf-cu12 26.2.1 requires numba<0.62.0,>=0.60.0, but you have numba 0.65.1 which is incompatible.
# cudf-cu12 26.2.1 requires numba-cuda[cu12]<0.23.0,>=0.22.2, but you have numba-cuda 0.30.2 which is incompatible.

# %%
# ── Cell 2: Imports and device setup ─────────────────────────────────────────
import torch
import torch.nn.functional as F
import re
import numpy as np
import pandas as pd
from transformers import AutoTokenizer, AutoModelForSequenceClassification
from datasets import load_dataset

device = "cuda" if torch.cuda.is_available() else "cpu"
print(f"Using device: {device}")
# Out:
# Using device: cuda

# %%
# ── Cell 3: Load dataset — identical split to RDS ────────────────────────────
# First 50 tweets = validation (used for hyperparameter tuning in RDS).
# Tweets 51–784 (index 50–783) = held-out test set → N=734.
# This exactly mirrors the RDS evaluation protocol.

print("Loading TweetEval Irony dataset...")
dataset   = load_dataset("tweet_eval", "irony")
test_data = dataset['test']

VAL_SIZE  = 50
val_data  = test_data.select(range(VAL_SIZE))
eval_data = test_data.select(range(VAL_SIZE, len(test_data)))  # N=734

print(f"Validation split : {len(val_data)} tweets  (indices 0–{VAL_SIZE-1})")
print(f"Test split       : {len(eval_data)} tweets  (indices {VAL_SIZE}–{len(test_data)-1})")
# Out:
# Loading TweetEval Irony dataset...
# README.md: 0.00B [00:00, ?B/s]
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# irony/train-00000-of-00001.parquet:   0%|          | 0.00/183k [00:00<?, ?B/s]
# irony/test-00000-of-00001.parquet:   0%|          | 0.00/54.0k [00:00<?, ?B/s]
# irony/validation-00000-of-00001.parquet:   0%|          | 0.00/61.1k [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/2862 [00:00<?, ? examples/s]
# Generating test split:   0%|          | 0/784 [00:00<?, ? examples/s]
# Generating validation split:   0%|          | 0/955 [00:00<?, ? examples/s]
# Validation split : 50 tweets  (indices 0–49)
# Test split       : 734 tweets  (indices 50–783)

# %%
# ── Cell 4: Load RoBERTa classifier — identical to RDS ───────────────────────
print("Loading RoBERTa classifier...")
roberta_name  = "cardiffnlp/twitter-roberta-base-irony"
rob_tokenizer = AutoTokenizer.from_pretrained(roberta_name)
rob_model     = AutoModelForSequenceClassification.from_pretrained(roberta_name).to(device)
rob_model.eval()
print("RoBERTa loaded.")
# Out:
# Loading RoBERTa classifier...
# config.json:   0%|          | 0.00/705 [00:00<?, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/150 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/499M [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/201 [00:00<?, ?it/s]
# RobertaForSequenceClassification LOAD REPORT from: cardiffnlp/twitter-roberta-base-irony
# Key                             | Status     |  |
# --------------------------------+------------+--+-
# roberta.embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# model.safetensors:   0%|          | 0.00/499M [00:00<?, ?B/s]
# RoBERTa loaded.

# %%
# ── Cell 5: Symbolic Prior — exact copy from RDS (Cell 9/11 of original) ─────
# No changes to regexes, weights, or logic. This is the identical module.

# Definitive author-labeled irony markers
_STRONG_IRONY_RE = re.compile(
    r"#(not|sarcasm|sarcastic|irony|ironic|jk|justkidding|kms|killme|"
    r"killusslow|obviously|surenot|yeahright|fml|eyeroll)\b",
    re.IGNORECASE
)

# Softer hashtag signals
_WEAK_IRONY_RE = re.compile(
    r"#(humor|lol|smh|seriously|really|wow|sure|totally|great|wonderful)\b",
    re.IGNORECASE
)

# Positive emoji immediately followed by a negative emoji → contrast
_EMOJI_CONTRAST_RE = re.compile(
    r"[\U0001F60A\U0001F604\U0001F600\U0001F44D\U00002764\U0001F642\U0001F601]"
    r"\s{0,3}[|,\s]*\s{0,3}"
    r"[\U0001F612\U0001F624\U0001F621\U0001F61E\U0001F611\U0001F644\U0001F614\U0001F622]"
)

# Letter elongation: "Loooove", "Soooo" (3+ repeated chars)
_ELONGATION_RE = re.compile(r"([a-zA-Z])\1{2,}")


def detect_explicit_irony_signal(tweet_text: str) -> float:
    """
    Exact replica of the symbolic prior from RDS.

    Returns:
      0.88  → Strong signal (#not, #sarcasm, etc.)   [ρ_strong]
      0–0.70 → Weak composite signal                 [ρ_cap = 0.70]
      0.0   → No explicit signal

    Parameter values (identical to RDS paper Section 4.3):
      ρ_strong = 0.88
      ρ_weak   = 0.15
      ρ_emoji  = 0.25
      ρ_elong  = 0.12
      ρ_cap    = 0.70
      η        = 3  (min repeated chars for elongation)
    """
    if _STRONG_IRONY_RE.search(tweet_text):
        return 0.88  # ρ_strong

    score = 0.0
    if _WEAK_IRONY_RE.search(tweet_text):
        score += 0.15  # ρ_weak
    if _EMOJI_CONTRAST_RE.search(tweet_text):
        score += 0.25  # ρ_emoji
    if _ELONGATION_RE.search(tweet_text):
        score += 0.12  # ρ_elong

    return min(score, 0.70)  # ρ_cap


print("Symbolic prior module loaded (identical to RDS).")
# Out:
# Symbolic prior module loaded (identical to RDS).

# %%
# ── Cell 6: RoBERTa classifier helper ────────────────────────────────────────
# Identical to classify_tweet() in RDS.

def classify_tweet(tweet_text: str):
    """Returns (predicted_class, p_ironic) from RoBERTa."""
    inputs = rob_tokenizer(
        tweet_text, return_tensors="pt",
        truncation=True, max_length=128
    ).to(device)
    with torch.no_grad():
        outputs = rob_model(**inputs)
    probs      = F.softmax(outputs.logits, dim=-1).squeeze().cpu()
    p_ironic   = probs[1].item()
    prediction = int(p_ironic >= 0.5)
    return prediction, p_ironic


print("RoBERTa helper loaded.")
# Out:
# RoBERTa helper loaded.

# %%
# ── Cell 7: Ablation fusion — RoBERTa + Hashtag Prior, no CoT ────────────────
#
# Fusion logic mirrors RDS Phase 3 (Prior Injection, Section 3.7) exactly:
#   Strong signal  → α ← min(α, α_cap=0.30), p_fused = ω_strong*p_base + (1-ω_strong)*prior
#   Weak signal    → p_fused = ω_weak*p_base + (1-ω_weak)*prior
#   No signal      → p_fused = p_roberta  (pure RoBERTa, no CoT to blend)
#
# The only structural difference from full RDS:
#   - p_base is always p_roberta (there is no p_cot to blend in)
#   - α is fixed at 1.0 for the base fusion (100% RoBERTa weight)
#   - Entropy budgeter and gradient guardian are not run
#
# Numerical parameters (identical to RDS Section 4.3):
#   ω_strong = 0.60,  α_cap = 0.30,  ω_weak = 0.75

OMEGA_STRONG = 0.60   # blend weight for p_base under strong prior (RDS: ωstrong)
ALPHA_CAP    = 0.30   # max RoBERTa trust when strong prior fires  (RDS: αcap)
OMEGA_WEAK   = 0.75   # blend weight for p_fused under weak prior  (RDS: ωweak)


def ablation_classify(tweet_text: str):
    """
    RoBERTa + Hashtag Prior classifier (no CoT, no entropy, no compression).

    Returns:
        prediction    : int   — 0 (non-ironic) or 1 (ironic)
        p_roberta     : float — raw RoBERTa ironic probability
        hashtag_prior : float — symbolic prior score
        p_fused       : float — final fused probability
    """
    _, p_roberta     = classify_tweet(tweet_text)
    hashtag_prior    = detect_explicit_irony_signal(tweet_text)

    # Base: RoBERTa only (α = 1.0, no CoT)
    p_base = p_roberta

    if hashtag_prior >= 0.88:  # strong signal threshold = ρ_strong
        # Cap RoBERTa trust, recompute base with capped alpha, then blend prior
        # In RDS the cap reduces RoBERTa weight to make room for CoT.
        # Here CoT = 0, so effectively: p_base_capped = ALPHA_CAP * p_roberta + (1-ALPHA_CAP)*0.5
        # But to stay maximally faithful to RDS intent, we treat p_cot = 0.5 (neutral)
        # when CoT is absent — this is the most conservative honest assumption.
        p_cot_neutral = 0.5
        p_base_capped = ALPHA_CAP * p_roberta + (1 - ALPHA_CAP) * p_cot_neutral
        p_fused       = OMEGA_STRONG * p_base_capped + (1 - OMEGA_STRONG) * hashtag_prior

    elif hashtag_prior > 0.0:  # weak signal
        p_fused = OMEGA_WEAK * p_base + (1 - OMEGA_WEAK) * hashtag_prior

    else:  # no signal — pure RoBERTa
        p_fused = p_base

    prediction = int(p_fused >= 0.5)
    return prediction, p_roberta, hashtag_prior, p_fused


print("Ablation fusion function loaded.")
# Out:
# Ablation fusion function loaded.

# %%
# ── Cell 8: Run on validation split (first 50) ───────────────────────────────
# Mirrors the RDS validation protocol. Useful for sanity-checking but
# no hyperparameters are tuned here — we use RDS values as-is.

print("Running ablation on VALIDATION split (N=50)...\n")

val_correct = 0
for i in range(len(val_data)):
    tweet      = val_data[i]["text"]
    true_label = val_data[i]["label"]
    pred, p_rob, htag, p_fused = ablation_classify(tweet)
    if pred == true_label:
        val_correct += 1

val_acc = val_correct / len(val_data) * 100
print(f"Validation Accuracy: {val_acc:.1f}%  ({val_correct}/{len(val_data)})")
print("(RDS validation accuracy was 88.0% — difference here isolates CoT contribution on val set)")
# Out:
# Running ablation on VALIDATION split (N=50)...
#
# Validation Accuracy: 90.0%  (45/50)
# (RDS validation accuracy was 88.0% — difference here isolates CoT contribution on val set)

# %%
# ── Cell 9: Main evaluation loop — held-out test set (N=734) ─────────────────

from sklearn.metrics import (
    accuracy_score, f1_score, precision_score,
    recall_score, confusion_matrix, classification_report
)

print(f"Running ablation on TEST split (N={len(eval_data)})...\n")
print(f"{'='*70}")

results_list        = []
correct_predictions = 0

for i in range(len(eval_data)):
    tweet      = eval_data[i]["text"]
    true_label = eval_data[i]["label"]

    pred, p_rob, htag, p_fused = ablation_classify(tweet)

    is_correct = (pred == true_label)
    if is_correct:
        correct_predictions += 1

    total_so_far = i + 1
    running_acc  = correct_predictions / total_so_far * 100
    htag_str     = f" | HTag={htag:.2f}" if htag > 0.0 else ""

    print(
        f"--- Tweet {i+1}: {tweet[:55]}... ---\n"
        f"  RoBERTa={p_rob:.3f}{htag_str} | Fused={p_fused:.3f} "
        f"| Pred={pred} | True={true_label} "
        f"| {'✅' if is_correct else '❌'} "
        f" [{correct_predictions}/{total_so_far} = {running_acc:.1f}%]"
    )

    results_list.append({
        "Tweet"            : tweet[:40] + "...",
        "True"             : true_label,
        "Pred"             : pred,
        "Correct"          : "✅" if is_correct else "❌",
        "RoBERTa P(ironic)": round(p_rob,   3),
        "HTag Prior"       : round(htag,    3),
        "Fused P(ironic)"  : round(p_fused, 3),
    })

print(f"\n{'='*70}")
# Out:
# Running ablation on TEST split (N=734)...
#
# ======================================================================
# --- Tweet 1: Rangers league game with Alloa moved because of the Pet... ---
#   RoBERTa=0.565 | HTag=0.88 | Fused=0.664 | Pred=1 | True=1 | ✅  [1/1 = 100.0%]
# --- Tweet 2: How to Find a Life Coach (& the questions you need to a... ---
#   RoBERTa=0.033 | Fused=0.033 | Pred=0 | True=0 | ✅  [2/2 = 100.0%]
# --- Tweet 3: I wonder what was the holiday rituals for true Africans... ---
#   RoBERTa=0.209 | Fused=0.209 | Pred=0 | True=0 | ✅  [3/3 = 100.0%]
# --- Tweet 4: Been at the ER now since 10... #yay #not... ---
#   RoBERTa=0.344 | HTag=0.88 | Fused=0.624 | Pred=1 | True=1 | ✅  [4/4 = 100.0%]
# --- Tweet 5: @user Suhs been clean for 2 years and has only been in ... ---
#   RoBERTa=0.041 | HTag=0.88 | Fused=0.569 | Pred=1 | True=0 | ❌  [4/5 = 80.0%]
# --- Tweet 6: @user @user thank you studs for perfecting and teaching... ---
#   RoBERTa=0.643 | Fused=0.643 | Pred=1 | True=0 | ❌  [4/6 = 66.7%]
# --- Tweet 7: Haley approves of her new hammock 🐭 #ratsofinstagram... ---
#   RoBERTa=0.187 | Fused=0.187 | Pred=0 | True=0 | ✅  [5/7 = 71.4%]
# --- Tweet 8: 30 years on, people still haven't got justice they dese... ---
#   RoBERTa=0.915 | HTag=0.88 | Fused=0.727 | Pred=1 | True=1 | ✅  [6/8 = 75.0%]
# --- Tweet 9: Pips who drop out of school n have Kirya as 'eir role m... ---
#   RoBERTa=0.289 | HTag=0.88 | Fused=0.614 | Pred=1 | True=0 | ❌  [6/9 = 66.7%]
# --- Tweet 10: Free Pets and Animals Books #freebiebookdownload #Pets... ---
#   RoBERTa=0.155 | Fused=0.155 | Pred=0 | True=0 | ✅  [7/10 = 70.0%]
# --- Tweet 11: @user There will be no next employer in NFL for Trestma... ---
#   RoBERTa=0.081 | Fused=0.081 | Pred=0 | True=0 | ✅  [8/11 = 72.7%]
# --- Tweet 12: Loooovvveeeeeee when my phone gets wiped -.- #not... ---
#   RoBERTa=0.306 | HTag=0.88 | Fused=0.617 | Pred=1 | True=1 | ✅  [9/12 = 75.0%]
# --- Tweet 13: Painting all cops with a broad brush because of the act... ---
#   RoBERTa=0.861 | HTag=0.88 | Fused=0.717 | Pred=1 | True=1 | ✅  [10/13 = 76.9%]
# --- Tweet 14: Don't know if I can handle this crazy 11-2 shift. It's ... ---
#   RoBERTa=0.084 | HTag=0.88 | Fused=0.577 | Pred=1 | True=1 | ✅  [11/14 = 78.6%]
# --- Tweet 15: I just love being ignored😊|#not😒... ---
#   RoBERTa=0.180 | HTag=0.88 | Fused=0.594 | Pred=1 | True=1 | ✅  [12/15 = 80.0%]
# --- Tweet 16: #Irony RT @user If you're going to give someone a scath... ---
#   RoBERTa=0.295 | HTag=0.88 | Fused=0.615 | Pred=1 | True=1 | ✅  [13/16 = 81.2%]
# --- Tweet 17: Produce Mobile Apps #not... ---
#   RoBERTa=0.319 | HTag=0.88 | Fused=0.619 | Pred=1 | True=1 | ✅  [14/17 = 82.4%]
# --- Tweet 18: Decide that you want it more than you are afraid of it.... ---
#   RoBERTa=0.077 | HTag=0.88 | Fused=0.576 | Pred=1 | True=1 | ✅  [15/18 = 83.3%]
# --- Tweet 19: Finally finished the first season of #VeronicaMars. Mov... ---
#   RoBERTa=0.103 | Fused=0.103 | Pred=0 | True=0 | ✅  [16/19 = 84.2%]
# --- Tweet 20: Merry Christmas to all those soldiers out there that co... ---
#   RoBERTa=0.041 | Fused=0.041 | Pred=0 | True=0 | ✅  [17/20 = 85.0%]
# --- Tweet 21: About as relevant as Michael Sam and Jason Collins. RT ... ---
#   RoBERTa=0.788 | Fused=0.788 | Pred=1 | True=0 | ❌  [17/21 = 81.0%]
# --- Tweet 22: Getting Final Jeopardy correct on Kids Jeopardy boosts ... ---
#   RoBERTa=0.966 | Fused=0.966 | Pred=1 | True=0 | ❌  [17/22 = 77.3%]
# --- Tweet 23: itsfunny bc people think im quiet|but im just listening... ---
#   RoBERTa=0.093 | HTag=0.88 | Fused=0.579 | Pred=1 | True=1 | ✅  [18/23 = 78.3%]
# --- Tweet 24: Woke Up , showered , made a lunch and got ready for wor... ---
#   RoBERTa=0.603 | Fused=0.603 | Pred=1 | True=0 | ❌  [18/24 = 75.0%]
# --- Tweet 25: @user @user @user @user @user How many of those jobs ea... ---
#   RoBERTa=0.096 | Fused=0.096 | Pred=0 | True=0 | ✅  [19/25 = 76.0%]
# --- Tweet 26: I reckon straight women fancy victoria secret models mo... ---
#   RoBERTa=0.879 | HTag=0.88 | Fused=0.720 | Pred=1 | True=1 | ✅  [20/26 = 76.9%]
# --- Tweet 27: Incredible insight on the @user #bornrisky campaign: #a... ---
#   RoBERTa=0.311 | Fused=0.311 | Pred=0 | True=0 | ✅  [21/27 = 77.8%]
# --- Tweet 28: Love #hiphop mix tapes or have a mixtape to promote che... ---
#   RoBERTa=0.057 | Fused=0.057 | Pred=0 | True=0 | ✅  [22/28 = 78.6%]
# --- Tweet 29: Extended cut "NICHA" #trailer #spoof #film #dramatic #a... ---
#   RoBERTa=0.210 | Fused=0.210 | Pred=0 | True=0 | ✅  [23/29 = 79.3%]
# --- Tweet 30: @user Stunning work. #british #textiles #footwear #made... ---
#   RoBERTa=0.378 | HTag=0.88 | Fused=0.630 | Pred=1 | True=0 | ❌  [23/30 = 76.7%]
# --- Tweet 31: @user @user Sent it but too slow. I had already posted.... ---
#   RoBERTa=0.046 | Fused=0.046 | Pred=0 | True=0 | ✅  [24/31 = 77.4%]
# --- Tweet 32: #FEMALECONDOM #anally #vaginally #prevent STD's/HIV/pre... ---
#   RoBERTa=0.160 | HTag=0.88 | Fused=0.591 | Pred=1 | True=0 | ❌  [24/32 = 75.0%]
# --- Tweet 33: Little cutie #Chico #Dog #Doggy #Puppy #Sweet #Cute #UK... ---
#   RoBERTa=0.092 | HTag=0.88 | Fused=0.578 | Pred=1 | True=0 | ❌  [24/33 = 72.7%]
# --- Tweet 34: @user Niagra Falls tho... Really? #irony #LOL... ---
#   RoBERTa=0.217 | HTag=0.88 | Fused=0.601 | Pred=1 | True=1 | ✅  [25/34 = 73.5%]
# --- Tweet 35: If we win against Poland and Scotland, does that put us... ---
#   RoBERTa=0.114 | HTag=0.88 | Fused=0.583 | Pred=1 | True=1 | ✅  [26/35 = 74.3%]
# --- Tweet 36: #Myanmar #men #plead #not #guilty to #murder of #Britis... ---
#   RoBERTa=0.209 | HTag=0.88 | Fused=0.600 | Pred=1 | True=0 | ❌  [26/36 = 72.2%]
# --- Tweet 37: Since the tribunal was established 14 years ago, no com... ---
#   RoBERTa=0.561 | HTag=0.88 | Fused=0.663 | Pred=1 | True=1 | ✅  [27/37 = 73.0%]
# --- Tweet 38: @user Garner protesters chant 'F*ck Fox News' despite F... ---
#   RoBERTa=0.812 | HTag=0.88 | Fused=0.708 | Pred=1 | True=1 | ✅  [28/38 = 73.7%]
# --- Tweet 39: @user After 1989, why did NATO need to expand?... ---
#   RoBERTa=0.169 | Fused=0.169 | Pred=0 | True=0 | ✅  [29/39 = 74.4%]
# --- Tweet 40: The #Irony of playing this song on my way to #work |#No... ---
#   RoBERTa=0.204 | HTag=0.88 | Fused=0.599 | Pred=1 | True=1 | ✅  [30/40 = 75.0%]
# --- Tweet 41: You are taking your responsibilities so seriously today... ---
#   RoBERTa=0.767 | Fused=0.767 | Pred=1 | True=0 | ❌  [30/41 = 73.2%]
# --- Tweet 42: @user @user @user @user @user we get it right for busin... ---
#   RoBERTa=0.473 | HTag=0.88 | Fused=0.647 | Pred=1 | True=1 | ✅  [31/42 = 73.8%]
# --- Tweet 43: can you not understand that not EVERYTHING is about the... ---
#   RoBERTa=0.070 | Fused=0.070 | Pred=0 | True=0 | ✅  [32/43 = 74.4%]
# --- Tweet 44: When you're in the doctors waiting room and hear a baby... ---
#   RoBERTa=0.971 | HTag=0.88 | Fused=0.737 | Pred=1 | True=1 | ✅  [33/44 = 75.0%]
# --- Tweet 45: Well now the festive season has begun, let's take a mom... ---
#   RoBERTa=0.616 | HTag=0.88 | Fused=0.673 | Pred=1 | True=1 | ✅  [34/45 = 75.6%]
# --- Tweet 46: The last day of the year and I will be tweeting on my m... ---
#   RoBERTa=0.133 | Fused=0.133 | Pred=0 | True=0 | ✅  [35/46 = 76.1%]
# --- Tweet 47: MB forgot to move the elf on shelf and now 10 is asking... ---
#   RoBERTa=0.629 | Fused=0.629 | Pred=1 | True=0 | ❌  [35/47 = 74.5%]
# --- Tweet 48: @user happy new year, da! Thanks sobra for this year 👍👍... ---
#   RoBERTa=0.095 | Fused=0.095 | Pred=0 | True=0 | ✅  [36/48 = 75.0%]
# --- Tweet 49: WATCH: #Megatron from #Transformers Rant About Social M... ---
#   RoBERTa=0.515 | HTag=0.88 | Fused=0.655 | Pred=1 | True=0 | ❌  [36/49 = 73.5%]
# --- Tweet 50: @user @user #not #working when are we able to download ... ---
#   RoBERTa=0.075 | HTag=0.88 | Fused=0.575 | Pred=1 | True=0 | ❌  [36/50 = 72.0%]
# --- Tweet 51: I just wrote a 13 page paper... I was awfully tired whe... ---
#   RoBERTa=0.273 | HTag=0.88 | Fused=0.611 | Pred=1 | True=1 | ✅  [37/51 = 72.5%]
# --- Tweet 52: @user happy birthday Skip! We will always love you! #Ph... ---
#   RoBERTa=0.036 | Fused=0.036 | Pred=0 | True=0 | ✅  [38/52 = 73.1%]
# --- Tweet 53: or a trout, or northern pike|@brownbearmike1 @user @use... ---
#   RoBERTa=0.034 | Fused=0.034 | Pred=0 | True=0 | ✅  [39/53 = 73.6%]
# --- Tweet 54: One of my favorite things to do is to make people wonde... ---
#   RoBERTa=0.411 | Fused=0.411 | Pred=0 | True=0 | ✅  [40/54 = 74.1%]
# --- Tweet 55: Watching Sanjay, @user ... Getting the start vs. Butler... ---
#   RoBERTa=0.042 | Fused=0.042 | Pred=0 | True=0 | ✅  [41/55 = 74.5%]
# --- Tweet 56: There's no better way to start the week than to get you... ---
#   RoBERTa=0.962 | HTag=0.88 | Fused=0.735 | Pred=1 | True=1 | ✅  [42/56 = 75.0%]
# --- Tweet 57: The most exciting way to start a Friday: a presentation... ---
#   RoBERTa=0.977 | HTag=0.88 | Fused=0.738 | Pred=1 | True=1 | ✅  [43/57 = 75.4%]
# --- Tweet 58: New shirt #new #shirt #im #sorry #its #just #i #literal... ---
#   RoBERTa=0.116 | HTag=0.88 | Fused=0.583 | Pred=1 | True=0 | ❌  [43/58 = 74.1%]
# --- Tweet 59: @user @user @user It wasn't for one person. It was a bu... ---
#   RoBERTa=0.047 | Fused=0.047 | Pred=0 | True=0 | ✅  [44/59 = 74.6%]
# --- Tweet 60: HAHAHAHA!! Oops.......I'm addicted to @user Tweets sooo... ---
#   RoBERTa=0.347 | HTag=0.88 | Fused=0.624 | Pred=1 | True=0 | ❌  [44/60 = 73.3%]
# --- Tweet 61: @user @user @user absolutely loved it! Well done all in... ---
#   RoBERTa=0.135 | Fused=0.135 | Pred=0 | True=0 | ✅  [45/61 = 73.8%]
# --- Tweet 62: @user That was the case, not the recording.So comparing... ---
#   RoBERTa=0.049 | Fused=0.049 | Pred=0 | True=0 | ✅  [46/62 = 74.2%]
# --- Tweet 63: Wow...lol||Need cash in your hands today? Go to #not #w... ---
#   RoBERTa=0.114 | HTag=0.88 | Fused=0.582 | Pred=1 | True=0 | ❌  [46/63 = 73.0%]
# --- Tweet 64: At least I don't have to clean the floor... ---
#   RoBERTa=0.950 | Fused=0.950 | Pred=1 | True=0 | ❌  [46/64 = 71.9%]
# --- Tweet 65: Incidentally the foreword for movie #BhopalAPrayerForRa... ---
#   RoBERTa=0.753 | HTag=0.88 | Fused=0.697 | Pred=1 | True=1 | ✅  [47/65 = 72.3%]
# --- Tweet 66: @user Our 3 losses followed bye weeks & an FCS team. Do... ---
#   RoBERTa=0.057 | HTag=0.88 | Fused=0.572 | Pred=1 | True=1 | ✅  [48/66 = 72.7%]
# --- Tweet 67: #AskSuperwomanLIVE if you could swim in any liquid besi... ---
#   RoBERTa=0.025 | Fused=0.025 | Pred=0 | True=0 | ✅  [49/67 = 73.1%]
# --- Tweet 68: One of the most embarrassing losses @user Ever. #WTF... ---
#   RoBERTa=0.330 | Fused=0.330 | Pred=0 | True=0 | ✅  [50/68 = 73.5%]
# --- Tweet 69: @user untrue - its Cutler's fault... ---
#   RoBERTa=0.101 | Fused=0.101 | Pred=0 | True=0 | ✅  [51/69 = 73.9%]
# --- Tweet 70: #Malala Yousufzai receives #NobelPeacePrize and #Pakist... ---
#   RoBERTa=0.912 | HTag=0.88 | Fused=0.726 | Pred=1 | True=1 | ✅  [52/70 = 74.3%]
# --- Tweet 71: #Not so Ugly Christmas Sweater red with red snowflakes ... ---
#   RoBERTa=0.032 | HTag=0.88 | Fused=0.568 | Pred=1 | True=0 | ❌  [52/71 = 73.2%]
# --- Tweet 72: Testing water temperatures #excitingtimes #Not... ---
#   RoBERTa=0.566 | HTag=0.88 | Fused=0.664 | Pred=1 | True=1 | ✅  [53/72 = 73.6%]
# --- Tweet 73: Waking up with your cat attacking your hand is always d... ---
#   RoBERTa=0.954 | HTag=0.88 | Fused=0.734 | Pred=1 | True=1 | ✅  [54/73 = 74.0%]
# --- Tweet 74: May not have hung out with you as much as some people, ... ---
#   RoBERTa=0.041 | Fused=0.041 | Pred=0 | True=0 | ✅  [55/74 = 74.3%]
# --- Tweet 75: @user the #USA is #NOT a #Democracy. The #USA is a #Rep... ---
#   RoBERTa=0.101 | HTag=0.88 | Fused=0.580 | Pred=1 | True=0 | ❌  [55/75 = 73.3%]
# --- Tweet 76: I blame my mom. Mother of the Year #sarcasm... ---
#   RoBERTa=0.414 | HTag=0.88 | Fused=0.637 | Pred=1 | True=1 | ✅  [56/76 = 73.7%]
# --- Tweet 77: Pulling my books out to prepare to organize my new book... ---
#   RoBERTa=0.300 | HTag=0.88 | Fused=0.616 | Pred=1 | True=1 | ✅  [57/77 = 74.0%]
# --- Tweet 78: @user @user To be fair, you didn't use the mandatory #s... ---
#   RoBERTa=0.155 | HTag=0.88 | Fused=0.590 | Pred=1 | True=0 | ❌  [57/78 = 73.1%]
# --- Tweet 79: 'I like the hope Jan Ellis writes with, the precision o... ---
#   RoBERTa=0.136 | HTag=0.88 | Fused=0.586 | Pred=1 | True=0 | ❌  [57/79 = 72.2%]
# --- Tweet 80: Girls just wanna have fun#work#not#friends#only#dance#d... ---
#   RoBERTa=0.232 | HTag=0.88 | Fused=0.604 | Pred=1 | True=0 | ❌  [57/80 = 71.2%]
# --- Tweet 81: The Bay Area storm is so big that tons of people's work... ---
#   RoBERTa=0.924 | HTag=0.88 | Fused=0.728 | Pred=1 | True=1 | ✅  [58/81 = 71.6%]
# --- Tweet 82: @user I'm from the UK and I honestly think your a godde... ---
#   RoBERTa=0.054 | Fused=0.054 | Pred=0 | True=0 | ✅  [59/82 = 72.0%]
# --- Tweet 83: Leaving whilst its dark is fun. #not... ---
#   RoBERTa=0.810 | HTag=0.88 | Fused=0.708 | Pred=1 | True=1 | ✅  [60/83 = 72.3%]
# --- Tweet 84: @user please note #sarcasm in last tweet before you kil... ---
#   RoBERTa=0.131 | HTag=0.88 | Fused=0.586 | Pred=1 | True=0 | ❌  [60/84 = 71.4%]
# --- Tweet 85: @user my mum to be back with us for Xmas 🎄... ---
#   RoBERTa=0.037 | Fused=0.037 | Pred=0 | True=0 | ✅  [61/85 = 71.8%]
# --- Tweet 86: @user Even though @user got more ex-wives than @user ma... ---
#   RoBERTa=0.253 | HTag=0.88 | Fused=0.607 | Pred=1 | True=1 | ✅  [62/86 = 72.1%]
# --- Tweet 87: @user Ucan MAKE MONEY #TWEETING this info w/ new app||h... ---
#   RoBERTa=0.087 | Fused=0.087 | Pred=0 | True=0 | ✅  [63/87 = 72.4%]
# --- Tweet 88: Take me tooooo church #not... ---
#   RoBERTa=0.034 | HTag=0.88 | Fused=0.568 | Pred=1 | True=0 | ❌  [63/88 = 71.6%]
# --- Tweet 89: A 'republican move' which will 'effectively rob the roy... ---
#   RoBERTa=0.500 | HTag=0.88 | Fused=0.652 | Pred=1 | True=1 | ✅  [64/89 = 71.9%]
# --- Tweet 90: #obama @user announce special urgent package for #Pakis... ---
#   RoBERTa=0.856 | HTag=0.88 | Fused=0.716 | Pred=1 | True=1 | ✅  [65/90 = 72.2%]
# --- Tweet 91: @user Shirota Yu and... Inoue Yoshio? He was in Mozart!... ---
#   RoBERTa=0.114 | Fused=0.114 | Pred=0 | True=0 | ✅  [66/91 = 72.5%]
# --- Tweet 92: Looking for quality music check> @user hot record "What... ---
#   RoBERTa=0.030 | Fused=0.030 | Pred=0 | True=0 | ✅  [67/92 = 72.8%]
# --- Tweet 93: how is it possible that somebody so interesting is also... ---
#   RoBERTa=0.087 | HTag=0.88 | Fused=0.578 | Pred=1 | True=1 | ✅  [68/93 = 73.1%]
# --- Tweet 94: @user Not going this time, we might have a chance! Fool... ---
#   RoBERTa=0.068 | Fused=0.068 | Pred=0 | True=0 | ✅  [69/94 = 73.4%]
# --- Tweet 95: @user Minky Wale tail fritter for price of a bijoux fla... ---
#   RoBERTa=0.063 | Fused=0.063 | Pred=0 | True=0 | ✅  [70/95 = 73.7%]
# --- Tweet 96: .@ibnlive is the first to cut to ads during primetime t... ---
#   RoBERTa=0.960 | HTag=0.88 | Fused=0.735 | Pred=1 | True=1 | ✅  [71/96 = 74.0%]
# --- Tweet 97: .@ChrisBrett2 @user @user @user I think it's your white... ---
#   RoBERTa=0.164 | HTag=0.88 | Fused=0.591 | Pred=1 | True=1 | ✅  [72/97 = 74.2%]
# --- Tweet 98: #hi #good #morning #instadaily #snapchat #selfie #comme... ---
#   RoBERTa=0.126 | HTag=0.88 | Fused=0.585 | Pred=1 | True=0 | ❌  [72/98 = 73.5%]
# --- Tweet 99: I JUST WANT TO BE DONE WITH FINALS #4hoursleft... ---
#   RoBERTa=0.052 | Fused=0.052 | Pred=0 | True=0 | ✅  [73/99 = 73.7%]
# --- Tweet 100: 1 bed flat #ToLet £550 pcm (£127 pw)|Humphrey Middlemor... ---
#   RoBERTa=0.047 | Fused=0.047 | Pred=0 | True=0 | ✅  [74/100 = 74.0%]
# --- Tweet 101: So there used to be a crossfit place here.... #irony #p... ---
#   RoBERTa=0.909 | HTag=0.88 | Fused=0.726 | Pred=1 | True=1 | ✅  [75/101 = 74.3%]
# --- Tweet 102: When I start singing songs from Once More With Feeling ... ---
#   RoBERTa=0.676 | Fused=0.676 | Pred=1 | True=0 | ❌  [75/102 = 73.5%]
# --- Tweet 103: I'm heading off, but need to say this! "Just because I ... ---
#   RoBERTa=0.087 | HTag=0.88 | Fused=0.578 | Pred=1 | True=0 | ❌  [75/103 = 72.8%]
# --- Tweet 104: Work hard in silence; let success make the noise.... ---
#   RoBERTa=0.399 | Fused=0.399 | Pred=0 | True=0 | ✅  [76/104 = 73.1%]
# --- Tweet 105: @user @user now what has he said/done??... ---
#   RoBERTa=0.038 | Fused=0.038 | Pred=0 | True=0 | ✅  [77/105 = 73.3%]
# --- Tweet 106: Watching Alison Jackson's portfolio of work #eurobest20... ---
#   RoBERTa=0.625 | HTag=0.88 | Fused=0.674 | Pred=1 | True=1 | ✅  [78/106 = 73.6%]
# --- Tweet 107: Spending the majority of my day in and out of the docto... ---
#   RoBERTa=0.961 | HTag=0.88 | Fused=0.735 | Pred=1 | True=1 | ✅  [79/107 = 73.8%]
# --- Tweet 108: @user - p.s. strong tweet. particularly Horatio's invol... ---
#   RoBERTa=0.113 | HTag=0.12 | Fused=0.114 | Pred=0 | True=0 | ✅  [80/108 = 74.1%]
# --- Tweet 109: @user #spnews #yxe I hope you weren't driving when you ... ---
#   RoBERTa=0.211 | HTag=0.88 | Fused=0.600 | Pred=1 | True=1 | ✅  [81/109 = 74.3%]
# --- Tweet 110: My beautiful Belles #3daughters#lucky #me #havefun @ Wi... ---
#   RoBERTa=0.116 | Fused=0.116 | Pred=0 | True=0 | ✅  [82/110 = 74.5%]
# --- Tweet 111: @user Yeah thanks for messing me about and then not del... ---
#   RoBERTa=0.988 | HTag=0.88 | Fused=0.740 | Pred=1 | True=1 | ✅  [83/111 = 74.8%]
# --- Tweet 112: @user aha, but white girl drinks make me 'so so cray ti... ---
#   RoBERTa=0.359 | Fused=0.359 | Pred=0 | True=0 | ✅  [84/112 = 75.0%]
# --- Tweet 113: This is definitely me! 😁|#me #sarcastic #sarcasm #ecard... ---
#   RoBERTa=0.262 | HTag=0.88 | Fused=0.609 | Pred=1 | True=0 | ❌  [84/113 = 74.3%]
# --- Tweet 114: Christmas alone😊 how nice #not... ---
#   RoBERTa=0.608 | HTag=0.88 | Fused=0.671 | Pred=1 | True=1 | ✅  [85/114 = 74.6%]
# --- Tweet 115: work Wednesday-Sunday .. #yay #not #moneytho 😩😭💰😒... ---
#   RoBERTa=0.257 | HTag=0.88 | Fused=0.608 | Pred=1 | True=1 | ✅  [86/115 = 74.8%]
# --- Tweet 116: @user Gavy is one rude motherfucker. *Subtweets me* *Ca... ---
#   RoBERTa=0.446 | HTag=0.88 | Fused=0.642 | Pred=1 | True=1 | ✅  [87/116 = 75.0%]
# --- Tweet 117: Access to housing is not a fundamental human right, acc... ---
#   RoBERTa=0.705 | Fused=0.705 | Pred=1 | True=0 | ❌  [87/117 = 74.4%]
# --- Tweet 118: @user Been friendzoned too many times in my life, the p... ---
#   RoBERTa=0.240 | HTag=0.88 | Fused=0.605 | Pred=1 | True=1 | ✅  [88/118 = 74.6%]
# --- Tweet 119: @user You want to see something Irish!!Of all the reaso... ---
#   RoBERTa=0.618 | HTag=0.88 | Fused=0.673 | Pred=1 | True=1 | ✅  [89/119 = 74.8%]
# --- Tweet 120: And then my sister should be home from college by time ... ---
#   RoBERTa=0.879 | Fused=0.879 | Pred=1 | True=0 | ❌  [89/120 = 74.2%]
# --- Tweet 121: Oh dear, some people don't get #irony 😳... ---
#   RoBERTa=0.288 | HTag=0.88 | Fused=0.614 | Pred=1 | True=0 | ❌  [89/121 = 73.6%]
# --- Tweet 122: Yay for Fire Alarms at 3AM #not... ---
#   RoBERTa=0.980 | HTag=0.88 | Fused=0.738 | Pred=1 | True=1 | ✅  [90/122 = 73.8%]
# --- Tweet 123: I just drank a healthy, homemade, all fruit smoothie...... ---
#   RoBERTa=0.351 | HTag=0.88 | Fused=0.625 | Pred=1 | True=1 | ✅  [91/123 = 74.0%]
# --- Tweet 124: Should I buy these? And become a full time hipster? Lol... ---
#   RoBERTa=0.083 | HTag=0.88 | Fused=0.577 | Pred=1 | True=1 | ✅  [92/124 = 74.2%]
# --- Tweet 125: Just paid $2.59 for gas! #ThanksObama #sarcasm... ---
#   RoBERTa=0.891 | HTag=0.88 | Fused=0.722 | Pred=1 | True=1 | ✅  [93/125 = 74.4%]
# --- Tweet 126: You are most welcome! Loved the post :D @user... ---
#   RoBERTa=0.069 | Fused=0.069 | Pred=0 | True=0 | ✅  [94/126 = 74.6%]
# --- Tweet 127: Can't take my eyes off you|http://t.co/cKYk9vXewc via @... ---
#   RoBERTa=0.068 | Fused=0.068 | Pred=0 | True=0 | ✅  [95/127 = 74.8%]
# --- Tweet 128: I am so ready for Monday. 🙆 #sarcasm... ---
#   RoBERTa=0.831 | HTag=0.88 | Fused=0.712 | Pred=1 | True=1 | ✅  [96/128 = 75.0%]
# --- Tweet 129: @user rollins was so pissed off haha... ---
#   RoBERTa=0.393 | Fused=0.393 | Pred=0 | True=0 | ✅  [97/129 = 75.2%]
# --- Tweet 130: @user I do love a chilled night in. Saves having a hang... ---
#   RoBERTa=0.204 | Fused=0.204 | Pred=0 | True=0 | ✅  [98/130 = 75.4%]
# --- Tweet 131: @user if it got the attention of the smartass to commen... ---
#   RoBERTa=0.243 | HTag=0.88 | Fused=0.606 | Pred=1 | True=1 | ✅  [99/131 = 75.6%]
# --- Tweet 132: When you're sick and you feel bad for your cells cause ... ---
#   RoBERTa=0.738 | HTag=0.88 | Fused=0.695 | Pred=1 | True=1 | ✅  [100/132 = 75.8%]
# --- Tweet 133: Does this look properly #shaded?? I think #not :-(|#sha... ---
#   RoBERTa=0.103 | HTag=0.88 | Fused=0.580 | Pred=1 | True=0 | ❌  [100/133 = 75.2%]
# --- Tweet 134: Company profile FORGET ME NOT PET CEMETERY - #FORGET #M... ---
#   RoBERTa=0.129 | HTag=0.88 | Fused=0.585 | Pred=1 | True=0 | ❌  [100/134 = 74.6%]
# --- Tweet 135: @user guys!!! you've just smashed it!! #WhereDoBrokenHe... ---
#   RoBERTa=0.253 | Fused=0.253 | Pred=0 | True=0 | ✅  [101/135 = 74.8%]
# --- Tweet 136: i wanna be at home already... ---
#   RoBERTa=0.114 | Fused=0.114 | Pred=0 | True=0 | ✅  [102/136 = 75.0%]
# --- Tweet 137: Just realized my last final is tomorrow. FAAAAA-... ---
#   RoBERTa=0.261 | HTag=0.12 | Fused=0.226 | Pred=0 | True=0 | ✅  [103/137 = 75.2%]
# --- Tweet 138: @user @user @user @user @user Christian Europe translat... ---
#   RoBERTa=0.801 | HTag=0.88 | Fused=0.706 | Pred=1 | True=1 | ✅  [104/138 = 75.4%]
# --- Tweet 139: Aaaaaand now I've found out that Chrome slows down down... ---
#   RoBERTa=0.980 | HTag=0.88 | Fused=0.738 | Pred=1 | True=1 | ✅  [105/139 = 75.5%]
# --- Tweet 140: The fact that this time next week I'll be getting my wi... ---
#   RoBERTa=0.126 | Fused=0.126 | Pred=0 | True=0 | ✅  [106/140 = 75.7%]
# --- Tweet 141: @user Way to lay out yesterday and put it all on the li... ---
#   RoBERTa=0.666 | HTag=0.88 | Fused=0.682 | Pred=1 | True=1 | ✅  [107/141 = 75.9%]
# --- Tweet 142: Two years later & gingerbread house making still makes ... ---
#   RoBERTa=0.226 | Fused=0.226 | Pred=0 | True=0 | ✅  [108/142 = 76.1%]
# --- Tweet 143: Amar Singh gives A+ rating to the Modi govt but Arun #S... ---
#   RoBERTa=0.396 | HTag=0.88 | Fused=0.633 | Pred=1 | True=1 | ✅  [109/143 = 76.2%]
# --- Tweet 144: @user @user @user |Thats a twist|Algorithms to cause mo... ---
#   RoBERTa=0.158 | HTag=0.88 | Fused=0.590 | Pred=1 | True=1 | ✅  [110/144 = 76.4%]
# --- Tweet 145: @user #sarcasm is a service I offer.... ---
#   RoBERTa=0.390 | HTag=0.88 | Fused=0.632 | Pred=1 | True=0 | ❌  [110/145 = 75.9%]
# --- Tweet 146: #PhatSexyAss #Picnic Picnic Porked Tiffany... ---
#   RoBERTa=0.134 | Fused=0.134 | Pred=0 | True=0 | ✅  [111/146 = 76.0%]
# --- Tweet 147: I'm absolutely positive that Coaches love it when paren... ---
#   RoBERTa=0.896 | HTag=0.88 | Fused=0.723 | Pred=1 | True=1 | ✅  [112/147 = 76.2%]
# --- Tweet 148: Nice touch. All the bar staff in the ground wearing #sa... ---
#   RoBERTa=0.963 | Fused=0.963 | Pred=1 | True=0 | ❌  [112/148 = 75.7%]
# --- Tweet 149: @user trust me it will be out of form Scandinavian reef... ---
#   RoBERTa=0.075 | HTag=0.88 | Fused=0.576 | Pred=1 | True=1 | ✅  [113/149 = 75.8%]
# --- Tweet 150: i literally love when someone throw me in at the deep e... ---
#   RoBERTa=0.384 | HTag=0.88 | Fused=0.631 | Pred=1 | True=1 | ✅  [114/150 = 76.0%]
# --- Tweet 151: Agree with that... #we #are #not #mind #readers #haha||... ---
#   RoBERTa=0.139 | HTag=0.88 | Fused=0.587 | Pred=1 | True=0 | ❌  [114/151 = 75.5%]
# --- Tweet 152: Day ninth December to have a pint at the boars head|#no... ---
#   RoBERTa=0.023 | HTag=0.88 | Fused=0.566 | Pred=1 | True=0 | ❌  [114/152 = 75.0%]
# --- Tweet 153: Speed cameras in Whipton by village shops. & yes it Tak... ---
#   RoBERTa=0.292 | HTag=0.88 | Fused=0.615 | Pred=1 | True=0 | ❌  [114/153 = 74.5%]
# --- Tweet 154: Picked an excellent day to get my hair done 😒 #sarcasm... ---
#   RoBERTa=0.523 | HTag=0.88 | Fused=0.656 | Pred=1 | True=1 | ✅  [115/154 = 74.7%]
# --- Tweet 155: @user his daughter is painting his toes! That is a pare... ---
#   RoBERTa=0.918 | Fused=0.918 | Pred=1 | True=0 | ❌  [115/155 = 74.2%]
# --- Tweet 156: Can't say no to that @user try now. Lets go @user we ca... ---
#   RoBERTa=0.025 | Fused=0.025 | Pred=0 | True=0 | ✅  [116/156 = 74.4%]
# --- Tweet 157: ABC Takes A Look At "The Turkey Song" by @user - Make I... ---
#   RoBERTa=0.045 | Fused=0.045 | Pred=0 | True=0 | ✅  [117/157 = 74.5%]
# --- Tweet 158: Waking up with a pounding headache is just what I need ... ---
#   RoBERTa=0.947 | HTag=0.88 | Fused=0.732 | Pred=1 | True=1 | ✅  [118/158 = 74.7%]
# --- Tweet 159: Can always count on you to speak to me on here then del... ---
#   RoBERTa=0.643 | Fused=0.643 | Pred=1 | True=0 | ❌  [118/159 = 74.2%]
# --- Tweet 160: Stop by and pick up Alexandra's book with a coupon!... ---
#   RoBERTa=0.035 | Fused=0.035 | Pred=0 | True=0 | ✅  [119/160 = 74.4%]
# --- Tweet 161: @user I swear we must be twins... ---
#   RoBERTa=0.085 | Fused=0.085 | Pred=0 | True=0 | ✅  [120/161 = 74.5%]
# --- Tweet 162: Some days are just better than others..... ---
#   RoBERTa=0.644 | Fused=0.644 | Pred=1 | True=0 | ❌  [120/162 = 74.1%]
# --- Tweet 163: After getting a total of 4 hours of sleep in 2 days, I ... ---
#   RoBERTa=0.329 | Fused=0.329 | Pred=0 | True=0 | ✅  [121/163 = 74.2%]
# --- Tweet 164: Her name is not Superwoman, Wonder Woman, nor Dorothy f... ---
#   RoBERTa=0.294 | Fused=0.294 | Pred=0 | True=0 | ✅  [122/164 = 74.4%]
# --- Tweet 165: I didn't realize Boston Coach also operated in Chicago ... ---
#   RoBERTa=0.386 | HTag=0.88 | Fused=0.632 | Pred=1 | True=1 | ✅  [123/165 = 74.5%]
# --- Tweet 166: @user and that "somebody" thought you were Padoin siste... ---
#   RoBERTa=0.829 | Fused=0.829 | Pred=1 | True=0 | ❌  [123/166 = 74.1%]
# --- Tweet 167: Once again @user is re writing history re: #CubaEmbargo... ---
#   RoBERTa=0.942 | Fused=0.942 | Pred=1 | True=0 | ❌  [123/167 = 73.7%]
# --- Tweet 168: Wow: Look what the NFL Rams player who did "Hands Up, D... ---
#   RoBERTa=0.822 | Fused=0.822 | Pred=1 | True=0 | ❌  [123/168 = 73.2%]
# --- Tweet 169: Someone needs to stop me before I kill someone 😡 love w... ---
#   RoBERTa=0.244 | HTag=0.88 | Fused=0.606 | Pred=1 | True=1 | ✅  [124/169 = 73.4%]
# --- Tweet 170: What to do with that old #motherboard you have laying a... ---
#   RoBERTa=0.053 | HTag=0.88 | Fused=0.572 | Pred=1 | True=1 | ✅  [125/170 = 73.5%]
# --- Tweet 171: Joe Cole just casually walking past...... ---
#   RoBERTa=0.629 | Fused=0.629 | Pred=1 | True=0 | ❌  [125/171 = 73.1%]
# --- Tweet 172: Am I the only one who finds it very stressful when the ... ---
#   RoBERTa=0.126 | Fused=0.126 | Pred=0 | True=0 | ✅  [126/172 = 73.3%]
# --- Tweet 173: @user No ... now someone will start a rumor of $ABBV pr... ---
#   RoBERTa=0.505 | HTag=0.88 | Fused=0.653 | Pred=1 | True=1 | ✅  [127/173 = 73.4%]
# --- Tweet 174: Never seen the gym so packed... ---
#   RoBERTa=0.731 | Fused=0.731 | Pred=1 | True=0 | ❌  [127/174 = 73.0%]
# --- Tweet 175: ❓❓GOT MENTIONS ❓❓||#MGWV #AutoFollow #RETWEET #RTMUZZA ... ---
#   RoBERTa=0.075 | Fused=0.075 | Pred=0 | True=0 | ✅  [128/175 = 73.1%]
# --- Tweet 176: Remember to raise a glass of merry to those who are at ... ---
#   RoBERTa=0.122 | Fused=0.122 | Pred=0 | True=0 | ✅  [129/176 = 73.3%]
# --- Tweet 177: Wishing everyone a Happy, Healthy, and Prosperous New Y... ---
#   RoBERTa=0.118 | Fused=0.118 | Pred=0 | True=0 | ✅  [130/177 = 73.4%]
# --- Tweet 178: @user @user @user Yes, and conventional taxis drive ver... ---
#   RoBERTa=0.641 | HTag=0.88 | Fused=0.677 | Pred=1 | True=1 | ✅  [131/178 = 73.6%]
# --- Tweet 179: Just ranted on and the moment I'm about to hit send, my... ---
#   RoBERTa=0.555 | HTag=0.88 | Fused=0.662 | Pred=1 | True=1 | ✅  [132/179 = 73.7%]
# --- Tweet 180: 30 week scan #not #long #now #exciting #memory #all #go... ---
#   RoBERTa=0.119 | HTag=0.88 | Fused=0.583 | Pred=1 | True=0 | ❌  [132/180 = 73.3%]
# --- Tweet 181: @user Obama and Hillary convinced Ukraine that they wou... ---
#   RoBERTa=0.747 | Fused=0.747 | Pred=1 | True=0 | ❌  [132/181 = 72.9%]
# --- Tweet 182: i just enjoy throwing up #not #hatethis #sick #wanna #g... ---
#   RoBERTa=0.187 | HTag=0.88 | Fused=0.596 | Pred=1 | True=1 | ✅  [133/182 = 73.1%]
# --- Tweet 183: @user I actually think he needs to use the youngsters i... ---
#   RoBERTa=0.064 | HTag=0.88 | Fused=0.574 | Pred=1 | True=1 | ✅  [134/183 = 73.2%]
# --- Tweet 184: What a golden morning. 😒 #not... ---
#   RoBERTa=0.799 | HTag=0.88 | Fused=0.706 | Pred=1 | True=1 | ✅  [135/184 = 73.4%]
# --- Tweet 185: Sleep. SLEEP YOU STUPID IDIOT I WANNA LEAVE MY ROOM... ---
#   RoBERTa=0.062 | Fused=0.062 | Pred=0 | True=0 | ✅  [136/185 = 73.5%]
# --- Tweet 186: LIBERAL/#LEFTISTS USE #RACIST/SEXIST #LABEL FOR |#DISLI... ---
#   RoBERTa=0.272 | HTag=0.88 | Fused=0.611 | Pred=1 | True=0 | ❌  [136/186 = 73.1%]
# --- Tweet 187: Read at the news '#Obama: #The #American #way #of #life... ---
#   RoBERTa=0.133 | HTag=0.88 | Fused=0.586 | Pred=1 | True=0 | ❌  [136/187 = 72.7%]
# --- Tweet 188: Really missing my momma today.. More than usual. I don'... ---
#   RoBERTa=0.098 | Fused=0.098 | Pred=0 | True=0 | ✅  [137/188 = 72.9%]
# --- Tweet 189: @user Nevermind that, but do pray tell,would Scherzy st... ---
#   RoBERTa=0.016 | Fused=0.016 | Pred=0 | True=0 | ✅  [138/189 = 73.0%]
# --- Tweet 190: Everyone wants the truth but nobody wants to be honest.... ---
#   RoBERTa=0.533 | HTag=0.88 | Fused=0.658 | Pred=1 | True=1 | ✅  [139/190 = 73.2%]
# --- Tweet 191: I won't be surprised if shelling across pak border inte... ---
#   RoBERTa=0.732 | Fused=0.732 | Pred=1 | True=0 | ❌  [139/191 = 72.8%]
# --- Tweet 192: Every inch of you is perfect from the bottom to the top... ---
#   RoBERTa=0.069 | HTag=0.88 | Fused=0.574 | Pred=1 | True=0 | ❌  [139/192 = 72.4%]
# --- Tweet 193: Take a look at those calves!!! 😎😎😂😂 ladies love the cal... ---
#   RoBERTa=0.293 | HTag=0.88 | Fused=0.615 | Pred=1 | True=0 | ❌  [139/193 = 72.0%]
# --- Tweet 194: @user your tongue in cheek @user weigh in does nothing ... ---
#   RoBERTa=0.510 | Fused=0.510 | Pred=1 | True=0 | ❌  [139/194 = 71.6%]
# --- Tweet 195: @user You think my mom and I would get along better, sh... ---
#   RoBERTa=0.281 | HTag=0.88 | Fused=0.613 | Pred=1 | True=1 | ✅  [140/195 = 71.8%]
# --- Tweet 196: Isn't this blaming the victim? #sarcasm RT @user Every ... ---
#   RoBERTa=0.594 | HTag=0.88 | Fused=0.669 | Pred=1 | True=1 | ✅  [141/196 = 71.9%]
# --- Tweet 197: that time when ward was mad because skye hide a secret ... ---
#   RoBERTa=0.197 | HTag=0.88 | Fused=0.597 | Pred=1 | True=1 | ✅  [142/197 = 72.1%]
# --- Tweet 198: While we applauded ourselves on getting to the Moon, Ca... ---
#   RoBERTa=0.850 | HTag=0.88 | Fused=0.715 | Pred=1 | True=1 | ✅  [143/198 = 72.2%]
# --- Tweet 199: Can holidays last forever?? #happytimes #sundayout #mew... ---
#   RoBERTa=0.259 | Fused=0.259 | Pred=0 | True=0 | ✅  [144/199 = 72.4%]
# --- Tweet 200: Watching @user trich vlogs helps me alot with my trich ... ---
#   RoBERTa=0.365 | Fused=0.365 | Pred=0 | True=0 | ✅  [145/200 = 72.5%]
# --- Tweet 201: Photo: Orchid Tassel Chain Mermaid Dress $39.99 Onesize... ---
#   RoBERTa=0.037 | Fused=0.037 | Pred=0 | True=0 | ✅  [146/201 = 72.6%]
# --- Tweet 202: @user this game is pathetic. How are they losing this g... ---
#   RoBERTa=0.040 | Fused=0.040 | Pred=0 | True=0 | ✅  [147/202 = 72.8%]
# --- Tweet 203: bromanceshmomance: #I just checked and he has zero#ZERO... ---
#   RoBERTa=0.098 | HTag=0.88 | Fused=0.580 | Pred=1 | True=0 | ❌  [147/203 = 72.4%]
# --- Tweet 204: Being a light sleeper is the best. #not... ---
#   RoBERTa=0.866 | HTag=0.88 | Fused=0.718 | Pred=1 | True=1 | ✅  [148/204 = 72.5%]
# --- Tweet 205: schools in India praying for # #peshawarattack victims ... ---
#   RoBERTa=0.751 | Fused=0.751 | Pred=1 | True=0 | ❌  [148/205 = 72.2%]
# --- Tweet 206: The only company I thought would be best for the thesis... ---
#   RoBERTa=0.138 | Fused=0.138 | Pred=0 | True=0 | ✅  [149/206 = 72.3%]
# --- Tweet 207: @user not worried about it. Whenevs 😉... ---
#   RoBERTa=0.035 | Fused=0.035 | Pred=0 | True=0 | ✅  [150/207 = 72.5%]
# --- Tweet 208: @user @user #not enough; unfortunately.... ---
#   RoBERTa=0.022 | HTag=0.88 | Fused=0.566 | Pred=1 | True=0 | ❌  [150/208 = 72.1%]
# --- Tweet 209: @user . #please email me captainpc@me.com or contact th... ---
#   RoBERTa=0.071 | HTag=0.88 | Fused=0.575 | Pred=1 | True=0 | ❌  [150/209 = 71.8%]
# --- Tweet 210: @user hahaha yeah I think so too cause you know how she... ---
#   RoBERTa=0.172 | HTag=0.88 | Fused=0.593 | Pred=1 | True=1 | ✅  [151/210 = 71.9%]
# --- Tweet 211: It's really #NOT #GOOD, too have the #REPUTATION for ST... ---
#   RoBERTa=0.094 | HTag=0.88 | Fused=0.579 | Pred=1 | True=0 | ❌  [151/211 = 71.6%]
# --- Tweet 212: we need to stop using the words "racist" & "racism" @us... ---
#   RoBERTa=0.069 | Fused=0.069 | Pred=0 | True=0 | ✅  [152/212 = 71.7%]
# --- Tweet 213: @user @user Probably my favourite book. Couldn't put it... ---
#   RoBERTa=0.021 | Fused=0.021 | Pred=0 | True=0 | ✅  [153/213 = 71.8%]
# --- Tweet 214: From what I can tell...most strippers belong right wher... ---
#   RoBERTa=0.237 | Fused=0.237 | Pred=0 | True=0 | ✅  [154/214 = 72.0%]
# --- Tweet 215: @user dualistic, as in good and evil? Right, because th... ---
#   RoBERTa=0.457 | HTag=0.88 | Fused=0.644 | Pred=1 | True=1 | ✅  [155/215 = 72.1%]
# --- Tweet 216: #Consensus of Absolute Hilarious #Irony – #MichaelMann ... ---
#   RoBERTa=0.299 | HTag=0.88 | Fused=0.616 | Pred=1 | True=1 | ✅  [156/216 = 72.2%]
# --- Tweet 217: 5 dollar OBX 1 dollar Gboro gone #lockitin #lottoclub #... ---
#   RoBERTa=0.057 | HTag=0.88 | Fused=0.572 | Pred=1 | True=0 | ❌  [156/217 = 71.9%]
# --- Tweet 218: I may or may not have put @user at the top of @user tre... ---
#   RoBERTa=0.181 | HTag=0.88 | Fused=0.595 | Pred=1 | True=1 | ✅  [157/218 = 72.0%]
# --- Tweet 219: Regarding my #ATT case; I've contacted the BBB, FCC, an... ---
#   RoBERTa=0.086 | HTag=0.88 | Fused=0.577 | Pred=1 | True=0 | ❌  [157/219 = 71.7%]
# --- Tweet 220: Acronyms because we're cool as fuck. Judge me.... ---
#   RoBERTa=0.712 | Fused=0.712 | Pred=1 | True=0 | ❌  [157/220 = 71.4%]
# --- Tweet 221: Only a true nightshift person would understand this #ni... ---
#   RoBERTa=0.147 | HTag=0.88 | Fused=0.588 | Pred=1 | True=0 | ❌  [157/221 = 71.0%]
# --- Tweet 222: actually, it wasnt, it was purely economics @user @user... ---
#   RoBERTa=0.045 | Fused=0.045 | Pred=0 | True=0 | ✅  [158/222 = 71.2%]
# --- Tweet 223: Sunday is such a fun day to study #not #ew #saywhat... ---
#   RoBERTa=0.365 | HTag=0.88 | Fused=0.628 | Pred=1 | True=1 | ✅  [159/223 = 71.3%]
# --- Tweet 224: Reunited with my pump this morning. #yay #not 😣... ---
#   RoBERTa=0.150 | HTag=0.88 | Fused=0.589 | Pred=1 | True=1 | ✅  [160/224 = 71.4%]
# --- Tweet 225: My dad's still gonna get me santa's gifts since it's my... ---
#   RoBERTa=0.034 | HTag=0.88 | Fused=0.568 | Pred=1 | True=1 | ✅  [161/225 = 71.6%]
# --- Tweet 226: Remember that one time I worked both jobs while sick an... ---
#   RoBERTa=0.476 | HTag=0.88 | Fused=0.648 | Pred=1 | True=1 | ✅  [162/226 = 71.7%]
# --- Tweet 227: I'm really excited for next semester... ---
#   RoBERTa=0.850 | Fused=0.850 | Pred=1 | True=0 | ❌  [162/227 = 71.4%]
# --- Tweet 228: @user @user Actually, even delivery won't save some. O ... ---
#   RoBERTa=0.476 | Fused=0.476 | Pred=0 | True=0 | ✅  [163/228 = 71.5%]
# --- Tweet 229: good luck finding someone to take the other side of tha... ---
#   RoBERTa=0.208 | Fused=0.208 | Pred=0 | True=0 | ✅  [164/229 = 71.6%]
# --- Tweet 230: It is good that very few businesses/govts in EM economi... ---
#   RoBERTa=0.917 | HTag=0.88 | Fused=0.727 | Pred=1 | True=1 | ✅  [165/230 = 71.7%]
# --- Tweet 231: @user 🙌🙌 #fitfam #fitness #health... ---
#   RoBERTa=0.234 | Fused=0.234 | Pred=0 | True=0 | ✅  [166/231 = 71.9%]
# --- Tweet 232: GTA #San #Andreas #2 #is #not #coming #in #2015: One me... ---
#   RoBERTa=0.115 | HTag=0.88 | Fused=0.583 | Pred=1 | True=0 | ❌  [166/232 = 71.6%]
# --- Tweet 233: What a great way to start the day!! #Not 😠... ---
#   RoBERTa=0.983 | HTag=0.88 | Fused=0.739 | Pred=1 | True=1 | ✅  [167/233 = 71.7%]
# --- Tweet 234: @user I wonder what % of that 43% agree on what a priva... ---
#   RoBERTa=0.239 | Fused=0.239 | Pred=0 | True=0 | ✅  [168/234 = 71.8%]
# --- Tweet 235: If i were to ask. I want to stay here for as long as po... ---
#   RoBERTa=0.040 | Fused=0.040 | Pred=0 | True=0 | ✅  [169/235 = 71.9%]
# --- Tweet 236: @user @user @user Just wait till Cleveland comes again!... ---
#   RoBERTa=0.469 | HTag=0.88 | Fused=0.646 | Pred=1 | True=1 | ✅  [170/236 = 72.0%]
# --- Tweet 237: 'Liberated' Iraq -- 2014 One of Bloodiest Years with Mo... ---
#   RoBERTa=0.816 | HTag=0.88 | Fused=0.709 | Pred=1 | True=1 | ✅  [171/237 = 72.2%]
# --- Tweet 238: @user one hope this gets a RT! #recycling #roses #holly... ---
#   RoBERTa=0.143 | Fused=0.143 | Pred=0 | True=0 | ✅  [172/238 = 72.3%]
# --- Tweet 239: @user Tag a teammate who is so bad, he runs the line ev... ---
#   RoBERTa=0.208 | Fused=0.208 | Pred=0 | True=0 | ✅  [173/239 = 72.4%]
# --- Tweet 240: @user easiest CL group with two rubbish teams but we wo... ---
#   RoBERTa=0.045 | HTag=0.88 | Fused=0.570 | Pred=1 | True=0 | ❌  [173/240 = 72.1%]
# --- Tweet 241: No one up? Okay cool #not... ---
#   RoBERTa=0.402 | HTag=0.88 | Fused=0.634 | Pred=1 | True=1 | ✅  [174/241 = 72.2%]
# --- Tweet 242: #np #NowPlaying #NowListening #Music #Don't Let Her Pul... ---
#   RoBERTa=0.051 | HTag=0.88 | Fused=0.571 | Pred=1 | True=0 | ❌  [174/242 = 71.9%]
# --- Tweet 243: Here we go again, thanks to all that claim to cover WVH... ---
#   RoBERTa=0.442 | HTag=0.88 | Fused=0.642 | Pred=1 | True=1 | ✅  [175/243 = 72.0%]
# --- Tweet 244: Long day and its not going to be possible without my go... ---
#   RoBERTa=0.112 | Fused=0.112 | Pred=0 | True=0 | ✅  [176/244 = 72.1%]
# --- Tweet 245: Just loveeee driving upstate in the snow #not... ---
#   RoBERTa=0.719 | HTag=0.88 | Fused=0.691 | Pred=1 | True=1 | ✅  [177/245 = 72.2%]
# --- Tweet 246: If you know people who could talk power-dressing and so... ---
#   RoBERTa=0.359 | Fused=0.359 | Pred=0 | True=0 | ✅  [178/246 = 72.4%]
# --- Tweet 247: I love getting up at 4 30 so I can wait on other ppl! #... ---
#   RoBERTa=0.977 | HTag=0.88 | Fused=0.738 | Pred=1 | True=1 | ✅  [179/247 = 72.5%]
# --- Tweet 248: Faux Leather Size Zipper Sleeveless Scoop Back Midi Dre... ---
#   RoBERTa=0.033 | Fused=0.033 | Pred=0 | True=0 | ✅  [180/248 = 72.6%]
# --- Tweet 249: and as much as I want to connect .. I like only the peo... ---
#   RoBERTa=0.174 | HTag=0.88 | Fused=0.593 | Pred=1 | True=1 | ✅  [181/249 = 72.7%]
# --- Tweet 250: @user I saw a leaf blowing in the breeze. You could yel... ---
#   RoBERTa=0.098 | Fused=0.098 | Pred=0 | True=0 | ✅  [182/250 = 72.8%]
# --- Tweet 251: @user hold on a minute. Are you saying All blonde white... ---
#   RoBERTa=0.422 | HTag=0.88 | Fused=0.638 | Pred=1 | True=1 | ✅  [183/251 = 72.9%]
# --- Tweet 252: @user Gotta love those racially based awards! #not... ---
#   RoBERTa=0.956 | HTag=0.88 | Fused=0.734 | Pred=1 | True=1 | ✅  [184/252 = 73.0%]
# --- Tweet 253: The best love is the kind that awakens the soul, and ma... ---
#   RoBERTa=0.054 | Fused=0.054 | Pred=0 | True=0 | ✅  [185/253 = 73.1%]
# --- Tweet 254: clashupdate #not... ---
#   RoBERTa=0.059 | HTag=0.88 | Fused=0.573 | Pred=1 | True=1 | ✅  [186/254 = 73.2%]
# --- Tweet 255: @user Super Junior's Henry asks sasaeng fans to let him... ---
#   RoBERTa=0.136 | Fused=0.136 | Pred=0 | True=0 | ✅  [187/255 = 73.3%]
# --- Tweet 256: I have officially surrounded myself with the most amazi... ---
#   RoBERTa=0.176 | Fused=0.176 | Pred=0 | True=0 | ✅  [188/256 = 73.4%]
# --- Tweet 257: @user @user republicans suck more at identifying #irony... ---
#   RoBERTa=0.558 | HTag=0.88 | Fused=0.662 | Pred=1 | True=0 | ❌  [188/257 = 73.2%]
# --- Tweet 258: That's always the solution..... #not. Doesn't fix anyth... ---
#   RoBERTa=0.229 | HTag=0.88 | Fused=0.603 | Pred=1 | True=1 | ✅  [189/258 = 73.3%]
# --- Tweet 259: Name an #excuse that people use #NOT to #workout ...... ---
#   RoBERTa=0.316 | HTag=0.88 | Fused=0.619 | Pred=1 | True=0 | ❌  [189/259 = 73.0%]
# --- Tweet 260: @user @user @user @user @user @user "left regressives" ... ---
#   RoBERTa=0.114 | HTag=0.88 | Fused=0.583 | Pred=1 | True=1 | ✅  [190/260 = 73.1%]
# --- Tweet 261: @user but you can't expect us to hire one in only 3 wee... ---
#   RoBERTa=0.184 | HTag=0.88 | Fused=0.595 | Pred=1 | True=0 | ❌  [190/261 = 72.8%]
# --- Tweet 262: A #celebrity is a person who is known for his well-know... ---
#   RoBERTa=0.531 | HTag=0.88 | Fused=0.658 | Pred=1 | True=1 | ✅  [191/262 = 72.9%]
# --- Tweet 263: Is there a basketball game on today? I'm not really sur... ---
#   RoBERTa=0.104 | HTag=0.88 | Fused=0.581 | Pred=1 | True=1 | ✅  [192/263 = 73.0%]
# --- Tweet 264: @user @user @user We Agree #NHSENGLAND needs to #Publis... ---
#   RoBERTa=0.201 | HTag=0.88 | Fused=0.598 | Pred=1 | True=0 | ❌  [192/264 = 72.7%]
# --- Tweet 265: If you've got the world on a string, you should give me... ---
#   RoBERTa=0.325 | Fused=0.325 | Pred=0 | True=0 | ✅  [193/265 = 72.8%]
# --- Tweet 266: Christmas this Christmas that FOH its just a day people... ---
#   RoBERTa=0.496 | Fused=0.496 | Pred=0 | True=0 | ✅  [194/266 = 72.9%]
# --- Tweet 267: #Warn them that your degree of #sarcasm depends on them... ---
#   RoBERTa=0.077 | HTag=0.88 | Fused=0.576 | Pred=1 | True=0 | ❌  [194/267 = 72.7%]
# --- Tweet 268: The #Gophers aren't nervous. #SammyCommentary #Gophers... ---
#   RoBERTa=0.146 | Fused=0.146 | Pred=0 | True=0 | ✅  [195/268 = 72.8%]
# --- Tweet 269: Bitches be like ..... #more #appointments #please #not#... ---
#   RoBERTa=0.131 | HTag=0.88 | Fused=0.586 | Pred=1 | True=0 | ❌  [195/269 = 72.5%]
# --- Tweet 270: I am so glad that I woke up early for this office visit... ---
#   RoBERTa=0.743 | HTag=0.88 | Fused=0.696 | Pred=1 | True=1 | ✅  [196/270 = 72.6%]
# --- Tweet 271: #Science of the #GardenOfEden - #Eden #KentHovind #Chri... ---
#   RoBERTa=0.139 | Fused=0.139 | Pred=0 | True=0 | ✅  [197/271 = 72.7%]
# --- Tweet 272: Sickens me that killing innocent black men & children h... ---
#   RoBERTa=0.304 | Fused=0.304 | Pred=0 | True=0 | ✅  [198/272 = 72.8%]
# --- Tweet 273: 50km into the #Rapha #festive500 and we stop off for a ... ---
#   RoBERTa=0.234 | Fused=0.234 | Pred=0 | True=0 | ✅  [199/273 = 72.9%]
# --- Tweet 274: @user u do really need to get a wee bit more lol... ---
#   RoBERTa=0.049 | Fused=0.049 | Pred=0 | True=0 | ✅  [200/274 = 73.0%]
# --- Tweet 275: @user so if they undo the affordable care act, and I sh... ---
#   RoBERTa=0.136 | HTag=0.88 | Fused=0.586 | Pred=1 | True=0 | ❌  [200/275 = 72.7%]
# --- Tweet 276: @user @user #not sure who will take it home?... ---
#   RoBERTa=0.022 | HTag=0.88 | Fused=0.566 | Pred=1 | True=0 | ❌  [200/276 = 72.5%]
# --- Tweet 277: I actually just started crying while brushing my teeth ... ---
#   RoBERTa=0.934 | HTag=0.88 | Fused=0.730 | Pred=1 | True=1 | ✅  [201/277 = 72.6%]
# --- Tweet 278: Don't you just love those people who won't shut up in c... ---
#   RoBERTa=0.943 | HTag=0.88 | Fused=0.732 | Pred=1 | True=1 | ✅  [202/278 = 72.7%]
# --- Tweet 279: @user Oh, BELIEVE me. I agree totally. My tweet was pur... ---
#   RoBERTa=0.101 | HTag=0.88 | Fused=0.580 | Pred=1 | True=1 | ✅  [203/279 = 72.8%]
# --- Tweet 280: The #Congressional #report on #torture #confirms that #... ---
#   RoBERTa=0.127 | HTag=0.88 | Fused=0.585 | Pred=1 | True=0 | ❌  [203/280 = 72.5%]
# --- Tweet 281: #Sarcasm makes you mentally stronger. Which is very eff... ---
#   RoBERTa=0.431 | HTag=0.88 | Fused=0.640 | Pred=1 | True=0 | ❌  [203/281 = 72.2%]
# --- Tweet 282: Also it is funny how things at work get done when I'm o... ---
#   RoBERTa=0.948 | HTag=0.88 | Fused=0.733 | Pred=1 | True=1 | ✅  [204/282 = 72.3%]
# --- Tweet 283: @user is this a new/recent release?... ---
#   RoBERTa=0.020 | Fused=0.020 | Pred=0 | True=0 | ✅  [205/283 = 72.4%]
# --- Tweet 284: When I'm lacking inspiration I resort to scribbling ang... ---
#   RoBERTa=0.915 | HTag=0.88 | Fused=0.727 | Pred=1 | True=1 | ✅  [206/284 = 72.5%]
# --- Tweet 285: Also it's amazing how a shower and Taco Bell can make y... ---
#   RoBERTa=0.535 | Fused=0.535 | Pred=1 | True=0 | ❌  [206/285 = 72.3%]
# --- Tweet 286: Visit #Tripplebeam #Music #Promotions @ #Michigan... ---
#   RoBERTa=0.184 | Fused=0.184 | Pred=0 | True=0 | ✅  [207/286 = 72.4%]
# --- Tweet 287: 'nuff #Bob #Couldn039t #Not #Repin #Ross #tattoo|Please... ---
#   RoBERTa=0.074 | HTag=0.88 | Fused=0.575 | Pred=1 | True=0 | ❌  [207/287 = 72.1%]
# --- Tweet 288: HAPPY BIRTHDAY BECCA. I just looked through ALL of my p... ---
#   RoBERTa=0.381 | Fused=0.381 | Pred=0 | True=0 | ✅  [208/288 = 72.2%]
# --- Tweet 289: Have you lost your zing? Working too hard? Check out my... ---
#   RoBERTa=0.136 | Fused=0.136 | Pred=0 | True=0 | ✅  [209/289 = 72.3%]
# --- Tweet 290: Heartless Sanghi #Sarcasm"@Retributions: #IndiawithPaki... ---
#   RoBERTa=0.622 | HTag=0.88 | Fused=0.674 | Pred=1 | True=0 | ❌  [209/290 = 72.1%]
# --- Tweet 291: I guess waking up every couple hours is cool |#not... ---
#   RoBERTa=0.814 | HTag=0.88 | Fused=0.709 | Pred=1 | True=1 | ✅  [210/291 = 72.2%]
# --- Tweet 292: #Is #There #Too #Much to #Do or #Are #You #Not #Delegat... ---
#   RoBERTa=0.076 | HTag=0.88 | Fused=0.576 | Pred=1 | True=0 | ❌  [210/292 = 71.9%]
# --- Tweet 293: @user @user told to stop work under crew contracts #iro... ---
#   RoBERTa=0.830 | HTag=0.88 | Fused=0.711 | Pred=1 | True=1 | ✅  [211/293 = 72.0%]
# --- Tweet 294: I need to get out of this car before I kill my dad.... ---
#   RoBERTa=0.051 | Fused=0.051 | Pred=0 | True=0 | ✅  [212/294 = 72.1%]
# --- Tweet 295: Everytime I try to like Chris Brown he does something t... ---
#   RoBERTa=0.307 | Fused=0.307 | Pred=0 | True=0 | ✅  [213/295 = 72.2%]
# --- Tweet 296: #bedroom #decoration done lol #upstairs just needs a ho... ---
#   RoBERTa=0.068 | HTag=0.12 | Fused=0.081 | Pred=0 | True=0 | ✅  [214/296 = 72.3%]
# --- Tweet 297: Look good feel good! #not #TeamNoSleep #cantopeneyes... ---
#   RoBERTa=0.500 | HTag=0.88 | Fused=0.652 | Pred=1 | True=1 | ✅  [215/297 = 72.4%]
# --- Tweet 298: How much did it cost to build #mygov #medicare? I see t... ---
#   RoBERTa=0.249 | Fused=0.249 | Pred=0 | True=0 | ✅  [216/298 = 72.5%]
# --- Tweet 299: That sad moment you realize you're past the point of ha... ---
#   RoBERTa=0.199 | Fused=0.199 | Pred=0 | True=0 | ✅  [217/299 = 72.6%]
# --- Tweet 300: So I may have had a "few" empties to recycle... ♻♻ |I ❤... ---
#   RoBERTa=0.184 | Fused=0.184 | Pred=0 | True=0 | ✅  [218/300 = 72.7%]
# --- Tweet 301: @user @user @user @user @user @user yet in Ferguson, MO... ---
#   RoBERTa=0.562 | HTag=0.88 | Fused=0.663 | Pred=1 | True=1 | ✅  [219/301 = 72.8%]
# --- Tweet 302: Abnormal professor walks in with the finals in a Zoloft... ---
#   RoBERTa=0.881 | HTag=0.88 | Fused=0.721 | Pred=1 | True=1 | ✅  [220/302 = 72.8%]
# --- Tweet 303: @user in hereford but can't leave bambino alone!... ---
#   RoBERTa=0.064 | Fused=0.064 | Pred=0 | True=0 | ✅  [221/303 = 72.9%]
# --- Tweet 304: @user skiing in Regents Park much #not... ---
#   RoBERTa=0.045 | HTag=0.88 | Fused=0.570 | Pred=1 | True=1 | ✅  [222/304 = 73.0%]
# --- Tweet 305: Rejoice in knowing he is now in his new place...#not ea... ---
#   RoBERTa=0.213 | HTag=0.88 | Fused=0.600 | Pred=1 | True=0 | ❌  [222/305 = 72.8%]
# --- Tweet 306: When "make dua for me bro" turns into an hour long conv... ---
#   RoBERTa=0.706 | Fused=0.706 | Pred=1 | True=0 | ❌  [222/306 = 72.5%]
# --- Tweet 307: @user @user A thief, a liar, a vote rigger, mocks those... ---
#   RoBERTa=0.685 | HTag=0.88 | Fused=0.685 | Pred=1 | True=0 | ❌  [222/307 = 72.3%]
# --- Tweet 308: What the hell has happened to Shahid Afridi in last cou... ---
#   RoBERTa=0.120 | Fused=0.120 | Pred=0 | True=0 | ✅  [223/308 = 72.4%]
# --- Tweet 309: Sub is making class go by so slow that I feel like I am... ---
#   RoBERTa=0.574 | HTag=0.88 | Fused=0.665 | Pred=1 | True=1 | ✅  [224/309 = 72.5%]
# --- Tweet 310: #Photography #Photoshop #Photos #Art #EyeCandy #Bible o... ---
#   RoBERTa=0.095 | Fused=0.095 | Pred=0 | True=0 | ✅  [225/310 = 72.6%]
# --- Tweet 311: @user Yeah someone with Hayek and hockey in their name ... ---
#   RoBERTa=0.732 | HTag=0.88 | Fused=0.694 | Pred=1 | True=1 | ✅  [226/311 = 72.7%]
# --- Tweet 312: The Rondo, Ellis, Parsons, Dirk, Chandler starting line... ---
#   RoBERTa=0.039 | Fused=0.039 | Pred=0 | True=0 | ✅  [227/312 = 72.8%]
# --- Tweet 313: @user @user @user but of course it was. Cops could shoo... ---
#   RoBERTa=0.177 | Fused=0.177 | Pred=0 | True=0 | ✅  [228/313 = 72.8%]
# --- Tweet 314: I love it when people ignore me. #sarcasm... ---
#   RoBERTa=0.966 | HTag=0.88 | Fused=0.736 | Pred=1 | True=1 | ✅  [229/314 = 72.9%]
# --- Tweet 315: Every you're a fucking cunt, lying cunt did I say cunt ... ---
#   RoBERTa=0.197 | HTag=0.88 | Fused=0.598 | Pred=1 | True=0 | ❌  [229/315 = 72.7%]
# ...
# --- Tweet 631: Why is there evidence of a stripper in my house yet I s... ---
#   RoBERTa=0.086 | Fused=0.086 | Pred=0 | True=0 | ✅  [471/631 = 74.6%]
# --- Tweet 632: Beach hangs with my bffz... ---
#   RoBERTa=0.227 | Fused=0.227 | Pred=0 | True=0 | ✅  [472/632 = 74.7%]
# --- Tweet 633: How can u miss something u never had?||#randomthoughts ... ---
#   RoBERTa=0.079 | HTag=0.88 | Fused=0.576 | Pred=1 | True=1 | ✅  [473/633 = 74.7%]
# --- Tweet 634: #Mahathir, one of the godfathers of Asian values, Malay... ---
#   RoBERTa=0.613 | HTag=0.88 | Fused=0.672 | Pred=1 | True=1 | ✅  [474/634 = 74.8%]
# --- Tweet 635: Love these guys! RT @user Tried to get the whole family... ---
#   RoBERTa=0.064 | Fused=0.064 | Pred=0 | True=0 | ✅  [475/635 = 74.8%]
# --- Tweet 636: So baffled that WWE wrestling is still as popular as it... ---
#   RoBERTa=0.384 | Fused=0.384 | Pred=0 | True=0 | ✅  [476/636 = 74.8%]
# --- Tweet 637: @user just check out the buttons, see what they do. And... ---
#   RoBERTa=0.062 | Fused=0.062 | Pred=0 | True=0 | ✅  [477/637 = 74.9%]
# --- Tweet 638: @user no one really says that... ---
#   RoBERTa=0.317 | Fused=0.317 | Pred=0 | True=0 | ✅  [478/638 = 74.9%]
# --- Tweet 639: @user The ones who did this, and the ones who support t... ---
#   RoBERTa=0.193 | Fused=0.193 | Pred=0 | True=0 | ✅  [479/639 = 75.0%]
# --- Tweet 640: @user that's some bullshit that's a complete rip off fo... ---
#   RoBERTa=0.504 | HTag=0.88 | Fused=0.653 | Pred=1 | True=1 | ✅  [480/640 = 75.0%]
# --- Tweet 641: Do you want to be right? |Or do you want to be happy?... ---
#   RoBERTa=0.034 | Fused=0.034 | Pred=0 | True=0 | ✅  [481/641 = 75.0%]
# --- Tweet 642: I like to think of myself as a broken down Justin Biebe... ---
#   RoBERTa=0.278 | HTag=0.88 | Fused=0.612 | Pred=1 | True=1 | ✅  [482/642 = 75.1%]
# --- Tweet 643: @user > matters we may exert or influence a change. But... ---
#   RoBERTa=0.038 | Fused=0.038 | Pred=0 | True=0 | ✅  [483/643 = 75.1%]
# --- Tweet 644: @user just trying to confuse you all 😘... ---
#   RoBERTa=0.333 | Fused=0.333 | Pred=0 | True=0 | ✅  [484/644 = 75.2%]
# --- Tweet 645: 20 years ago I arrived in CR, happy to leave behind all... ---
#   RoBERTa=0.253 | HTag=0.88 | Fused=0.608 | Pred=1 | True=1 | ✅  [485/645 = 75.2%]
# --- Tweet 646: again, your myth of "racist DNA" is still only a figmen... ---
#   RoBERTa=0.074 | Fused=0.074 | Pred=0 | True=0 | ✅  [486/646 = 75.2%]
# --- Tweet 647: #NOT SO UGLY CHRISTMAS SWEATER HUNTER'S RUN SANTA'S SLE... ---
#   RoBERTa=0.071 | HTag=0.88 | Fused=0.575 | Pred=1 | True=0 | ❌  [486/647 = 75.1%]
# --- Tweet 648: I know who I am. I am not perfect. I'm not the most bea... ---
#   RoBERTa=0.054 | HTag=0.88 | Fused=0.572 | Pred=1 | True=0 | ❌  [486/648 = 75.0%]
# --- Tweet 649: @user @user @user effigies of jesus or allah..... when ... ---
#   RoBERTa=0.200 | HTag=0.88 | Fused=0.598 | Pred=1 | True=1 | ✅  [487/649 = 75.0%]
# --- Tweet 650: I have three exams today lets gooooo! #School #Sarcasm ... ---
#   RoBERTa=0.288 | HTag=0.88 | Fused=0.614 | Pred=1 | True=1 | ✅  [488/650 = 75.1%]
# --- Tweet 651: Today was a very good day in Iceland.... ---
#   RoBERTa=0.973 | Fused=0.973 | Pred=1 | True=0 | ❌  [488/651 = 75.0%]
# --- Tweet 652: Welll helllo fever. Id say 103 is feelin real good toda... ---
#   RoBERTa=0.068 | HTag=0.88 | Fused=0.574 | Pred=1 | True=1 | ✅  [489/652 = 75.0%]
# --- Tweet 653: I feel and look like shit. #rainyday #nomakeup #sorryno... ---
#   RoBERTa=0.245 | Fused=0.245 | Pred=0 | True=0 | ✅  [490/653 = 75.0%]
# --- Tweet 654: Today's NCAA action on the way.... ---
#   RoBERTa=0.564 | Fused=0.564 | Pred=1 | True=0 | ❌  [490/654 = 74.9%]
# --- Tweet 655: @user @user lol.. Old enough to know better... Young en... ---
#   RoBERTa=0.251 | Fused=0.251 | Pred=0 | True=0 | ✅  [491/655 = 75.0%]
# --- Tweet 656: Monday morning inspiration! #sarcasm #itstruetho #dontt... ---
#   RoBERTa=0.252 | HTag=0.88 | Fused=0.607 | Pred=1 | True=1 | ✅  [492/656 = 75.0%]
# --- Tweet 657: My mom is the most annoying person I know. I know you'r... ---
#   RoBERTa=0.240 | HTag=0.12 | Fused=0.210 | Pred=0 | True=0 | ✅  [493/657 = 75.0%]
# --- Tweet 658: @user @user Talking to yourself again Mo #Irony... ---
#   RoBERTa=0.632 | HTag=0.88 | Fused=0.676 | Pred=1 | True=0 | ❌  [493/658 = 74.9%]
# --- Tweet 659: @user @user @user @user @user @user #irony #oxymoron "p... ---
#   RoBERTa=0.222 | HTag=0.88 | Fused=0.602 | Pred=1 | True=1 | ✅  [494/659 = 75.0%]
# --- Tweet 660: Who said that birthday girl can't celebrate the next da... ---
#   RoBERTa=0.143 | Fused=0.143 | Pred=0 | True=0 | ✅  [495/660 = 75.0%]
# --- Tweet 661: @user yep, overall it was a great show live. ending of ... ---
#   RoBERTa=0.104 | HTag=0.12 | Fused=0.108 | Pred=0 | True=0 | ✅  [496/661 = 75.0%]
# --- Tweet 662: Video: #im#not#the#only#one#you#think#im#crazy# ahhhhhh... ---
#   RoBERTa=0.113 | HTag=0.88 | Fused=0.582 | Pred=1 | True=0 | ❌  [496/662 = 74.9%]
# --- Tweet 663: Trying to eat crackers on the quiet floor likeee.. Mayb... ---
#   RoBERTa=0.289 | HTag=0.88 | Fused=0.614 | Pred=1 | True=1 | ✅  [497/663 = 75.0%]
# --- Tweet 664: Woke up with my foot the size of a balloon, that's just... ---
#   RoBERTa=0.415 | HTag=0.88 | Fused=0.637 | Pred=1 | True=1 | ✅  [498/664 = 75.0%]
# --- Tweet 665: #Celtics RT @user And then there were none... ---
#   RoBERTa=0.070 | Fused=0.070 | Pred=0 | True=0 | ✅  [499/665 = 75.0%]
# --- Tweet 666: Image via We Heart It #feelings #not #people #telling... ---
#   RoBERTa=0.115 | HTag=0.88 | Fused=0.583 | Pred=1 | True=0 | ❌  [499/666 = 74.9%]
# --- Tweet 667: No one talks like I do , No one thinks like I do , No m... ---
#   RoBERTa=0.037 | Fused=0.037 | Pred=0 | True=0 | ✅  [500/667 = 75.0%]
# --- Tweet 668: No doubt. Main Stream Media, Obama, Holder, DeBlasio et... ---
#   RoBERTa=0.316 | Fused=0.316 | Pred=0 | True=0 | ✅  [501/668 = 75.0%]
# --- Tweet 669: @user thanks for the spoiler!!!! #not... ---
#   RoBERTa=0.790 | HTag=0.88 | Fused=0.704 | Pred=1 | True=1 | ✅  [502/669 = 75.0%]
# --- Tweet 670: Congress just screwed us but it's a great day in the Di... ---
#   RoBERTa=0.973 | HTag=0.88 | Fused=0.737 | Pred=1 | True=1 | ✅  [503/670 = 75.1%]
# --- Tweet 671: #AdvancedWarfare is so much better than any FPS release... ---
#   RoBERTa=0.492 | Fused=0.492 | Pred=0 | True=0 | ✅  [504/671 = 75.1%]
# --- Tweet 672: It's always the little things that's attracts me... ---
#   RoBERTa=0.811 | Fused=0.811 | Pred=1 | True=0 | ❌  [504/672 = 75.0%]
# --- Tweet 673: @user @user You're #not familiar #with Matt Busby, #the... ---
#   RoBERTa=0.070 | HTag=0.88 | Fused=0.575 | Pred=1 | True=0 | ❌  [504/673 = 74.9%]
# --- Tweet 674: Highly inflamed stomach is just what I like #not... ---
#   RoBERTa=0.909 | HTag=0.88 | Fused=0.726 | Pred=1 | True=1 | ✅  [505/674 = 74.9%]
# --- Tweet 675: I think about Disney World just about every day. #missi... ---
#   RoBERTa=0.434 | Fused=0.434 | Pred=0 | True=0 | ✅  [506/675 = 75.0%]
# --- Tweet 676: almost 72 hs of a kid asking for his christmas gift and... ---
#   RoBERTa=0.952 | HTag=0.88 | Fused=0.733 | Pred=1 | True=1 | ✅  [507/676 = 75.0%]
# --- Tweet 677: ... Can#do#no#more#not#usually#a#quitter#only#so#much#c... ---
#   RoBERTa=0.071 | HTag=0.88 | Fused=0.575 | Pred=1 | True=0 | ❌  [507/677 = 74.9%]
# --- Tweet 678: @user Well maybe if you werent such a noob you would be... ---
#   RoBERTa=0.154 | Fused=0.154 | Pred=0 | True=0 | ✅  [508/678 = 74.9%]
# --- Tweet 679: #not insured... ---
#   RoBERTa=0.049 | HTag=0.88 | Fused=0.571 | Pred=1 | True=0 | ❌  [508/679 = 74.8%]
# --- Tweet 680: Horray to working all weekend! #sarcasm #ohwell 💰💰👍😏... ---
#   RoBERTa=0.494 | HTag=0.88 | Fused=0.651 | Pred=1 | True=1 | ✅  [509/680 = 74.9%]
# --- Tweet 681: @user thankfully not full cold.. Just one side down. Ge... ---
#   RoBERTa=0.070 | Fused=0.070 | Pred=0 | True=0 | ✅  [510/681 = 74.9%]
# --- Tweet 682: HELLO Wednesday! BY THE WAY IT'S December 10, 2014 at 0... ---
#   RoBERTa=0.130 | Fused=0.130 | Pred=0 | True=0 | ✅  [511/682 = 74.9%]
# --- Tweet 683: I do hope you Anti #GamerGate'rs will sleep better, kno... ---
#   RoBERTa=0.955 | HTag=0.88 | Fused=0.734 | Pred=1 | True=1 | ✅  [512/683 = 75.0%]
# --- Tweet 684: Haha guess my tweet was ok then. Are you back in traini... ---
#   RoBERTa=0.266 | Fused=0.266 | Pred=0 | True=0 | ✅  [513/684 = 75.0%]
# --- Tweet 685: 13 voice mails at work is always lovely #not... ---
#   RoBERTa=0.977 | HTag=0.88 | Fused=0.738 | Pred=1 | True=1 | ✅  [514/685 = 75.0%]
# --- Tweet 686: Sick on Christmas YAYYYY #not... ---
#   RoBERTa=0.797 | HTag=0.88 | Fused=0.706 | Pred=1 | True=1 | ✅  [515/686 = 75.1%]
# --- Tweet 687: How were your #holidays? We'd love to hear all about th... ---
#   RoBERTa=0.053 | Fused=0.053 | Pred=0 | True=0 | ✅  [516/687 = 75.1%]
# --- Tweet 688: Ah yes. Just what I wanted today- a pounding migraine. ... ---
#   RoBERTa=0.954 | HTag=0.88 | Fused=0.734 | Pred=1 | True=1 | ✅  [517/688 = 75.1%]
# --- Tweet 689: Munching cheese like its Christmas #stiltonoverload... ---
#   RoBERTa=0.337 | Fused=0.337 | Pred=0 | True=0 | ✅  [518/689 = 75.2%]
# --- Tweet 690: #Hazard worker training. 1st break there was 3 doz donu... ---
#   RoBERTa=0.253 | HTag=0.88 | Fused=0.608 | Pred=1 | True=1 | ✅  [519/690 = 75.2%]
# --- Tweet 691: The thought of work tonight really kills that Friday fe... ---
#   RoBERTa=0.747 | Fused=0.747 | Pred=1 | True=0 | ❌  [519/691 = 75.1%]
# --- Tweet 692: The thirstiest of thirst buckets calling other people t... ---
#   RoBERTa=0.491 | HTag=0.88 | Fused=0.650 | Pred=1 | True=1 | ✅  [520/692 = 75.1%]
# --- Tweet 693: @user #pantsdowntiggy was his crime. Pixelation #moot o... ---
#   RoBERTa=0.090 | HTag=0.88 | Fused=0.578 | Pred=1 | True=0 | ❌  [520/693 = 75.0%]
# --- Tweet 694: #notcies #eu Green determined to block Hinkley Point - ... ---
#   RoBERTa=0.262 | Fused=0.262 | Pred=0 | True=0 | ✅  [521/694 = 75.1%]
# --- Tweet 695: I've got a right thirst on... #NewsYearsEve... ---
#   RoBERTa=0.101 | Fused=0.101 | Pred=0 | True=0 | ✅  [522/695 = 75.1%]
# --- Tweet 696: Love the fact that I turned off my alarm this morning a... ---
#   RoBERTa=0.911 | HTag=0.88 | Fused=0.726 | Pred=1 | True=1 | ✅  [523/696 = 75.1%]
# --- Tweet 697: #mcfc trying to kill their opponents.... ---
#   RoBERTa=0.405 | Fused=0.405 | Pred=0 | True=0 | ✅  [524/697 = 75.2%]
# --- Tweet 698: #Seen #a #headline #about #a #doctor #that #starts #wit... ---
#   RoBERTa=0.117 | HTag=0.88 | Fused=0.583 | Pred=1 | True=0 | ❌  [524/698 = 75.1%]
# --- Tweet 699: @user @user Yet no "dog in the manger" that actually ma... ---
#   RoBERTa=0.401 | HTag=0.88 | Fused=0.634 | Pred=1 | True=1 | ✅  [525/699 = 75.1%]
# --- Tweet 700: #Irony Reverend tells kids that Santa is not real why d... ---
#   RoBERTa=0.844 | HTag=0.88 | Fused=0.714 | Pred=1 | True=1 | ✅  [526/700 = 75.1%]
# --- Tweet 701: Laborers in the San Joaquin Valley, one of the most pro... ---
#   RoBERTa=0.609 | HTag=0.88 | Fused=0.672 | Pred=1 | True=1 | ✅  [527/701 = 75.2%]
# --- Tweet 702: I think my friend just sent @user a snapchat of me drin... ---
#   RoBERTa=0.678 | HTag=0.88 | Fused=0.684 | Pred=1 | True=1 | ✅  [528/702 = 75.2%]
# --- Tweet 703: Girls won't answer their phone when I'm calling them bc... ---
#   RoBERTa=0.636 | HTag=0.88 | Fused=0.677 | Pred=1 | True=1 | ✅  [529/703 = 75.2%]
# --- Tweet 704: @user make sure you don't say Christmas!! The decorate ... ---
#   RoBERTa=0.372 | HTag=0.88 | Fused=0.629 | Pred=1 | True=1 | ✅  [530/704 = 75.3%]
# --- Tweet 705: Re: prison book ban - Of course Grayling is also trying... ---
#   RoBERTa=0.918 | HTag=0.88 | Fused=0.727 | Pred=1 | True=1 | ✅  [531/705 = 75.3%]
# --- Tweet 706: Rolled out of bed for closing.... #ilookreallygood #not... ---
#   RoBERTa=0.193 | HTag=0.88 | Fused=0.597 | Pred=1 | True=1 | ✅  [532/706 = 75.4%]
# --- Tweet 707: Watching VT and Cincy - qb for VT with (GODS) down left... ---
#   RoBERTa=0.213 | HTag=0.88 | Fused=0.600 | Pred=1 | True=1 | ✅  [533/707 = 75.4%]
# --- Tweet 708: you seem super smart MT "@GrannyMarried: @user @user ||... ---
#   RoBERTa=0.347 | HTag=0.88 | Fused=0.624 | Pred=1 | True=1 | ✅  [534/708 = 75.4%]
# --- Tweet 709: @user Cheers bro! Top man 🙋... ---
#   RoBERTa=0.045 | Fused=0.045 | Pred=0 | True=0 | ✅  [535/709 = 75.5%]
# --- Tweet 710: Even getting cooked breakfast.. Hes defo up to somethin... ---
#   RoBERTa=0.207 | Fused=0.207 | Pred=0 | True=0 | ✅  [536/710 = 75.5%]
# --- Tweet 711: ROFLMAO yeah, OOPS is right @user @user @user @user... ---
#   RoBERTa=0.078 | Fused=0.078 | Pred=0 | True=0 | ✅  [537/711 = 75.5%]
# --- Tweet 712: Coin ! LeCoinCanard: Coin ! LeCoinCanard: Coin ! have a... ---
#   RoBERTa=0.136 | HTag=0.88 | Fused=0.586 | Pred=1 | True=1 | ✅  [538/712 = 75.6%]
# --- Tweet 713: I really want to see Into The Woods!... ---
#   RoBERTa=0.053 | Fused=0.053 | Pred=0 | True=0 | ✅  [539/713 = 75.6%]
# --- Tweet 714: @user that bump off the apron looked like it hurt.. was... ---
#   RoBERTa=0.054 | HTag=0.88 | Fused=0.572 | Pred=1 | True=1 | ✅  [540/714 = 75.6%]
# --- Tweet 715: @user please make me smile this Xmas.. First Xmas witho... ---
#   RoBERTa=0.037 | HTag=0.12 | Fused=0.057 | Pred=0 | True=0 | ✅  [541/715 = 75.7%]
# --- Tweet 716: @user Hope the header didn't mess up that barnet... ---
#   RoBERTa=0.100 | Fused=0.100 | Pred=0 | True=0 | ✅  [542/716 = 75.7%]
# --- Tweet 717: If it's NOT? then it IS! Hand Crafted Artistically Fash... ---
#   RoBERTa=0.059 | Fused=0.059 | Pred=0 | True=0 | ✅  [543/717 = 75.7%]
# --- Tweet 718: It's okay @user I didn't really want to see my idol any... ---
#   RoBERTa=0.281 | HTag=0.88 | Fused=0.613 | Pred=1 | True=1 | ✅  [544/718 = 75.8%]
# --- Tweet 719: I'll try to guess the ASCII symbols without my admins h... ---
#   RoBERTa=0.297 | Fused=0.297 | Pred=0 | True=0 | ✅  [545/719 = 75.8%]
# --- Tweet 720: Hearing gun shots when I first wake up makes me feel li... ---
#   RoBERTa=0.982 | HTag=0.88 | Fused=0.739 | Pred=1 | True=1 | ✅  [546/720 = 75.8%]
# --- Tweet 721: Protesters upset over decision in chokehold death take ... ---
#   RoBERTa=0.621 | Fused=0.621 | Pred=1 | True=0 | ❌  [546/721 = 75.7%]
# --- Tweet 722: @user Great,& not sure if i've seen that actual pic! #n... ---
#   RoBERTa=0.057 | HTag=0.88 | Fused=0.572 | Pred=1 | True=0 | ❌  [546/722 = 75.6%]
# --- Tweet 723: #TGIF oh just kidding I have 30 mins from one job to th... ---
#   RoBERTa=0.933 | HTag=0.88 | Fused=0.730 | Pred=1 | True=1 | ✅  [547/723 = 75.7%]
# --- Tweet 724: Just got yelled at by proxy. It's going to be an excell... ---
#   RoBERTa=0.974 | HTag=0.88 | Fused=0.737 | Pred=1 | True=1 | ✅  [548/724 = 75.7%]
# --- Tweet 725: Lol everyday excuse the language #relationships #men #w... ---
#   RoBERTa=0.268 | HTag=0.88 | Fused=0.610 | Pred=1 | True=0 | ❌  [548/725 = 75.6%]
# --- Tweet 726: Making the most out of my last vacation day. #not #tvan... ---
#   RoBERTa=0.509 | HTag=0.88 | Fused=0.654 | Pred=1 | True=1 | ✅  [549/726 = 75.6%]
# --- Tweet 727: What a lovely day to drive #not #boo #fog #work 😳😳😳... ---
#   RoBERTa=0.345 | HTag=0.88 | Fused=0.624 | Pred=1 | True=1 | ✅  [550/727 = 75.7%]
# --- Tweet 728: So restaurants that thrive on the social nature of eati... ---
#   RoBERTa=0.935 | HTag=0.88 | Fused=0.730 | Pred=1 | True=1 | ✅  [551/728 = 75.7%]
# --- Tweet 729: This long drive home later in the snow is gonna be shwe... ---
#   RoBERTa=0.074 | HTag=0.88 | Fused=0.575 | Pred=1 | True=1 | ✅  [552/729 = 75.7%]
# --- Tweet 730: If you drag yesterday into today, your tomorrow cannot ... ---
#   RoBERTa=0.027 | Fused=0.027 | Pred=0 | True=0 | ✅  [553/730 = 75.8%]
# --- Tweet 731: Congrats to my fav @user & her team & my birthplace tea... ---
#   RoBERTa=0.082 | Fused=0.082 | Pred=0 | True=0 | ✅  [554/731 = 75.8%]
# --- Tweet 732: @user Jessica sheds tears at her fan signing event make... ---
#   RoBERTa=0.326 | Fused=0.326 | Pred=0 | True=0 | ✅  [555/732 = 75.8%]
# --- Tweet 733: #Irony: al jazeera is pro Anti - #GamerGate because fem... ---
#   RoBERTa=0.796 | HTag=0.88 | Fused=0.705 | Pred=1 | True=1 | ✅  [556/733 = 75.9%]
# --- Tweet 734: #NOT ALL 👌 There good & bad in every occupation & race ... ---
#   RoBERTa=0.093 | HTag=0.88 | Fused=0.579 | Pred=1 | True=0 | ❌  [556/734 = 75.7%]
#
# ======================================================================

# %%
# ── Cell 10: Metrics — mirrors Table 1 of the RDS paper ──────────────────────

y_true = [r["True"] for r in results_list]
y_pred = [r["Pred"] for r in results_list]

accuracy   = accuracy_score(y_true, y_pred)
macro_f1   = f1_score(y_true, y_pred, average="macro")
ironic_f1  = f1_score(y_true, y_pred, pos_label=1, average="binary")
ironic_p   = precision_score(y_true, y_pred, pos_label=1, average="binary")
ironic_r   = recall_score(y_true, y_pred, pos_label=1, average="binary")
nonironic_f1 = f1_score(y_true, y_pred, pos_label=0, average="binary")
cm         = confusion_matrix(y_true, y_pred)

tn, fp, fn, tp = cm.ravel()

print("\n" + "="*70)
print(" ABLATION RESULTS: RoBERTa + Hashtag Prior  (No CoT)")
print(" Test set N=734  |  same split as RDS paper")
print("="*70)
print(f"  Accuracy        : {accuracy*100:.1f}%")
print(f"  Macro F1        : {macro_f1:.3f}")
print(f"  Ironic F1       : {ironic_f1:.3f}")
print(f"  Ironic Precision: {ironic_p:.3f}")
print(f"  Ironic Recall   : {ironic_r:.3f}")
print(f"  Non-Ironic F1   : {nonironic_f1:.3f}")
print(f"  Confusion Matrix: TP={tp}  FP={fp}  FN={fn}  TN={tn}")
print("="*70)

print("\n--- For comparison (from RDS paper Table 1) ---")
print("  Method                  Acc    MacroF1  IronicF1  IronicPrec  IronicRec  Non-IronicF1")
print("  RoBERTa-Only Baseline  73.2%   0.706    0.620     0.700       0.557      0.792")
print("  Full RDS Framework     78.1%   0.777    0.747     0.684       0.824      0.806")
print(f"  RoBERTa + Hashtag     {accuracy*100:.1f}%   {macro_f1:.3f}    {ironic_f1:.3f}     {ironic_p:.3f}       {ironic_r:.3f}      {nonironic_f1:.3f}")
print("="*70)
# Out:
# ======================================================================
#  ABLATION RESULTS: RoBERTa + Hashtag Prior  (No CoT)
#  Test set N=734  |  same split as RDS paper
# ======================================================================
#   Accuracy        : 75.7%
#   Macro F1        : 0.757
#   Ironic F1       : 0.765
#   Ironic Precision: 0.619
#   Ironic Recall   : 1.000
#   Non-Ironic F1   : 0.750
#   Confusion Matrix: TP=289  FP=178  FN=0  TN=267
# ======================================================================
#
# --- For comparison (from RDS paper Table 1) ---
#   Method                  Acc    MacroF1  IronicF1  IronicPrec  IronicRec  Non-IronicF1
#   RoBERTa-Only Baseline  73.2%   0.706    0.620     0.700       0.557      0.792
#   Full RDS Framework     78.1%   0.777    0.747     0.684       0.824      0.806
#   RoBERTa + Hashtag     75.7%   0.757    0.765     0.619       1.000      0.750
# ======================================================================

# %%
# ── Cell 11: McNemar's test vs. RoBERTa-Only baseline ────────────────────────
# Mirrors the statistical validation in RDS Section 5.2.
# Run this after also running the RoBERTa-Only baseline notebook to get
# its per-tweet predictions. If you have them, paste them into roberta_only_preds.
#
# If you don't have them yet, skip this cell — it requires the baseline predictions.

from statsmodels.stats.contingency_tables import mcnemar

# --- Paste RoBERTa-Only per-tweet predictions here (list of 0/1, length 734) ---
# roberta_only_preds = [...]  # fill this in

# Uncomment below once roberta_only_preds is available:
# y_ablation = y_pred
# both_wrong = sum(1 for a,b,t in zip(roberta_only_preds, y_ablation, y_true) if a!=t and b!=t)
# ablation_right_base_wrong = sum(1 for a,b,t in zip(roberta_only_preds, y_ablation, y_true) if a!=t and b==t)
# ablation_wrong_base_right = sum(1 for a,b,t in zip(roberta_only_preds, y_ablation, y_true) if a==t and b!=t)
# both_right = sum(1 for a,b,t in zip(roberta_only_preds, y_ablation, y_true) if a==t and b==t)
# table = [[both_right, ablation_wrong_base_right],
#          [ablation_right_base_wrong, both_wrong]]
# result = mcnemar(table, exact=False, correction=True)
# print(f"McNemar chi2={result.statistic:.3f}, p={result.pvalue:.4f}")

print("McNemar cell ready. Fill in roberta_only_preds list to run.")
# Out:
# McNemar cell ready. Fill in roberta_only_preds list to run.

# %%
# ── Cell 12: Subpopulation breakdown — mirrors Table 2 of RDS paper ──────────
# Breaks down performance on hashtag-triggered vs non-triggered subsets.

triggered_results     = [r for r in results_list if r["HTag Prior"] > 0.0]
non_triggered_results = [r for r in results_list if r["HTag Prior"] == 0.0]

def subset_metrics(subset):
    yt = [r["True"] for r in subset]
    yp = [r["Pred"] for r in subset]
    if len(set(yt)) < 2:  # guard against single-class subset
        return None
    return {
        "n"           : len(subset),
        "accuracy"    : accuracy_score(yt, yp) * 100,
        "macro_f1"    : f1_score(yt, yp, average="macro"),
        "nonironic_f1": f1_score(yt, yp, pos_label=0, average="binary"),
        "ironic_f1"   : f1_score(yt, yp, pos_label=1, average="binary"),
    }

trig_m  = subset_metrics(triggered_results)
notrig_m = subset_metrics(non_triggered_results)

print("\n" + "="*70)
print(" SUBPOPULATION ANALYSIS (mirrors RDS Table 2)")
print("="*70)
print(f"{'Subset':<22} {'n':>5} {'Accuracy':>10} {'Macro F1':>10} {'Non-Ironic F1':>14} {'Ironic F1':>10}")
print("-"*70)
if trig_m:
    print(f"{'Hashtag-Triggered':<22} {trig_m['n']:>5} {trig_m['accuracy']:>9.1f}% {trig_m['macro_f1']:>10.3f} {trig_m['nonironic_f1']:>14.3f} {trig_m['ironic_f1']:>10.3f}")
if notrig_m:
    print(f"{'Non-Triggered':<22} {notrig_m['n']:>5} {notrig_m['accuracy']:>9.1f}% {notrig_m['macro_f1']:>10.3f} {notrig_m['nonironic_f1']:>14.3f} {notrig_m['ironic_f1']:>10.3f}")
print("="*70)

htag_strong = sum(1 for r in results_list if r["HTag Prior"] >= 0.88)
htag_weak   = sum(1 for r in results_list if 0.0 < r["HTag Prior"] < 0.88)
print(f"\nHashtag detector: {len(triggered_results)} fired ({htag_strong} strong, {htag_weak} weak) | {len(non_triggered_results)} silent")
# Out:
# ======================================================================
#  SUBPOPULATION ANALYSIS (mirrors RDS Table 2)
# ======================================================================
# Subset                     n   Accuracy   Macro F1  Non-Ironic F1  Ironic F1
# ----------------------------------------------------------------------
# Hashtag-Triggered        417      71.5%      0.480          0.131      0.829
# ======================================================================
#
# Hashtag detector: 417 fired (407 strong, 10 weak) | 317 silent

# %%
# ── Cell 13: Full results dataframe ──────────────────────────────────────────

df = pd.DataFrame(results_list)
print(f"Full results table (N={len(df)}):")
display(df)
# Out:
# Full results table (N=734):
#                                            Tweet  True  Pred Correct  \
# 0    Rangers league game with Alloa moved bec...     1     1       ✅
# 1    How to Find a Life Coach (& the question...     0     0       ✅
# 2    I wonder what was the holiday rituals fo...     0     0       ✅
# 3    Been at the ER now since 10... #yay #not...     1     1       ✅
# 4    @user Suhs been clean for 2 years and ha...     0     1       ❌
# ..                                           ...   ...   ...     ...
# 729  If you drag yesterday into today, your t...     0     0       ✅
# 730  Congrats to my fav @user & her team & my...     0     0       ✅
# 731  @user Jessica sheds tears at her fan sig...     0     0       ✅
# 732  #Irony: al jazeera is pro Anti - #GamerG...     1     1       ✅
# 733  #NOT ALL 👌 There good & bad in every occ...     0     1       ❌
#
#      RoBERTa P(ironic)  HTag Prior  Fused P(ironic)
# 0                0.565        0.88            0.664
# 1                0.033        0.00            0.033
# 2                0.209        0.00            0.209
# 3                0.344        0.88            0.624
# 4                0.041        0.88            0.569
# ..                 ...         ...              ...
# 729              0.027        0.00            0.027
# 730              0.082        0.00            0.082
# 731              0.326        0.00            0.326
# 732              0.796        0.88            0.705
# 733              0.093        0.88            0.579
#
# [734 rows x 7 columns]

# %% [markdown]
# ## Interpretation Guide
#
# Compare these results against Table 1 and Table 2 of the RDS paper:
#
# | Scenario | Implication |
# |---|---|
# | **Ablation ≈ Full RDS** | CoT compression adds nothing. The contribution claim needs to be dropped or reframed. Paper becomes a neuro-symbolic gating study. |
# | **Full RDS > Ablation** | CoT machinery is doing real work. The paper's contribution holds. Difference magnitude determines how much it matters. |
# | **Ablation > Full RDS** | CoT compression is actively hurting performance. Significant reframing required. |
#
# Pay particular attention to the **non-triggered subset** (no hashtag). If both ablation and RDS show Ironic F1 ≈ 0 there, that confirms the hashtag prior is the sole driver of irony detection regardless of whether CoT is present.
