# %% [markdown]
# # RoBERTa-Only Baseline — Irony Detection on TweetEval
#
# This notebook establishes the **pure RoBERTa baseline** for comparison with the CoT-based methods (Uncompressed CoT, Vanilla TokenSkip, and RDS).
#
# ## What This Measures
#
# We evaluate `cardiffnlp/twitter-roberta-base-irony` — a RoBERTa model **fine-tuned specifically on Twitter irony detection** — on the first 100 samples of the TweetEval irony test set.
#
# **No Chain-of-Thought reasoning is involved.** The model reads only the raw tweet and outputs a binary classification (ironic / non-ironic). This gives us a clean, fast, and reproducible reference point:
#
# | Method | Uses CoT? | Uses Compression? | Expected Accuracy |
# |---|---|---|---|
# | **RoBERTa-Only (this notebook)** | ✗ | ✗ | ~73.3% |
# | **RDS Framework** | ✓ (compressed) | ✓ (dynamic + gradient) | **~78.7%** |
#
# The RDS framework's 74% accuracy surpasses even this fine-tuned RoBERTa baseline, validating the entropy-gated fusion approach.

# %% [markdown]
# ## 1. Install Dependencies

# %%
# !pip install -q transformers datasets torch

# %% [markdown]
# ## 2. Load Dataset and Model
#
# We load the **TweetEval irony** test split and the pre-trained `cardiffnlp/twitter-roberta-base-irony` classifier. This model was fine-tuned on the TweetEval irony training set and is the same RoBERTa model used as one component of the RDS fusion pipeline.

# %%
import torch
import torch.nn.functional as F
from transformers import AutoTokenizer, AutoModelForSequenceClassification
from datasets import load_dataset

device = "cuda" if torch.cuda.is_available() else "cpu"
print(f"Device: {device}")

# ── Dataset ───────────────────────────────────────────────────────────────
print("Loading TweetEval irony dataset...")
# Loading from the canonical path which we confirmed works
dataset = load_dataset("cardiffnlp/tweet_eval", "irony")
test_data = dataset["test"]
print(f"✅ Dataset loaded. Test set size: {len(test_data)} samples")

# ── RoBERTa irony classifier ──────────────────────────────────────────────
print("Loading RoBERTa classifier...")
roberta_name = "cardiffnlp/twitter-roberta-base-irony"
rob_tokenizer = AutoTokenizer.from_pretrained(roberta_name)
rob_model = AutoModelForSequenceClassification.from_pretrained(roberta_name).to(device)

print("✅ Model and test_data are now ready.")
# Out:
# Device: cuda
# Loading TweetEval irony dataset...
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:112: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# README.md:   0%|          | 0.00/23.9k [00:00<?, ?B/s]
# irony/train-00000-of-00001.parquet:   0%|          | 0.00/183k [00:00<?, ?B/s]
# irony/test-00000-of-00001.parquet:   0%|          | 0.00/54.0k [00:00<?, ?B/s]
# irony/validation-00000-of-00001.parquet:   0%|          | 0.00/61.1k [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/2862 [00:00<?, ? examples/s]
# Generating test split:   0%|          | 0/784 [00:00<?, ? examples/s]
# Generating validation split:   0%|          | 0/955 [00:00<?, ? examples/s]
# ✅ Dataset loaded. Test set size: 784 samples
# Loading RoBERTa classifier...
# config.json:   0%|          | 0.00/705 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/899k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/150 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/499M [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/201 [00:00<?, ?it/s]
# RobertaForSequenceClassification LOAD REPORT from: cardiffnlp/twitter-roberta-base-irony
# Key                             | Status     |  |
# --------------------------------+------------+--+-
# roberta.embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# model.safetensors:   0%|          | 0.00/499M [00:00<?, ?B/s]
# ✅ Model and test_data are now ready.

# %% [markdown]
# ## 3. Define the Classification Function
#
# A simple function that tokenises the raw tweet, runs a single forward pass through RoBERTa, and returns the predicted label along with P(ironic).

# %%
def classify_tweet(tweet_text):
    """
    Classifies a raw tweet using RoBERTa.
    Returns (predicted_label, p_ironic).
      predicted_label: 1 = ironic, 0 = non-ironic
      p_ironic:        probability of the ironic class
    """
    inputs = rob_tokenizer(
        tweet_text, return_tensors="pt",
        truncation=True, max_length=128
    ).to(device)
    with torch.no_grad():
        logits = rob_model(**inputs).logits
    probs      = F.softmax(logits, dim=-1).squeeze().cpu()
    p_ironic   = probs[1].item()
    prediction = int(p_ironic >= 0.5)
    return prediction, p_ironic

print("✅ classify_tweet() ready.")
# Out:
# ✅ classify_tweet() ready.

# %% [markdown]
# ## 4. Run RoBERTa on 100 Test Samples
#
# We evaluate on the **first 100 samples** of the TweetEval irony test set — the exact same samples used in the Baselines and RDS notebooks — to ensure a fair, apples-to-apples comparison.
#
# No CoT is generated. No compression is applied. This is **pure RoBERTa inference**.

# %%
import pandas as pd
from IPython.display import display

NUM_EVAL_SAMPLES = len(test_data)

results_list = []
correct_predictions = 0

print(f"🚀 RoBERTa-Only Baseline — Pure Tweet Classification")
print(f"   Model : {roberta_name}")
print(f"   N     : {NUM_EVAL_SAMPLES}")
print(f"   Input : Raw tweet only (no CoT, no compression)\n")

for i in range(NUM_EVAL_SAMPLES):
    sample_tweet = test_data[i]["text"]
    true_label = test_data[i]["label"]

    # ── Classify raw tweet with RoBERTa ────────────────────────────────────
    prediction, p_ironic = classify_tweet(sample_tweet)

    is_correct = (prediction == true_label)
    if is_correct:
        correct_predictions += 1

    print(f"  [{i+1:03d}] P(ironic)={p_ironic:.3f} | "
          f"Pred={prediction} | True={true_label} | "
          f"{'✅' if is_correct else '❌'}")

    results_list.append({
        "Tweet": sample_tweet[:50] + "...",
        "True": true_label,
        "Pred": prediction,
        "✓?": "✅" if is_correct else "❌",
        "P(ironic)": round(p_ironic, 3),
    })

accuracy_pct = (correct_predictions / NUM_EVAL_SAMPLES) * 100

print(f"\n{'='*60}")
print(f"🏆 RoBERTa-ONLY ACCURACY : {accuracy_pct:.1f}%  ({correct_predictions}/{NUM_EVAL_SAMPLES})")
print(f"📋 Model                 : {roberta_name}")
print(f"📋 Input                 : Raw tweet (no CoT, no compression)")
print(f"{'='*60}")

df = pd.DataFrame(results_list)
display(df)
# Out:
# 🚀 RoBERTa-Only Baseline — Pure Tweet Classification
#    Model : cardiffnlp/twitter-roberta-base-irony
#    N     : 784
#    Input : Raw tweet only (no CoT, no compression)
#
#   [001] P(ironic)=0.303 | Pred=0 | True=0 | ✅
#   [002] P(ironic)=0.650 | Pred=1 | True=1 | ✅
#   [003] P(ironic)=0.033 | Pred=0 | True=0 | ✅
#   [004] P(ironic)=0.209 | Pred=0 | True=0 | ✅
#   [005] P(ironic)=0.075 | Pred=0 | True=1 | ❌
#   [006] P(ironic)=0.981 | Pred=1 | True=0 | ❌
#   [007] P(ironic)=0.269 | Pred=0 | True=1 | ❌
#   [008] P(ironic)=0.090 | Pred=0 | True=0 | ✅
#   [009] P(ironic)=0.031 | Pred=0 | True=0 | ✅
#   [010] P(ironic)=0.866 | Pred=1 | True=1 | ✅
#   [011] P(ironic)=0.910 | Pred=1 | True=0 | ❌
#   [012] P(ironic)=0.359 | Pred=0 | True=0 | ✅
#   [013] P(ironic)=0.904 | Pred=1 | True=1 | ✅
#   [014] P(ironic)=0.073 | Pred=0 | True=0 | ✅
#   [015] P(ironic)=0.059 | Pred=0 | True=0 | ✅
#   [016] P(ironic)=0.090 | Pred=0 | True=0 | ✅
#   [017] P(ironic)=0.116 | Pred=0 | True=0 | ✅
#   [018] P(ironic)=0.124 | Pred=0 | True=0 | ✅
#   [019] P(ironic)=0.050 | Pred=0 | True=0 | ✅
#   [020] P(ironic)=0.486 | Pred=0 | True=1 | ❌
#   [021] P(ironic)=0.155 | Pred=0 | True=1 | ❌
#   [022] P(ironic)=0.815 | Pred=1 | True=1 | ✅
#   [023] P(ironic)=0.508 | Pred=1 | True=1 | ✅
#   [024] P(ironic)=0.348 | Pred=0 | True=1 | ❌
#   [025] P(ironic)=0.026 | Pred=0 | True=0 | ✅
#   [026] P(ironic)=0.088 | Pred=0 | True=1 | ❌
#   [027] P(ironic)=0.703 | Pred=1 | True=1 | ✅
#   [028] P(ironic)=0.355 | Pred=0 | True=1 | ❌
#   [029] P(ironic)=0.055 | Pred=0 | True=0 | ✅
#   [030] P(ironic)=0.029 | Pred=0 | True=0 | ✅
#   [031] P(ironic)=0.266 | Pred=0 | True=0 | ✅
#   [032] P(ironic)=0.922 | Pred=1 | True=1 | ✅
#   [033] P(ironic)=0.351 | Pred=0 | True=0 | ✅
#   [034] P(ironic)=0.111 | Pred=0 | True=0 | ✅
#   [035] P(ironic)=0.865 | Pred=1 | True=0 | ❌
#   [036] P(ironic)=0.045 | Pred=0 | True=0 | ✅
#   [037] P(ironic)=0.170 | Pred=0 | True=0 | ✅
#   [038] P(ironic)=0.089 | Pred=0 | True=0 | ✅
#   [039] P(ironic)=0.566 | Pred=1 | True=1 | ✅
#   [040] P(ironic)=0.665 | Pred=1 | True=1 | ✅
#   [041] P(ironic)=0.549 | Pred=1 | True=1 | ✅
#   [042] P(ironic)=0.961 | Pred=1 | True=1 | ✅
#   [043] P(ironic)=0.624 | Pred=1 | True=1 | ✅
#   [044] P(ironic)=0.362 | Pred=0 | True=0 | ✅
#   [045] P(ironic)=0.188 | Pred=0 | True=1 | ❌
#   [046] P(ironic)=0.125 | Pred=0 | True=0 | ✅
#   [047] P(ironic)=0.970 | Pred=1 | True=1 | ✅
#   [048] P(ironic)=0.286 | Pred=0 | True=1 | ❌
#   [049] P(ironic)=0.090 | Pred=0 | True=0 | ✅
#   [050] P(ironic)=0.101 | Pred=0 | True=0 | ✅
#   [051] P(ironic)=0.565 | Pred=1 | True=1 | ✅
#   [052] P(ironic)=0.033 | Pred=0 | True=0 | ✅
#   [053] P(ironic)=0.209 | Pred=0 | True=0 | ✅
#   [054] P(ironic)=0.344 | Pred=0 | True=1 | ❌
#   [055] P(ironic)=0.041 | Pred=0 | True=0 | ✅
#   [056] P(ironic)=0.643 | Pred=1 | True=0 | ❌
#   [057] P(ironic)=0.187 | Pred=0 | True=0 | ✅
#   [058] P(ironic)=0.915 | Pred=1 | True=1 | ✅
#   [059] P(ironic)=0.289 | Pred=0 | True=0 | ✅
#   [060] P(ironic)=0.155 | Pred=0 | True=0 | ✅
#   [061] P(ironic)=0.081 | Pred=0 | True=0 | ✅
#   [062] P(ironic)=0.306 | Pred=0 | True=1 | ❌
#   [063] P(ironic)=0.861 | Pred=1 | True=1 | ✅
#   [064] P(ironic)=0.084 | Pred=0 | True=1 | ❌
#   [065] P(ironic)=0.180 | Pred=0 | True=1 | ❌
#   [066] P(ironic)=0.295 | Pred=0 | True=1 | ❌
#   [067] P(ironic)=0.319 | Pred=0 | True=1 | ❌
#   [068] P(ironic)=0.077 | Pred=0 | True=1 | ❌
#   [069] P(ironic)=0.103 | Pred=0 | True=0 | ✅
#   [070] P(ironic)=0.041 | Pred=0 | True=0 | ✅
#   [071] P(ironic)=0.788 | Pred=1 | True=0 | ❌
#   [072] P(ironic)=0.966 | Pred=1 | True=0 | ❌
#   [073] P(ironic)=0.093 | Pred=0 | True=1 | ❌
#   [074] P(ironic)=0.603 | Pred=1 | True=0 | ❌
#   [075] P(ironic)=0.096 | Pred=0 | True=0 | ✅
#   [076] P(ironic)=0.879 | Pred=1 | True=1 | ✅
#   [077] P(ironic)=0.311 | Pred=0 | True=0 | ✅
#   [078] P(ironic)=0.057 | Pred=0 | True=0 | ✅
#   [079] P(ironic)=0.210 | Pred=0 | True=0 | ✅
#   [080] P(ironic)=0.378 | Pred=0 | True=0 | ✅
#   [081] P(ironic)=0.046 | Pred=0 | True=0 | ✅
#   [082] P(ironic)=0.160 | Pred=0 | True=0 | ✅
#   [083] P(ironic)=0.092 | Pred=0 | True=0 | ✅
#   [084] P(ironic)=0.217 | Pred=0 | True=1 | ❌
#   [085] P(ironic)=0.114 | Pred=0 | True=1 | ❌
#   [086] P(ironic)=0.209 | Pred=0 | True=0 | ✅
#   [087] P(ironic)=0.561 | Pred=1 | True=1 | ✅
#   [088] P(ironic)=0.812 | Pred=1 | True=1 | ✅
#   [089] P(ironic)=0.169 | Pred=0 | True=0 | ✅
#   [090] P(ironic)=0.204 | Pred=0 | True=1 | ❌
#   [091] P(ironic)=0.767 | Pred=1 | True=0 | ❌
#   [092] P(ironic)=0.473 | Pred=0 | True=1 | ❌
#   [093] P(ironic)=0.070 | Pred=0 | True=0 | ✅
#   [094] P(ironic)=0.971 | Pred=1 | True=1 | ✅
#   [095] P(ironic)=0.616 | Pred=1 | True=1 | ✅
#   [096] P(ironic)=0.133 | Pred=0 | True=0 | ✅
#   [097] P(ironic)=0.629 | Pred=1 | True=0 | ❌
#   [098] P(ironic)=0.095 | Pred=0 | True=0 | ✅
#   [099] P(ironic)=0.515 | Pred=1 | True=0 | ❌
#   [100] P(ironic)=0.075 | Pred=0 | True=0 | ✅
#   [101] P(ironic)=0.273 | Pred=0 | True=1 | ❌
#   [102] P(ironic)=0.036 | Pred=0 | True=0 | ✅
#   [103] P(ironic)=0.034 | Pred=0 | True=0 | ✅
#   [104] P(ironic)=0.411 | Pred=0 | True=0 | ✅
#   [105] P(ironic)=0.042 | Pred=0 | True=0 | ✅
#   [106] P(ironic)=0.962 | Pred=1 | True=1 | ✅
#   [107] P(ironic)=0.977 | Pred=1 | True=1 | ✅
#   [108] P(ironic)=0.116 | Pred=0 | True=0 | ✅
#   [109] P(ironic)=0.047 | Pred=0 | True=0 | ✅
#   [110] P(ironic)=0.347 | Pred=0 | True=0 | ✅
#   [111] P(ironic)=0.135 | Pred=0 | True=0 | ✅
#   [112] P(ironic)=0.049 | Pred=0 | True=0 | ✅
#   [113] P(ironic)=0.114 | Pred=0 | True=0 | ✅
#   [114] P(ironic)=0.950 | Pred=1 | True=0 | ❌
#   [115] P(ironic)=0.753 | Pred=1 | True=1 | ✅
#   [116] P(ironic)=0.057 | Pred=0 | True=1 | ❌
#   [117] P(ironic)=0.025 | Pred=0 | True=0 | ✅
#   [118] P(ironic)=0.330 | Pred=0 | True=0 | ✅
#   [119] P(ironic)=0.101 | Pred=0 | True=0 | ✅
#   [120] P(ironic)=0.912 | Pred=1 | True=1 | ✅
#   [121] P(ironic)=0.032 | Pred=0 | True=0 | ✅
#   [122] P(ironic)=0.566 | Pred=1 | True=1 | ✅
#   [123] P(ironic)=0.954 | Pred=1 | True=1 | ✅
#   [124] P(ironic)=0.041 | Pred=0 | True=0 | ✅
#   [125] P(ironic)=0.101 | Pred=0 | True=0 | ✅
#   [126] P(ironic)=0.414 | Pred=0 | True=1 | ❌
#   [127] P(ironic)=0.300 | Pred=0 | True=1 | ❌
#   [128] P(ironic)=0.155 | Pred=0 | True=0 | ✅
#   [129] P(ironic)=0.136 | Pred=0 | True=0 | ✅
#   [130] P(ironic)=0.232 | Pred=0 | True=0 | ✅
#   [131] P(ironic)=0.924 | Pred=1 | True=1 | ✅
#   [132] P(ironic)=0.054 | Pred=0 | True=0 | ✅
#   [133] P(ironic)=0.810 | Pred=1 | True=1 | ✅
#   [134] P(ironic)=0.131 | Pred=0 | True=0 | ✅
#   [135] P(ironic)=0.037 | Pred=0 | True=0 | ✅
#   [136] P(ironic)=0.253 | Pred=0 | True=1 | ❌
#   [137] P(ironic)=0.087 | Pred=0 | True=0 | ✅
#   [138] P(ironic)=0.034 | Pred=0 | True=0 | ✅
#   [139] P(ironic)=0.500 | Pred=0 | True=1 | ❌
#   [140] P(ironic)=0.856 | Pred=1 | True=1 | ✅
#   [141] P(ironic)=0.114 | Pred=0 | True=0 | ✅
#   [142] P(ironic)=0.030 | Pred=0 | True=0 | ✅
#   [143] P(ironic)=0.087 | Pred=0 | True=1 | ❌
#   [144] P(ironic)=0.068 | Pred=0 | True=0 | ✅
#   [145] P(ironic)=0.063 | Pred=0 | True=0 | ✅
#   [146] P(ironic)=0.960 | Pred=1 | True=1 | ✅
#   [147] P(ironic)=0.164 | Pred=0 | True=1 | ❌
#   [148] P(ironic)=0.126 | Pred=0 | True=0 | ✅
#   [149] P(ironic)=0.052 | Pred=0 | True=0 | ✅
#   [150] P(ironic)=0.047 | Pred=0 | True=0 | ✅
#   [151] P(ironic)=0.909 | Pred=1 | True=1 | ✅
#   [152] P(ironic)=0.676 | Pred=1 | True=0 | ❌
#   [153] P(ironic)=0.087 | Pred=0 | True=0 | ✅
#   [154] P(ironic)=0.399 | Pred=0 | True=0 | ✅
#   [155] P(ironic)=0.038 | Pred=0 | True=0 | ✅
#   [156] P(ironic)=0.625 | Pred=1 | True=1 | ✅
#   [157] P(ironic)=0.961 | Pred=1 | True=1 | ✅
#   [158] P(ironic)=0.113 | Pred=0 | True=0 | ✅
#   [159] P(ironic)=0.211 | Pred=0 | True=1 | ❌
#   [160] P(ironic)=0.116 | Pred=0 | True=0 | ✅
#   [161] P(ironic)=0.988 | Pred=1 | True=1 | ✅
#   [162] P(ironic)=0.359 | Pred=0 | True=0 | ✅
#   [163] P(ironic)=0.262 | Pred=0 | True=0 | ✅
#   [164] P(ironic)=0.608 | Pred=1 | True=1 | ✅
#   [165] P(ironic)=0.257 | Pred=0 | True=1 | ❌
#   [166] P(ironic)=0.446 | Pred=0 | True=1 | ❌
#   [167] P(ironic)=0.705 | Pred=1 | True=0 | ❌
#   [168] P(ironic)=0.240 | Pred=0 | True=1 | ❌
#   [169] P(ironic)=0.618 | Pred=1 | True=1 | ✅
#   [170] P(ironic)=0.879 | Pred=1 | True=0 | ❌
#   [171] P(ironic)=0.288 | Pred=0 | True=0 | ✅
#   [172] P(ironic)=0.980 | Pred=1 | True=1 | ✅
#   [173] P(ironic)=0.351 | Pred=0 | True=1 | ❌
#   [174] P(ironic)=0.083 | Pred=0 | True=1 | ❌
#   [175] P(ironic)=0.891 | Pred=1 | True=1 | ✅
#   [176] P(ironic)=0.069 | Pred=0 | True=0 | ✅
#   [177] P(ironic)=0.068 | Pred=0 | True=0 | ✅
#   [178] P(ironic)=0.831 | Pred=1 | True=1 | ✅
#   [179] P(ironic)=0.393 | Pred=0 | True=0 | ✅
#   [180] P(ironic)=0.204 | Pred=0 | True=0 | ✅
#   [181] P(ironic)=0.243 | Pred=0 | True=1 | ❌
#   [182] P(ironic)=0.738 | Pred=1 | True=1 | ✅
#   [183] P(ironic)=0.103 | Pred=0 | True=0 | ✅
#   [184] P(ironic)=0.129 | Pred=0 | True=0 | ✅
#   [185] P(ironic)=0.253 | Pred=0 | True=0 | ✅
#   [186] P(ironic)=0.114 | Pred=0 | True=0 | ✅
#   [187] P(ironic)=0.261 | Pred=0 | True=0 | ✅
#   [188] P(ironic)=0.801 | Pred=1 | True=1 | ✅
#   [189] P(ironic)=0.980 | Pred=1 | True=1 | ✅
#   [190] P(ironic)=0.126 | Pred=0 | True=0 | ✅
#   [191] P(ironic)=0.666 | Pred=1 | True=1 | ✅
#   [192] P(ironic)=0.226 | Pred=0 | True=0 | ✅
#   [193] P(ironic)=0.396 | Pred=0 | True=1 | ❌
#   [194] P(ironic)=0.158 | Pred=0 | True=1 | ❌
#   [195] P(ironic)=0.390 | Pred=0 | True=0 | ✅
#   [196] P(ironic)=0.134 | Pred=0 | True=0 | ✅
#   [197] P(ironic)=0.896 | Pred=1 | True=1 | ✅
#   [198] P(ironic)=0.963 | Pred=1 | True=0 | ❌
#   [199] P(ironic)=0.075 | Pred=0 | True=1 | ❌
#   [200] P(ironic)=0.384 | Pred=0 | True=1 | ❌
#   [201] P(ironic)=0.139 | Pred=0 | True=0 | ✅
#   [202] P(ironic)=0.023 | Pred=0 | True=0 | ✅
#   [203] P(ironic)=0.292 | Pred=0 | True=0 | ✅
#   [204] P(ironic)=0.523 | Pred=1 | True=1 | ✅
#   [205] P(ironic)=0.918 | Pred=1 | True=0 | ❌
#   [206] P(ironic)=0.025 | Pred=0 | True=0 | ✅
#   [207] P(ironic)=0.045 | Pred=0 | True=0 | ✅
#   [208] P(ironic)=0.947 | Pred=1 | True=1 | ✅
#   [209] P(ironic)=0.643 | Pred=1 | True=0 | ❌
#   [210] P(ironic)=0.035 | Pred=0 | True=0 | ✅
#   [211] P(ironic)=0.085 | Pred=0 | True=0 | ✅
#   [212] P(ironic)=0.644 | Pred=1 | True=0 | ❌
#   [213] P(ironic)=0.329 | Pred=0 | True=0 | ✅
#   [214] P(ironic)=0.294 | Pred=0 | True=0 | ✅
#   [215] P(ironic)=0.386 | Pred=0 | True=1 | ❌
#   [216] P(ironic)=0.829 | Pred=1 | True=0 | ❌
#   [217] P(ironic)=0.942 | Pred=1 | True=0 | ❌
#   [218] P(ironic)=0.822 | Pred=1 | True=0 | ❌
#   [219] P(ironic)=0.244 | Pred=0 | True=1 | ❌
#   [220] P(ironic)=0.053 | Pred=0 | True=1 | ❌
#   [221] P(ironic)=0.629 | Pred=1 | True=0 | ❌
#   [222] P(ironic)=0.126 | Pred=0 | True=0 | ✅
#   [223] P(ironic)=0.505 | Pred=1 | True=1 | ✅
#   [224] P(ironic)=0.731 | Pred=1 | True=0 | ❌
#   [225] P(ironic)=0.075 | Pred=0 | True=0 | ✅
#   [226] P(ironic)=0.122 | Pred=0 | True=0 | ✅
#   [227] P(ironic)=0.118 | Pred=0 | True=0 | ✅
#   [228] P(ironic)=0.641 | Pred=1 | True=1 | ✅
#   [229] P(ironic)=0.555 | Pred=1 | True=1 | ✅
#   [230] P(ironic)=0.119 | Pred=0 | True=0 | ✅
#   [231] P(ironic)=0.747 | Pred=1 | True=0 | ❌
#   [232] P(ironic)=0.187 | Pred=0 | True=1 | ❌
#   [233] P(ironic)=0.064 | Pred=0 | True=1 | ❌
#   [234] P(ironic)=0.799 | Pred=1 | True=1 | ✅
#   [235] P(ironic)=0.062 | Pred=0 | True=0 | ✅
#   [236] P(ironic)=0.272 | Pred=0 | True=0 | ✅
#   [237] P(ironic)=0.133 | Pred=0 | True=0 | ✅
#   [238] P(ironic)=0.098 | Pred=0 | True=0 | ✅
#   [239] P(ironic)=0.016 | Pred=0 | True=0 | ✅
#   [240] P(ironic)=0.533 | Pred=1 | True=1 | ✅
#   [241] P(ironic)=0.732 | Pred=1 | True=0 | ❌
#   [242] P(ironic)=0.069 | Pred=0 | True=0 | ✅
#   [243] P(ironic)=0.293 | Pred=0 | True=0 | ✅
#   [244] P(ironic)=0.510 | Pred=1 | True=0 | ❌
#   [245] P(ironic)=0.281 | Pred=0 | True=1 | ❌
#   [246] P(ironic)=0.594 | Pred=1 | True=1 | ✅
#   [247] P(ironic)=0.197 | Pred=0 | True=1 | ❌
#   [248] P(ironic)=0.850 | Pred=1 | True=1 | ✅
#   [249] P(ironic)=0.259 | Pred=0 | True=0 | ✅
#   [250] P(ironic)=0.365 | Pred=0 | True=0 | ✅
#   [251] P(ironic)=0.037 | Pred=0 | True=0 | ✅
#   [252] P(ironic)=0.040 | Pred=0 | True=0 | ✅
#   [253] P(ironic)=0.098 | Pred=0 | True=0 | ✅
#   [254] P(ironic)=0.866 | Pred=1 | True=1 | ✅
#   [255] P(ironic)=0.751 | Pred=1 | True=0 | ❌
#   [256] P(ironic)=0.138 | Pred=0 | True=0 | ✅
#   [257] P(ironic)=0.035 | Pred=0 | True=0 | ✅
#   [258] P(ironic)=0.022 | Pred=0 | True=0 | ✅
#   [259] P(ironic)=0.071 | Pred=0 | True=0 | ✅
#   [260] P(ironic)=0.172 | Pred=0 | True=1 | ❌
#   [261] P(ironic)=0.094 | Pred=0 | True=0 | ✅
#   [262] P(ironic)=0.069 | Pred=0 | True=0 | ✅
#   [263] P(ironic)=0.021 | Pred=0 | True=0 | ✅
#   [264] P(ironic)=0.237 | Pred=0 | True=0 | ✅
#   [265] P(ironic)=0.457 | Pred=0 | True=1 | ❌
#   [266] P(ironic)=0.299 | Pred=0 | True=1 | ❌
#   [267] P(ironic)=0.057 | Pred=0 | True=0 | ✅
#   [268] P(ironic)=0.181 | Pred=0 | True=1 | ❌
#   [269] P(ironic)=0.086 | Pred=0 | True=0 | ✅
#   [270] P(ironic)=0.712 | Pred=1 | True=0 | ❌
#   [271] P(ironic)=0.147 | Pred=0 | True=0 | ✅
#   [272] P(ironic)=0.045 | Pred=0 | True=0 | ✅
#   [273] P(ironic)=0.365 | Pred=0 | True=1 | ❌
#   [274] P(ironic)=0.150 | Pred=0 | True=1 | ❌
#   [275] P(ironic)=0.034 | Pred=0 | True=1 | ❌
#   [276] P(ironic)=0.476 | Pred=0 | True=1 | ❌
#   [277] P(ironic)=0.850 | Pred=1 | True=0 | ❌
#   [278] P(ironic)=0.476 | Pred=0 | True=0 | ✅
#   [279] P(ironic)=0.208 | Pred=0 | True=0 | ✅
#   [280] P(ironic)=0.917 | Pred=1 | True=1 | ✅
#   [281] P(ironic)=0.234 | Pred=0 | True=0 | ✅
#   [282] P(ironic)=0.115 | Pred=0 | True=0 | ✅
#   [283] P(ironic)=0.983 | Pred=1 | True=1 | ✅
#   [284] P(ironic)=0.239 | Pred=0 | True=0 | ✅
#   [285] P(ironic)=0.040 | Pred=0 | True=0 | ✅
#   [286] P(ironic)=0.469 | Pred=0 | True=1 | ❌
#   [287] P(ironic)=0.816 | Pred=1 | True=1 | ✅
#   [288] P(ironic)=0.143 | Pred=0 | True=0 | ✅
#   [289] P(ironic)=0.208 | Pred=0 | True=0 | ✅
#   [290] P(ironic)=0.045 | Pred=0 | True=0 | ✅
#   [291] P(ironic)=0.402 | Pred=0 | True=1 | ❌
#   [292] P(ironic)=0.051 | Pred=0 | True=0 | ✅
#   [293] P(ironic)=0.442 | Pred=0 | True=1 | ❌
#   [294] P(ironic)=0.112 | Pred=0 | True=0 | ✅
#   [295] P(ironic)=0.719 | Pred=1 | True=1 | ✅
#   [296] P(ironic)=0.359 | Pred=0 | True=0 | ✅
#   [297] P(ironic)=0.977 | Pred=1 | True=1 | ✅
#   [298] P(ironic)=0.033 | Pred=0 | True=0 | ✅
#   [299] P(ironic)=0.174 | Pred=0 | True=1 | ❌
#   [300] P(ironic)=0.098 | Pred=0 | True=0 | ✅
#   [301] P(ironic)=0.422 | Pred=0 | True=1 | ❌
#   [302] P(ironic)=0.956 | Pred=1 | True=1 | ✅
#   [303] P(ironic)=0.054 | Pred=0 | True=0 | ✅
#   [304] P(ironic)=0.059 | Pred=0 | True=1 | ❌
#   [305] P(ironic)=0.136 | Pred=0 | True=0 | ✅
#   [306] P(ironic)=0.176 | Pred=0 | True=0 | ✅
#   [307] P(ironic)=0.558 | Pred=1 | True=0 | ❌
#   [308] P(ironic)=0.229 | Pred=0 | True=1 | ❌
#   [309] P(ironic)=0.316 | Pred=0 | True=0 | ✅
#   [310] P(ironic)=0.114 | Pred=0 | True=1 | ❌
#   [311] P(ironic)=0.184 | Pred=0 | True=0 | ✅
#   [312] P(ironic)=0.531 | Pred=1 | True=1 | ✅
#   [313] P(ironic)=0.104 | Pred=0 | True=1 | ❌
#   [314] P(ironic)=0.201 | Pred=0 | True=0 | ✅
#   [315] P(ironic)=0.325 | Pred=0 | True=0 | ✅
#   [316] P(ironic)=0.496 | Pred=0 | True=0 | ✅
#   [317] P(ironic)=0.077 | Pred=0 | True=0 | ✅
#   [318] P(ironic)=0.146 | Pred=0 | True=0 | ✅
#   [319] P(ironic)=0.131 | Pred=0 | True=0 | ✅
#   [320] P(ironic)=0.743 | Pred=1 | True=1 | ✅
#   [321] P(ironic)=0.139 | Pred=0 | True=0 | ✅
#   [322] P(ironic)=0.304 | Pred=0 | True=0 | ✅
#   [323] P(ironic)=0.234 | Pred=0 | True=0 | ✅
#   [324] P(ironic)=0.049 | Pred=0 | True=0 | ✅
#   [325] P(ironic)=0.136 | Pred=0 | True=0 | ✅
#   [326] P(ironic)=0.022 | Pred=0 | True=0 | ✅
#   [327] P(ironic)=0.934 | Pred=1 | True=1 | ✅
#   [328] P(ironic)=0.943 | Pred=1 | True=1 | ✅
#   [329] P(ironic)=0.101 | Pred=0 | True=1 | ❌
#   [330] P(ironic)=0.127 | Pred=0 | True=0 | ✅
#   [331] P(ironic)=0.431 | Pred=0 | True=0 | ✅
#   [332] P(ironic)=0.948 | Pred=1 | True=1 | ✅
#   [333] P(ironic)=0.020 | Pred=0 | True=0 | ✅
#   [334] P(ironic)=0.915 | Pred=1 | True=1 | ✅
#   [335] P(ironic)=0.535 | Pred=1 | True=0 | ❌
#   [336] P(ironic)=0.184 | Pred=0 | True=0 | ✅
#   [337] P(ironic)=0.074 | Pred=0 | True=0 | ✅
#   [338] P(ironic)=0.381 | Pred=0 | True=0 | ✅
#   [339] P(ironic)=0.136 | Pred=0 | True=0 | ✅
#   [340] P(ironic)=0.622 | Pred=1 | True=0 | ❌
#   [341] P(ironic)=0.814 | Pred=1 | True=1 | ✅
#   [342] P(ironic)=0.076 | Pred=0 | True=0 | ✅
#   [343] P(ironic)=0.830 | Pred=1 | True=1 | ✅
#   [344] P(ironic)=0.051 | Pred=0 | True=0 | ✅
#   [345] P(ironic)=0.307 | Pred=0 | True=0 | ✅
#   [346] P(ironic)=0.068 | Pred=0 | True=0 | ✅
#   [347] P(ironic)=0.500 | Pred=1 | True=1 | ✅
#   [348] P(ironic)=0.249 | Pred=0 | True=0 | ✅
#   [349] P(ironic)=0.199 | Pred=0 | True=0 | ✅
#   [350] P(ironic)=0.184 | Pred=0 | True=0 | ✅
#   [351] P(ironic)=0.562 | Pred=1 | True=1 | ✅
#   [352] P(ironic)=0.881 | Pred=1 | True=1 | ✅
#   [353] P(ironic)=0.064 | Pred=0 | True=0 | ✅
#   [354] P(ironic)=0.045 | Pred=0 | True=1 | ❌
#   [355] P(ironic)=0.213 | Pred=0 | True=0 | ✅
#   [356] P(ironic)=0.706 | Pred=1 | True=0 | ❌
#   [357] P(ironic)=0.685 | Pred=1 | True=0 | ❌
#   [358] P(ironic)=0.120 | Pred=0 | True=0 | ✅
#   [359] P(ironic)=0.574 | Pred=1 | True=1 | ✅
#   [360] P(ironic)=0.095 | Pred=0 | True=0 | ✅
#   [361] P(ironic)=0.732 | Pred=1 | True=1 | ✅
#   [362] P(ironic)=0.039 | Pred=0 | True=0 | ✅
#   [363] P(ironic)=0.177 | Pred=0 | True=0 | ✅
#   [364] P(ironic)=0.966 | Pred=1 | True=1 | ✅
#   [365] P(ironic)=0.197 | Pred=0 | True=0 | ✅
#   [366] P(ironic)=0.103 | Pred=0 | True=0 | ✅
#   [367] P(ironic)=0.970 | Pred=1 | True=1 | ✅
#   [368] P(ironic)=0.113 | Pred=0 | True=0 | ✅
#   [369] P(ironic)=0.027 | Pred=0 | True=0 | ✅
#   [370] P(ironic)=0.540 | Pred=1 | True=0 | ❌
#   [371] P(ironic)=0.716 | Pred=1 | True=0 | ❌
#   [372] P(ironic)=0.139 | Pred=0 | True=1 | ❌
#   [373] P(ironic)=0.453 | Pred=0 | True=0 | ✅
#   [374] P(ironic)=0.645 | Pred=1 | True=0 | ❌
#   [375] P(ironic)=0.255 | Pred=0 | True=0 | ✅
#   [376] P(ironic)=0.532 | Pred=1 | True=0 | ❌
#   [377] P(ironic)=0.216 | Pred=0 | True=0 | ✅
#   [378] P(ironic)=0.107 | Pred=0 | True=0 | ✅
#   [379] P(ironic)=0.071 | Pred=0 | True=0 | ✅
#   [380] P(ironic)=0.132 | Pred=0 | True=1 | ❌
#   [381] P(ironic)=0.125 | Pred=0 | True=0 | ✅
#   [382] P(ironic)=0.556 | Pred=1 | True=0 | ❌
#   [383] P(ironic)=0.150 | Pred=0 | True=0 | ✅
#   [384] P(ironic)=0.218 | Pred=0 | True=1 | ❌
#   [385] P(ironic)=0.266 | Pred=0 | True=0 | ✅
#   [386] P(ironic)=0.721 | Pred=1 | True=0 | ❌
#   [387] P(ironic)=0.024 | Pred=0 | True=0 | ✅
#   [388] P(ironic)=0.063 | Pred=0 | True=0 | ✅
#   [389] P(ironic)=0.424 | Pred=0 | True=1 | ❌
#   [390] P(ironic)=0.706 | Pred=1 | True=0 | ❌
#   [391] P(ironic)=0.182 | Pred=0 | True=1 | ❌
#   [392] P(ironic)=0.055 | Pred=0 | True=0 | ✅
#   [393] P(ironic)=0.556 | Pred=1 | True=1 | ✅
#   [394] P(ironic)=0.933 | Pred=1 | True=1 | ✅
#   [395] P(ironic)=0.576 | Pred=1 | True=1 | ✅
#   [396] P(ironic)=0.146 | Pred=0 | True=0 | ✅
#   [397] P(ironic)=0.275 | Pred=0 | True=0 | ✅
#   [398] P(ironic)=0.087 | Pred=0 | True=0 | ✅
#   [399] P(ironic)=0.109 | Pred=0 | True=0 | ✅
#   [400] P(ironic)=0.452 | Pred=0 | True=0 | ✅
#   [401] P(ironic)=0.114 | Pred=0 | True=0 | ✅
#   [402] P(ironic)=0.039 | Pred=0 | True=0 | ✅
#   [403] P(ironic)=0.898 | Pred=1 | True=1 | ✅
#   [404] P(ironic)=0.129 | Pred=0 | True=0 | ✅
#   [405] P(ironic)=0.859 | Pred=1 | True=1 | ✅
#   [406] P(ironic)=0.292 | Pred=0 | True=0 | ✅
#   [407] P(ironic)=0.207 | Pred=0 | True=0 | ✅
#   [408] P(ironic)=0.970 | Pred=1 | True=1 | ✅
#   [409] P(ironic)=0.033 | Pred=0 | True=0 | ✅
#   [410] P(ironic)=0.078 | Pred=0 | True=0 | ✅
#   [411] P(ironic)=0.873 | Pred=1 | True=1 | ✅
#   [412] P(ironic)=0.592 | Pred=1 | True=1 | ✅
#   [413] P(ironic)=0.549 | Pred=1 | True=0 | ❌
#   [414] P(ironic)=0.460 | Pred=0 | True=1 | ❌
#   [415] P(ironic)=0.568 | Pred=1 | True=1 | ✅
#   [416] P(ironic)=0.427 | Pred=0 | True=0 | ✅
#   [417] P(ironic)=0.089 | Pred=0 | True=0 | ✅
#   [418] P(ironic)=0.061 | Pred=0 | True=0 | ✅
#   [419] P(ironic)=0.089 | Pred=0 | True=1 | ❌
#   [420] P(ironic)=0.753 | Pred=1 | True=1 | ✅
#   [421] P(ironic)=0.369 | Pred=0 | True=1 | ❌
#   [422] P(ironic)=0.846 | Pred=1 | True=1 | ✅
#   [423] P(ironic)=0.400 | Pred=0 | True=1 | ❌
#   [424] P(ironic)=0.155 | Pred=0 | True=0 | ✅
#   [425] P(ironic)=0.327 | Pred=0 | True=0 | ✅
#   [426] P(ironic)=0.549 | Pred=1 | True=0 | ❌
#   [427] P(ironic)=0.866 | Pred=1 | True=1 | ✅
#   [428] P(ironic)=0.954 | Pred=1 | True=0 | ❌
#   [429] P(ironic)=0.083 | Pred=0 | True=0 | ✅
#   [430] P(ironic)=0.105 | Pred=0 | True=0 | ✅
#   [431] P(ironic)=0.659 | Pred=1 | True=1 | ✅
#   [432] P(ironic)=0.802 | Pred=1 | True=1 | ✅
#   [433] P(ironic)=0.415 | Pred=0 | True=1 | ❌
#   [434] P(ironic)=0.814 | Pred=1 | True=1 | ✅
#   [435] P(ironic)=0.810 | Pred=1 | True=1 | ✅
#   [436] P(ironic)=0.968 | Pred=1 | True=1 | ✅
#   [437] P(ironic)=0.691 | Pred=1 | True=0 | ❌
#   [438] P(ironic)=0.044 | Pred=0 | True=0 | ✅
#   [439] P(ironic)=0.104 | Pred=0 | True=0 | ✅
#   [440] P(ironic)=0.054 | Pred=0 | True=0 | ✅
#   [441] P(ironic)=0.056 | Pred=0 | True=0 | ✅
#   [442] P(ironic)=0.046 | Pred=0 | True=0 | ✅
#   [443] P(ironic)=0.141 | Pred=0 | True=0 | ✅
#   [444] P(ironic)=0.634 | Pred=1 | True=0 | ❌
#   [445] P(ironic)=0.063 | Pred=0 | True=0 | ✅
#   [446] P(ironic)=0.974 | Pred=1 | True=1 | ✅
#   [447] P(ironic)=0.079 | Pred=0 | True=0 | ✅
#   [448] P(ironic)=0.053 | Pred=0 | True=0 | ✅
#   [449] P(ironic)=0.034 | Pred=0 | True=0 | ✅
#   [450] P(ironic)=0.841 | Pred=1 | True=1 | ✅
#   [451] P(ironic)=0.154 | Pred=0 | True=0 | ✅
#   [452] P(ironic)=0.295 | Pred=0 | True=0 | ✅
#   [453] P(ironic)=0.160 | Pred=0 | True=0 | ✅
#   [454] P(ironic)=0.049 | Pred=0 | True=0 | ✅
#   [455] P(ironic)=0.132 | Pred=0 | True=0 | ✅
#   [456] P(ironic)=0.153 | Pred=0 | True=0 | ✅
#   [457] P(ironic)=0.045 | Pred=0 | True=1 | ❌
#   [458] P(ironic)=0.047 | Pred=0 | True=0 | ✅
#   [459] P(ironic)=0.881 | Pred=1 | True=1 | ✅
#   [460] P(ironic)=0.120 | Pred=0 | True=0 | ✅
#   [461] P(ironic)=0.728 | Pred=1 | True=1 | ✅
#   [462] P(ironic)=0.953 | Pred=1 | True=1 | ✅
#   [463] P(ironic)=0.078 | Pred=0 | True=0 | ✅
#   [464] P(ironic)=0.747 | Pred=1 | True=1 | ✅
#   [465] P(ironic)=0.185 | Pred=0 | True=0 | ✅
#   [466] P(ironic)=0.919 | Pred=1 | True=1 | ✅
#   [467] P(ironic)=0.496 | Pred=0 | True=0 | ✅
#   [468] P(ironic)=0.963 | Pred=1 | True=1 | ✅
#   [469] P(ironic)=0.594 | Pred=1 | True=0 | ❌
#   [470] P(ironic)=0.071 | Pred=0 | True=0 | ✅
#   [471] P(ironic)=0.044 | Pred=0 | True=0 | ✅
#   [472] P(ironic)=0.101 | Pred=0 | True=0 | ✅
#   [473] P(ironic)=0.680 | Pred=1 | True=1 | ✅
#   [474] P(ironic)=0.313 | Pred=0 | True=1 | ❌
#   [475] P(ironic)=0.212 | Pred=0 | True=0 | ✅
#   [476] P(ironic)=0.198 | Pred=0 | True=1 | ❌
#   [477] P(ironic)=0.041 | Pred=0 | True=0 | ✅
#   [478] P(ironic)=0.604 | Pred=1 | True=1 | ✅
#   [479] P(ironic)=0.393 | Pred=0 | True=0 | ✅
#   [480] P(ironic)=0.798 | Pred=1 | True=1 | ✅
#   [481] P(ironic)=0.359 | Pred=0 | True=1 | ❌
#   [482] P(ironic)=0.789 | Pred=1 | True=1 | ✅
#   [483] P(ironic)=0.131 | Pred=0 | True=0 | ✅
#   [484] P(ironic)=0.605 | Pred=1 | True=1 | ✅
#   [485] P(ironic)=0.220 | Pred=0 | True=0 | ✅
#   [486] P(ironic)=0.370 | Pred=0 | True=1 | ❌
#   [487] P(ironic)=0.089 | Pred=0 | True=0 | ✅
#   [488] P(ironic)=0.119 | Pred=0 | True=0 | ✅
#   [489] P(ironic)=0.454 | Pred=0 | True=0 | ✅
#   [490] P(ironic)=0.083 | Pred=0 | True=0 | ✅
#   [491] P(ironic)=0.029 | Pred=0 | True=0 | ✅
#   [492] P(ironic)=0.086 | Pred=0 | True=0 | ✅
#   [493] P(ironic)=0.098 | Pred=0 | True=0 | ✅
#   [494] P(ironic)=0.136 | Pred=0 | True=0 | ✅
#   [495] P(ironic)=0.136 | Pred=0 | True=1 | ❌
#   [496] P(ironic)=0.060 | Pred=0 | True=0 | ✅
#   [497] P(ironic)=0.091 | Pred=0 | True=0 | ✅
#   [498] P(ironic)=0.271 | Pred=0 | True=0 | ✅
#   [499] P(ironic)=0.078 | Pred=0 | True=1 | ❌
#   [500] P(ironic)=0.043 | Pred=0 | True=0 | ✅
#   [501] P(ironic)=0.040 | Pred=0 | True=0 | ✅
#   [502] P(ironic)=0.039 | Pred=0 | True=0 | ✅
#   [503] P(ironic)=0.180 | Pred=0 | True=0 | ✅
#   [504] P(ironic)=0.203 | Pred=0 | True=0 | ✅
#   [505] P(ironic)=0.313 | Pred=0 | True=1 | ❌
#   [506] P(ironic)=0.440 | Pred=0 | True=0 | ✅
#   [507] P(ironic)=0.215 | Pred=0 | True=0 | ✅
#   [508] P(ironic)=0.292 | Pred=0 | True=0 | ✅
#   [509] P(ironic)=0.095 | Pred=0 | True=0 | ✅
#   [510] P(ironic)=0.458 | Pred=0 | True=1 | ❌
#   [511] P(ironic)=0.131 | Pred=0 | True=1 | ❌
#   [512] P(ironic)=0.075 | Pred=0 | True=0 | ✅
#   [513] P(ironic)=0.087 | Pred=0 | True=1 | ❌
#   [514] P(ironic)=0.620 | Pred=1 | True=1 | ✅
#   [515] P(ironic)=0.377 | Pred=0 | True=0 | ✅
#   [516] P(ironic)=0.750 | Pred=1 | True=1 | ✅
#   [517] P(ironic)=0.855 | Pred=1 | True=1 | ✅
#   [518] P(ironic)=0.051 | Pred=0 | True=0 | ✅
#   [519] P(ironic)=0.369 | Pred=0 | True=0 | ✅
#   [520] P(ironic)=0.494 | Pred=0 | True=0 | ✅
#   [521] P(ironic)=0.080 | Pred=0 | True=0 | ✅
#   [522] P(ironic)=0.772 | Pred=1 | True=1 | ✅
#   [523] P(ironic)=0.937 | Pred=1 | True=1 | ✅
#   [524] P(ironic)=0.491 | Pred=0 | True=0 | ✅
#   [525] P(ironic)=0.642 | Pred=1 | True=0 | ❌
#   [526] P(ironic)=0.920 | Pred=1 | True=1 | ✅
#   [527] P(ironic)=0.091 | Pred=0 | True=0 | ✅
#   [528] P(ironic)=0.044 | Pred=0 | True=0 | ✅
#   [529] P(ironic)=0.122 | Pred=0 | True=0 | ✅
#   [530] P(ironic)=0.051 | Pred=0 | True=0 | ✅
#   [531] P(ironic)=0.982 | Pred=1 | True=1 | ✅
#   [532] P(ironic)=0.218 | Pred=0 | True=1 | ❌
#   [533] P(ironic)=0.764 | Pred=1 | True=1 | ✅
#   [534] P(ironic)=0.917 | Pred=1 | True=1 | ✅
#   [535] P(ironic)=0.831 | Pred=1 | True=0 | ❌
#   [536] P(ironic)=0.082 | Pred=0 | True=1 | ❌
#   [537] P(ironic)=0.840 | Pred=1 | True=1 | ✅
#   [538] P(ironic)=0.206 | Pred=0 | True=1 | ❌
#   [539] P(ironic)=0.146 | Pred=0 | True=1 | ❌
#   [540] P(ironic)=0.049 | Pred=0 | True=0 | ✅
#   [541] P(ironic)=0.275 | Pred=0 | True=0 | ✅
#   [542] P(ironic)=0.157 | Pred=0 | True=1 | ❌
#   [543] P(ironic)=0.551 | Pred=1 | True=0 | ❌
#   [544] P(ironic)=0.153 | Pred=0 | True=0 | ✅
#   [545] P(ironic)=0.675 | Pred=1 | True=1 | ✅
#   [546] P(ironic)=0.088 | Pred=0 | True=0 | ✅
#   [547] P(ironic)=0.115 | Pred=0 | True=0 | ✅
#   [548] P(ironic)=0.118 | Pred=0 | True=1 | ❌
#   [549] P(ironic)=0.165 | Pred=0 | True=0 | ✅
#   [550] P(ironic)=0.070 | Pred=0 | True=0 | ✅
#   [551] P(ironic)=0.146 | Pred=0 | True=1 | ❌
#   [552] P(ironic)=0.062 | Pred=0 | True=0 | ✅
#   [553] P(ironic)=0.525 | Pred=1 | True=0 | ❌
#   [554] P(ironic)=0.368 | Pred=0 | True=0 | ✅
#   [555] P(ironic)=0.846 | Pred=1 | True=0 | ❌
#   [556] P(ironic)=0.113 | Pred=0 | True=1 | ❌
#   [557] P(ironic)=0.847 | Pred=1 | True=1 | ✅
#   [558] P(ironic)=0.057 | Pred=0 | True=0 | ✅
#   [559] P(ironic)=0.232 | Pred=0 | True=1 | ❌
#   [560] P(ironic)=0.817 | Pred=1 | True=1 | ✅
#   [561] P(ironic)=0.115 | Pred=0 | True=0 | ✅
#   [562] P(ironic)=0.127 | Pred=0 | True=0 | ✅
#   [563] P(ironic)=0.371 | Pred=0 | True=0 | ✅
#   [564] P(ironic)=0.042 | Pred=0 | True=0 | ✅
#   [565] P(ironic)=0.405 | Pred=0 | True=1 | ❌
#   [566] P(ironic)=0.595 | Pred=1 | True=1 | ✅
#   [567] P(ironic)=0.179 | Pred=0 | True=0 | ✅
#   [568] P(ironic)=0.113 | Pred=0 | True=0 | ✅
#   [569] P(ironic)=0.070 | Pred=0 | True=0 | ✅
#   [570] P(ironic)=0.934 | Pred=1 | True=1 | ✅
#   [571] P(ironic)=0.867 | Pred=1 | True=1 | ✅
#   [572] P(ironic)=0.988 | Pred=1 | True=1 | ✅
#   [573] P(ironic)=0.051 | Pred=0 | True=0 | ✅
#   [574] P(ironic)=0.741 | Pred=1 | True=0 | ❌
#   [575] P(ironic)=0.129 | Pred=0 | True=0 | ✅
#   [576] P(ironic)=0.954 | Pred=1 | True=1 | ✅
#   [577] P(ironic)=0.104 | Pred=0 | True=0 | ✅
#   [578] P(ironic)=0.567 | Pred=1 | True=0 | ❌
#   [579] P(ironic)=0.811 | Pred=1 | True=1 | ✅
#   [580] P(ironic)=0.038 | Pred=0 | True=0 | ✅
#   [581] P(ironic)=0.684 | Pred=1 | True=1 | ✅
#   [582] P(ironic)=0.409 | Pred=0 | True=0 | ✅
#   [583] P(ironic)=0.161 | Pred=0 | True=0 | ✅
#   [584] P(ironic)=0.057 | Pred=0 | True=1 | ❌
#   [585] P(ironic)=0.099 | Pred=0 | True=0 | ✅
#   [586] P(ironic)=0.105 | Pred=0 | True=0 | ✅
#   [587] P(ironic)=0.599 | Pred=1 | True=1 | ✅
#   [588] P(ironic)=0.755 | Pred=1 | True=0 | ❌
#   [589] P(ironic)=0.221 | Pred=0 | True=1 | ❌
#   [590] P(ironic)=0.968 | Pred=1 | True=1 | ✅
#   [591] P(ironic)=0.219 | Pred=0 | True=1 | ❌
#   [592] P(ironic)=0.428 | Pred=0 | True=0 | ✅
#   [593] P(ironic)=0.667 | Pred=1 | True=1 | ✅
#   [594] P(ironic)=0.203 | Pred=0 | True=1 | ❌
#   [595] P(ironic)=0.082 | Pred=0 | True=0 | ✅
#   [596] P(ironic)=0.924 | Pred=1 | True=1 | ✅
#   [597] P(ironic)=0.057 | Pred=0 | True=0 | ✅
#   [598] P(ironic)=0.122 | Pred=0 | True=0 | ✅
#   [599] P(ironic)=0.835 | Pred=1 | True=1 | ✅
#   [600] P(ironic)=0.901 | Pred=1 | True=0 | ❌
#   [601] P(ironic)=0.090 | Pred=0 | True=0 | ✅
#   [602] P(ironic)=0.077 | Pred=0 | True=0 | ✅
#   [603] P(ironic)=0.154 | Pred=0 | True=0 | ✅
#   [604] P(ironic)=0.725 | Pred=1 | True=1 | ✅
#   [605] P(ironic)=0.065 | Pred=0 | True=0 | ✅
#   [606] P(ironic)=0.847 | Pred=1 | True=1 | ✅
#   [607] P(ironic)=0.055 | Pred=0 | True=0 | ✅
#   [608] P(ironic)=0.764 | Pred=1 | True=1 | ✅
#   [609] P(ironic)=0.642 | Pred=1 | True=1 | ✅
#   [610] P(ironic)=0.559 | Pred=1 | True=0 | ❌
#   [611] P(ironic)=0.124 | Pred=0 | True=1 | ❌
#   [612] P(ironic)=0.485 | Pred=0 | True=0 | ✅
#   [613] P(ironic)=0.088 | Pred=0 | True=0 | ✅
#   [614] P(ironic)=0.119 | Pred=0 | True=1 | ❌
#   [615] P(ironic)=0.365 | Pred=0 | True=1 | ❌
#   [616] P(ironic)=0.776 | Pred=1 | True=1 | ✅
#   [617] P(ironic)=0.048 | Pred=0 | True=0 | ✅
#   [618] P(ironic)=0.049 | Pred=0 | True=0 | ✅
#   [619] P(ironic)=0.816 | Pred=1 | True=0 | ❌
#   [620] P(ironic)=0.238 | Pred=0 | True=1 | ❌
#   [621] P(ironic)=0.711 | Pred=1 | True=0 | ❌
#   [622] P(ironic)=0.699 | Pred=1 | True=1 | ✅
#   [623] P(ironic)=0.146 | Pred=0 | True=0 | ✅
#   [624] P(ironic)=0.459 | Pred=0 | True=0 | ✅
#   [625] P(ironic)=0.097 | Pred=0 | True=1 | ❌
#   [626] P(ironic)=0.960 | Pred=1 | True=1 | ✅
#   [627] P(ironic)=0.574 | Pred=1 | True=1 | ✅
#   [628] P(ironic)=0.766 | Pred=1 | True=1 | ✅
#   [629] P(ironic)=0.511 | Pred=1 | True=1 | ✅
#   [630] P(ironic)=0.211 | Pred=0 | True=0 | ✅
#   [631] P(ironic)=0.267 | Pred=0 | True=0 | ✅
#   [632] P(ironic)=0.817 | Pred=1 | True=1 | ✅
#   [633] P(ironic)=0.055 | Pred=0 | True=1 | ❌
#   [634] P(ironic)=0.097 | Pred=0 | True=1 | ❌
#   [635] P(ironic)=0.077 | Pred=0 | True=0 | ✅
#   [636] P(ironic)=0.970 | Pred=1 | True=0 | ❌
#   [637] P(ironic)=0.881 | Pred=1 | True=1 | ✅
#   [638] P(ironic)=0.429 | Pred=0 | True=1 | ❌
#   [639] P(ironic)=0.282 | Pred=0 | True=0 | ✅
#   [640] P(ironic)=0.308 | Pred=0 | True=1 | ❌
#   [641] P(ironic)=0.074 | Pred=0 | True=0 | ✅
#   [642] P(ironic)=0.167 | Pred=0 | True=0 | ✅
#   [643] P(ironic)=0.909 | Pred=1 | True=0 | ❌
#   [644] P(ironic)=0.072 | Pred=0 | True=0 | ✅
#   [645] P(ironic)=0.959 | Pred=1 | True=1 | ✅
#   [646] P(ironic)=0.030 | Pred=0 | True=0 | ✅
#   [647] P(ironic)=0.074 | Pred=0 | True=0 | ✅
#   [648] P(ironic)=0.090 | Pred=0 | True=0 | ✅
#   [649] P(ironic)=0.138 | Pred=0 | True=0 | ✅
#   [650] P(ironic)=0.616 | Pred=1 | True=1 | ✅
#   [651] P(ironic)=0.755 | Pred=1 | True=1 | ✅
#   [652] P(ironic)=0.147 | Pred=0 | True=0 | ✅
#   [653] P(ironic)=0.054 | Pred=0 | True=0 | ✅
#   [654] P(ironic)=0.512 | Pred=1 | True=0 | ❌
#   [655] P(ironic)=0.965 | Pred=1 | True=1 | ✅
#   [656] P(ironic)=0.759 | Pred=1 | True=0 | ❌
#   [657] P(ironic)=0.245 | Pred=0 | True=0 | ✅
#   [658] P(ironic)=0.163 | Pred=0 | True=0 | ✅
#   [659] P(ironic)=0.053 | Pred=0 | True=1 | ❌
#   [660] P(ironic)=0.847 | Pred=1 | True=1 | ✅
#   [661] P(ironic)=0.189 | Pred=0 | True=0 | ✅
#   [662] P(ironic)=0.983 | Pred=1 | True=1 | ✅
#   [663] P(ironic)=0.532 | Pred=1 | True=0 | ❌
#   [664] P(ironic)=0.686 | Pred=1 | True=1 | ✅
#   [665] P(ironic)=0.510 | Pred=1 | True=0 | ❌
#   [666] P(ironic)=0.941 | Pred=1 | True=1 | ✅
#   [667] P(ironic)=0.121 | Pred=0 | True=0 | ✅
#   [668] P(ironic)=0.031 | Pred=0 | True=0 | ✅
#   [669] P(ironic)=0.169 | Pred=0 | True=0 | ✅
#   [670] P(ironic)=0.124 | Pred=0 | True=0 | ✅
#   [671] P(ironic)=0.498 | Pred=0 | True=1 | ❌
#   [672] P(ironic)=0.889 | Pred=1 | True=1 | ✅
#   [673] P(ironic)=0.605 | Pred=1 | True=0 | ❌
#   [674] P(ironic)=0.112 | Pred=0 | True=1 | ❌
#   [675] P(ironic)=0.802 | Pred=1 | True=1 | ✅
#   [676] P(ironic)=0.331 | Pred=0 | True=0 | ✅
#   [677] P(ironic)=0.277 | Pred=0 | True=0 | ✅
#   [678] P(ironic)=0.479 | Pred=0 | True=0 | ✅
#   [679] P(ironic)=0.221 | Pred=0 | True=0 | ✅
#   [680] P(ironic)=0.188 | Pred=0 | True=0 | ✅
#   [681] P(ironic)=0.086 | Pred=0 | True=0 | ✅
#   [682] P(ironic)=0.227 | Pred=0 | True=0 | ✅
#   [683] P(ironic)=0.079 | Pred=0 | True=1 | ❌
#   [684] P(ironic)=0.613 | Pred=1 | True=1 | ✅
#   [685] P(ironic)=0.064 | Pred=0 | True=0 | ✅
#   [686] P(ironic)=0.384 | Pred=0 | True=0 | ✅
#   [687] P(ironic)=0.062 | Pred=0 | True=0 | ✅
#   [688] P(ironic)=0.317 | Pred=0 | True=0 | ✅
#   [689] P(ironic)=0.193 | Pred=0 | True=0 | ✅
#   [690] P(ironic)=0.504 | Pred=1 | True=1 | ✅
#   [691] P(ironic)=0.034 | Pred=0 | True=0 | ✅
#   [692] P(ironic)=0.278 | Pred=0 | True=1 | ❌
#   [693] P(ironic)=0.038 | Pred=0 | True=0 | ✅
#   [694] P(ironic)=0.333 | Pred=0 | True=0 | ✅
#   [695] P(ironic)=0.253 | Pred=0 | True=1 | ❌
#   [696] P(ironic)=0.074 | Pred=0 | True=0 | ✅
#   [697] P(ironic)=0.071 | Pred=0 | True=0 | ✅
#   [698] P(ironic)=0.054 | Pred=0 | True=0 | ✅
#   [699] P(ironic)=0.200 | Pred=0 | True=1 | ❌
#   [700] P(ironic)=0.288 | Pred=0 | True=1 | ❌
#   [701] P(ironic)=0.973 | Pred=1 | True=0 | ❌
#   [702] P(ironic)=0.068 | Pred=0 | True=1 | ❌
#   [703] P(ironic)=0.245 | Pred=0 | True=0 | ✅
#   [704] P(ironic)=0.564 | Pred=1 | True=0 | ❌
#   [705] P(ironic)=0.251 | Pred=0 | True=0 | ✅
#   [706] P(ironic)=0.252 | Pred=0 | True=1 | ❌
#   [707] P(ironic)=0.240 | Pred=0 | True=0 | ✅
#   [708] P(ironic)=0.632 | Pred=1 | True=0 | ❌
#   [709] P(ironic)=0.222 | Pred=0 | True=1 | ❌
#   [710] P(ironic)=0.143 | Pred=0 | True=0 | ✅
#   [711] P(ironic)=0.104 | Pred=0 | True=0 | ✅
#   [712] P(ironic)=0.113 | Pred=0 | True=0 | ✅
#   [713] P(ironic)=0.289 | Pred=0 | True=1 | ❌
#   [714] P(ironic)=0.415 | Pred=0 | True=1 | ❌
#   [715] P(ironic)=0.070 | Pred=0 | True=0 | ✅
#   [716] P(ironic)=0.115 | Pred=0 | True=0 | ✅
#   [717] P(ironic)=0.037 | Pred=0 | True=0 | ✅
#   [718] P(ironic)=0.316 | Pred=0 | True=0 | ✅
#   [719] P(ironic)=0.790 | Pred=1 | True=1 | ✅
#   [720] P(ironic)=0.973 | Pred=1 | True=1 | ✅
#   [721] P(ironic)=0.492 | Pred=0 | True=0 | ✅
#   [722] P(ironic)=0.811 | Pred=1 | True=0 | ❌
#   [723] P(ironic)=0.070 | Pred=0 | True=0 | ✅
#   [724] P(ironic)=0.909 | Pred=1 | True=1 | ✅
#   [725] P(ironic)=0.434 | Pred=0 | True=0 | ✅
#   [726] P(ironic)=0.952 | Pred=1 | True=1 | ✅
#   [727] P(ironic)=0.071 | Pred=0 | True=0 | ✅
#   [728] P(ironic)=0.154 | Pred=0 | True=0 | ✅
#   [729] P(ironic)=0.049 | Pred=0 | True=0 | ✅
#   [730] P(ironic)=0.494 | Pred=0 | True=1 | ❌
#   [731] P(ironic)=0.070 | Pred=0 | True=0 | ✅
#   [732] P(ironic)=0.130 | Pred=0 | True=0 | ✅
#   [733] P(ironic)=0.955 | Pred=1 | True=1 | ✅
#   [734] P(ironic)=0.266 | Pred=0 | True=0 | ✅
#   [735] P(ironic)=0.977 | Pred=1 | True=1 | ✅
#   [736] P(ironic)=0.797 | Pred=1 | True=1 | ✅
#   [737] P(ironic)=0.053 | Pred=0 | True=0 | ✅
#   [738] P(ironic)=0.954 | Pred=1 | True=1 | ✅
#   [739] P(ironic)=0.337 | Pred=0 | True=0 | ✅
#   [740] P(ironic)=0.253 | Pred=0 | True=1 | ❌
#   [741] P(ironic)=0.747 | Pred=1 | True=0 | ❌
#   [742] P(ironic)=0.491 | Pred=0 | True=1 | ❌
#   [743] P(ironic)=0.090 | Pred=0 | True=0 | ✅
#   [744] P(ironic)=0.262 | Pred=0 | True=0 | ✅
#   [745] P(ironic)=0.101 | Pred=0 | True=0 | ✅
#   [746] P(ironic)=0.911 | Pred=1 | True=1 | ✅
#   [747] P(ironic)=0.405 | Pred=0 | True=0 | ✅
#   [748] P(ironic)=0.117 | Pred=0 | True=0 | ✅
#   [749] P(ironic)=0.401 | Pred=0 | True=1 | ❌
#   [750] P(ironic)=0.844 | Pred=1 | True=1 | ✅
#   [751] P(ironic)=0.609 | Pred=1 | True=1 | ✅
#   [752] P(ironic)=0.678 | Pred=1 | True=1 | ✅
#   [753] P(ironic)=0.636 | Pred=1 | True=1 | ✅
#   [754] P(ironic)=0.372 | Pred=0 | True=1 | ❌
#   [755] P(ironic)=0.918 | Pred=1 | True=1 | ✅
#   [756] P(ironic)=0.193 | Pred=0 | True=1 | ❌
#   [757] P(ironic)=0.213 | Pred=0 | True=1 | ❌
#   [758] P(ironic)=0.347 | Pred=0 | True=1 | ❌
#   [759] P(ironic)=0.045 | Pred=0 | True=0 | ✅
#   [760] P(ironic)=0.207 | Pred=0 | True=0 | ✅
#   [761] P(ironic)=0.078 | Pred=0 | True=0 | ✅
#   [762] P(ironic)=0.136 | Pred=0 | True=1 | ❌
#   [763] P(ironic)=0.053 | Pred=0 | True=0 | ✅
#   [764] P(ironic)=0.054 | Pred=0 | True=1 | ❌
#   [765] P(ironic)=0.037 | Pred=0 | True=0 | ✅
#   [766] P(ironic)=0.100 | Pred=0 | True=0 | ✅
#   [767] P(ironic)=0.059 | Pred=0 | True=0 | ✅
#   [768] P(ironic)=0.281 | Pred=0 | True=1 | ❌
#   [769] P(ironic)=0.297 | Pred=0 | True=0 | ✅
#   [770] P(ironic)=0.982 | Pred=1 | True=1 | ✅
#   [771] P(ironic)=0.621 | Pred=1 | True=0 | ❌
#   [772] P(ironic)=0.057 | Pred=0 | True=0 | ✅
#   [773] P(ironic)=0.933 | Pred=1 | True=1 | ✅
#   [774] P(ironic)=0.974 | Pred=1 | True=1 | ✅
#   [775] P(ironic)=0.268 | Pred=0 | True=0 | ✅
#   [776] P(ironic)=0.509 | Pred=1 | True=1 | ✅
#   [777] P(ironic)=0.345 | Pred=0 | True=1 | ❌
#   [778] P(ironic)=0.935 | Pred=1 | True=1 | ✅
#   [779] P(ironic)=0.074 | Pred=0 | True=1 | ❌
#   [780] P(ironic)=0.027 | Pred=0 | True=0 | ✅
#   [781] P(ironic)=0.082 | Pred=0 | True=0 | ✅
#   [782] P(ironic)=0.326 | Pred=0 | True=0 | ✅
#   [783] P(ironic)=0.796 | Pred=1 | True=1 | ✅
#   [784] P(ironic)=0.093 | Pred=0 | True=0 | ✅
#
# ============================================================
# 🏆 RoBERTa-ONLY ACCURACY : 73.5%  (576/784)
# 📋 Model                 : cardiffnlp/twitter-roberta-base-irony
# 📋 Input                 : Raw tweet (no CoT, no compression)
# ============================================================
#                                                  Tweet  True  Pred ✓?  \
# 0    @user Can U Help?||More conservatives needed o...     0     0  ✅
# 1    Just walked in to #Starbucks and asked for a "...     1     1  ✅
# 2                                    #NOT GONNA WIN...     0     0  ✅
# 3    @user He is exactly that sort of person. Weird...     0     0  ✅
# 4    So much #sarcasm at work mate 10/10 #boring 10...     1     0  ❌
# ..                                                 ...   ...   ... ..
# 779  If you drag yesterday into today, your tomorro...     0     0  ✅
# 780  Congrats to my fav @user & her team & my birth...     0     0  ✅
# 781  @user Jessica sheds tears at her fan signing e...     0     0  ✅
# 782  #Irony: al jazeera is pro Anti - #GamerGate be...     1     1  ✅
# 783  #NOT ALL 👌 There good & bad in every occupatio...     0     0  ✅
#
#      P(ironic)
# 0        0.303
# 1        0.650
# 2        0.033
# 3        0.209
# 4        0.075
# ..         ...
# 779      0.027
# 780      0.082
# 781      0.326
# 782      0.796
# 783      0.093
#
# [784 rows x 5 columns]

# %% [markdown]
# ## 5. Summary
#
# This notebook quantifies the baseline classification accuracy of a fine-tuned RoBERTa model on the TweetEval irony task **without any Chain-of-Thought augmentation**.
#
# The expected accuracy of ~69% serves as a critical reference point for the comparative study:
#
# - **Uncompressed CoT (~51%)** shows that Qwen 2.5-3B alone is weaker than RoBERTa at zero-shot irony detection.
# - **Vanilla TokenSkip (~48%)** shows that blind compression further degrades the already weak CoT signal.
# - **RDS Framework (~74%)** shows that entropy-gated fusion of compressed CoT with RoBERTa **surpasses** both individual components, validating the synergistic value of the Robust Dynamic Skipping architecture.
#
# The RDS framework does not merely preserve RoBERTa's 69% — it **enhances** it by intelligently leveraging Qwen's confident reasoning (low entropy) while suppressing its noisy predictions (high entropy).
